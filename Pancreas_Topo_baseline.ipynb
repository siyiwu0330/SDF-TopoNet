# %%
import sys
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False
if IN_COLAB:
    # !pip3 install torch matplotlib torchmetrics scikit-image segmentation-models-pytorch &> /dev/null

# %%
# !pip install -U giotto-tda &> /dev/null
# !pip install torch_topological &> /dev/null

# %%
import torch
from torch import nn as nn
from torchvision import transforms as T
from torchvision.transforms import functional as TF
from torchvision.datasets.utils import download_url
from torchvision.transforms import RandomCrop, Compose, ToTensor

from torch import Tensor

import torchmetrics
import segmentation_models_pytorch as smp

import random
import numpy as np
import matplotlib.pyplot as plt
import os

from pprint import pformat
from skimage.transform import resize
from pathlib import Path
from glob import glob
from matplotlib.pyplot import imread
from collections import defaultdict

from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import DataLoader, random_split
from torchvision import transforms
import statistics
import cv2

import torch.nn.functional as F

# from gtda.homology import VietorisRipsPersistence, CubicalPersistence, WeakAlphaPersistence
# from gtda.diagrams import PersistenceEntropy, PairwiseDistance, Amplitude

from torch_topological.nn import AlphaComplex, VietorisRipsComplex, CubicalComplex, WassersteinDistance, SignatureLoss

import h5py
from scipy.ndimage import binary_dilation

# %%
import h5py
from skimage import morphology
from scipy.ndimage import distance_transform_edt

# %%
gpu = torch.cuda.is_available()
device = torch.device("cuda:0" if gpu else "cpu")
print("device:", device)
# Out:
# device: cuda:0

# %%
data_path = '/content/drive/MyDrive/code/TDA/sample_A_20160501.hdf'

batch_size = 4

epochs = 200

lr = 0.0001

# loss = loss_1 * alpha + loss_2 * (1-alpha)
alpha = 0.99

crop_size = (128,128)

padding = 2

# %%
def load_datasets(root_dir):
    datasets = []
    for subdir in sorted(os.listdir(root_dir)):
        img_dir = os.path.join(root_dir, subdir, "COL_MIP_CLEAN.mat")

        with h5py.File(img_dir, 'r') as f:
            imgs = np.array(f['COL_MIP_CLEAN'])[:, 0, :, :]  # Only use the first channel
        datasets.append(imgs)
    return datasets

# %%
root_dir = '/content/drive/MyDrive/code/datasets/ForJonsStudent/'
datasets = load_datasets(root_dir)

# %%
def img_norm(img):
    img = img - np.min(img)
    img = img / np.max(img)
    img = img * 255.0
    img = img.astype(np.uint8)
    return img

# %%
def gen_label(img, threshold):
    img = img > threshold
    img = morphology.remove_small_objects(img, min_size=64, connectivity=2)
    img = morphology.remove_small_holes(img, 64)

    return img

# %%
datasets[0].shape
# Out:
# (170, 1024, 1024)

# %%
class Dataset(Dataset):
    def __init__(self, datasets, data_type, sample_size=10, crop_size=None, enable_sdf=False):
        """
        datasets: A list of tuples, each containing images and labels from one directory.
        data_type: 'train', 'val', or 'test'
        """
        self.crop_size = crop_size
        self.data_type = data_type
        self.sample_size = sample_size
        self.enable_sdf = enable_sdf

        self.transform = Compose([
            ToTensor(),
            RandomCrop(crop_size) if crop_size else None  # 添加随机剪裁
        ])

        all_imgs = np.concatenate([d for d in datasets], axis=0)

        # Example split: 5 folders for training, 1 folder for validation, 1 folder for testing
        if data_type == 'train':
            self.imgs = all_imgs[:850]  # Use the first 5 folders for training
        elif data_type == 'val':
            self.imgs = all_imgs[850:1200] # Use the 6th folders for validation
        elif data_type == 'test':
            self.imgs = all_imgs[1200:]  # Use the last folder for testing

        # Sample every 10th image to get 17 images per set from each folder
        indices = np.arange(0, len(self.imgs), self.sample_size)
        self.imgs = self.imgs[indices]


    def __getitem__(self, idx):
        img = self.imgs[idx]

        label = gen_label(img, 2000)

        img = img_norm(img)
        img = Image.fromarray(img).convert('L')
        label = Image.fromarray(label).convert('L')

        # Crop images
        if self.crop_size:
            seed = np.random.randint(1145141919810)
            torch.manual_seed(seed)
            img = self.transform(img)
            torch.manual_seed(seed)
            label = self.transform(label)

        if self.enable_sdf == True:
            label = label.numpy()
            label = distance_transform_edt(label) - distance_transform_edt(1 - label)
            label = torch.from_numpy(label).float()

        return img, label

    def __len__(self):
        return len(self.imgs)

# %%
train_set = Dataset(datasets, data_type="train", crop_size=crop_size, enable_sdf=True)
val_set = Dataset(datasets, data_type="val", crop_size=crop_size, enable_sdf=True)
test_set = Dataset(datasets, data_type="test", crop_size=crop_size, enable_sdf=True)

print(len(train_set))
print(len(val_set))
print(len(test_set))

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_set, batch_size=1, shuffle=False)
# Out:
# 85
# 35
# 35

# %%
for batch_x, batch_y in train_loader:
    print(batch_x.size())
    print(batch_y.size())
    plt.subplot(1, 3, 1)
    plt.imshow(batch_x[0].numpy().transpose(1,2,0), cmap=plt.get_cmap('gray'))
    plt.axis("off")
    plt.subplot(1, 3, 2)
    plt.imshow(batch_y[0][0], cmap=plt.get_cmap('gray'))
    plt.axis("off")
    plt.subplot(1, 3, 3)
    plt.imshow(batch_y[0][0]>0, cmap=plt.get_cmap('gray'))
    plt.axis("off")
    plt.show()

    print(np.max(batch_y[0].numpy()))
    print(np.min(batch_y[0].numpy()))
    print(batch_y[0].dtype)

    break
# Out:
# torch.Size([4, 1, 128, 128])
# torch.Size([4, 1, 128, 128])
# 20.880613
# -30.413813
# torch.float32

# %%
def plot_image_with_segmentation(image, segmentation, ax=None, model='gray', sdf=True, threshold=0.5):
    """
    Plots an image with overlayed segmentation mask. Segmentation is thresholded at 0.5

    Returns: plt.fig and ax objects
    """
    if ax is None:
        fig = plt.figure(figsize=(8, 8))
        ax = fig.add_subplot(111)
        ax.axis("off")

    im = image.cpu().detach().numpy()
    segm = segmentation.cpu().detach().numpy()
    if model == 'gray':
        ax.imshow(im.squeeze(), cmap="gray")
    elif model == 'rgb':
        ax.imshow(np.transpose(im.squeeze(), (1, 2, 0)))
    if sdf == True:
        mask = segm
    else:
        mask = segm < threshold
    ax.imshow(mask.squeeze(), cmap="Set1", alpha=0.5)
    return plt.gcf(), ax

# %%
def evaluate_model_on_single_image(model, x, device=device):
    """
    Evaluate a model on a single data point on the device.

    Returns: model(x)
    """
    with torch.no_grad():
        x = x.to(device)
        return model(x.view(1, *x.shape))

# %%
def evaluate_model(model, data_loader, metrics_dict, reduction=True, device=device, alpha=0.5):
    """
    Evaluate a model 'model' on all batches of a torch DataLoader 'data_loader'.
    On each batch, compute all metric functions stored in dictionary 'metrics_dict'.

    Returns: dict of metric_name: (list of batch-wise metrics if reduction == False, else single scalar)
    """

    # defaultdict(list) returns a dictionary-like object with default_factory list.
    # When a new key is encountered, an entry is automatically created of type default_factory.
    metrics = defaultdict(list)
    with torch.no_grad():
        for i, (batch_x, batch_y) in enumerate(data_loader):
            # Predict on batch
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)
            logits = model(batch_x)

            if alpha == 0.0:
                for metric_name, metric_func in metrics_dict.items():
                    value_1 = 0
                    value_2 = metric_func[1](logits.cpu(), batch_y.cpu()).item()

                    value = alpha*value_1 + (1-alpha)*value_2

                    metrics[metric_name].append(value)

            elif alpha == 1.0:
                for metric_name, metric_func in metrics_dict.items():
                    value_1 = metric_func[0](logits.cpu(), batch_y.cpu()).item() #.cpu().numpy()
                    value_2 = 0

                    value = alpha*value_1 + (1-alpha)*value_2

                    metrics[metric_name].append(value)

            else:
                for metric_name, metric_func in metrics_dict.items():
                    value_1 = metric_func[0](logits.cpu(), batch_y.cpu()).item() #.cpu().numpy()
                    value_2 = metric_func[1](logits.cpu(), batch_y.cpu()).item()

                    value = alpha*value_1 + (1-alpha)*value_2

                    metrics[metric_name].append(value)

    if reduction == True:
        # Return mean values
        return {key: np.mean(value) for key, value in metrics.items()}
    else:
        return metrics

# %%
def save_model(model, path, optimizer=None):
    """
    Saves the state_dict of a torch model and optional optimizer to 'path'
    Returns: None
    """
    state = {"model": model.state_dict()}
    if optimizer is not None:
        state["optimizer"] = optimizer.state_dict()
    torch.save(state, path)


def load_model(model, path, optimizer=None):
    """
    Loads the state_dict of a torch model and optional optimizer from 'path'
    Returns: None
    """
    state = torch.load(path)
    model.load_state_dict(state["model"])
    if optimizer is not None:
        optimizer.load_state_dict(state["optimizer"])

# %%
def plot_histories(train_history=None, val_history=None, label="Loss"):
    """
    Takes a list of training and/or validation metrics and plots them
    Returns: plt.figure and ax objects
    """
    if not train_history and not val_history:
        raise ValueError("Must specify at least one of 'train_histories' and 'val_histories'")
    fig = plt.figure(figsize=(5, 3))
    ax = fig.add_subplot(111)

    epochs = np.arange(len(train_history or val_history))
    if train_history:
        ax.plot(epochs, train_history, label="Training", color="black")
    if val_history:
        ax.plot(epochs, val_history, label="Validation", color="darkred")

    ax.set_xlabel("Epoch")
    ax.set_ylabel(label)
    ax.legend(loc=0)

    return fig, ax

# %%
def run_one_epoch(model, loss, optimizer, train_loader, val_loader, n_epochs, metrics_dict, device=device, alpha=0.5):
    """
    Run 1 epoch of training
    Changes to model parameters and optimizer occour internally (state updates)
    Returns:
        two dictionaries, training and a validation metrics
    """
    train_losses = []
    for i, (batch_x, batch_y) in enumerate(train_loader):
        # Zero out stored gradients for all parameters
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)
        optimizer.zero_grad()

        print(f"   -- Batch {i+1}/{len(train_loader)}", end=" / ")
        # Predict on batch
        logits = model(batch_x)

        if alpha == 0.0:
            loss_tensor_1 = 0
            loss_tensor_2 = loss[1](logits, batch_y)
        elif alpha == 1.0:
            loss_tensor_1 = loss[0](logits, batch_y)
            loss_tensor_2 = 0
        else:
            # Compute loss function
            loss_tensor_1 = loss[0](logits, batch_y)
            loss_tensor_2 = loss[1](logits, batch_y)

            print(loss_tensor_2)

        loss_tensor = alpha*loss_tensor_1 + (1-alpha)*loss_tensor_2
        loss_scalar = loss_tensor.detach().cpu().numpy()

        train_losses.append(loss_scalar)
        print("Loss: ", loss_scalar)

        # Backprop and step
        loss_tensor.backward()
        optimizer.step()

    # Run validation
    print("   Validation running...")
    val_metrics = evaluate_model(
        model=model,
        data_loader=val_loader,
        metrics_dict=metrics_dict,
        alpha=alpha
    )
    # Return loss and metrics as dicts
    return {"loss": np.mean(train_losses)}, val_metrics


def merge_list_of_dicts(list_of_dicts):
    """
    Takes a list of dictionaries and merges them into a single dictionary pointing to lists

    E.g. [{"loss": 5}, {"loss": 3}, {"loss": -2, "F1": 0.5}] --> {"loss": [5, 3, -2], "F1": [0.5]}

    Returns: dict
    """
    merged = defaultdict(list)
    for dict_ in list_of_dicts:
        for value, key in dict_.items():
            merged[value].append(key)
    return merged


def training_loop(model, loss, optimizer, train_loader, val_loader, n_epochs, init_epoch=None, metrics_dict=None, save_path=None, alpha=0.5):
    """
    Run training of a model given a loss function, optimizer and a set of training and validation data.
    Supports computing additional metrics on the validation set (only) via the metrics_dict param.
    Specify save_path to store the model at each epoch.

    Returns:
        Two lists of metric dictionaries for each epoch for training and validation, specifically
    """
    train_history, val_history = [], []

    metrics_with_loss = {"loss": loss}
    if metrics_dict is not None:
        metrics_with_loss.update(metrics_dict)

    if init_epoch == None:
        init_epoch = 0
    try:
        for i in range(init_epoch, n_epochs):
            print(f"Epoch {i+1}/{n_epochs}")
            train_metrics, val_metrics = run_one_epoch(
                model=model,
                loss=loss,
                optimizer=optimizer,
                train_loader=train_loader,
                val_loader=val_loader,
                n_epochs=n_epochs,
                metrics_dict=metrics_with_loss,
                alpha=alpha
            )
            print("   Mean epoch metrics:")
            print(f"   Training:   {pformat(train_metrics)}")
            print(f"   Validation: {pformat(val_metrics)}")
            train_history.append(train_metrics), val_history.append(val_metrics)

            # wandb.log({'epoch': n_epochs+1, 'loss': train_metrics['loss'], 'val_loss': val_metrics['loss']})
            # wandb.watch(model, loss, log="all")

            # if save_path:
            #     save_path_epoch = f"epoch_{i+1}_{save_path}"
            #     print(f"   Saving to: {save_path_epoch}")
            #     save_model(model, save_path_epoch, optimizer)
            #     old_path_epoch = f"epoch_{i}_{save_path}"
            #     if os.path.exists(old_path_epoch):
            #         os.remove(old_path_epoch)

    except KeyboardInterrupt:
        print("Training stopped.")
        pass

    # Merge list of training and validation dicts into single dicts
    return merge_list_of_dicts(train_history), merge_list_of_dicts(val_history)

# %%
# Init U-Net model
model = smp.Unet(encoder_name='efficientnet-b0',in_channels=1,classes=1)

model.to(device)

# Define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

print(model)
# Out:
# Unet(
#   (encoder): EfficientNetEncoder(
#     (_conv_stem): Conv2dStaticSamePadding(
#       1, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#       (static_padding): ZeroPad2d((0, 1, 0, 1))
#     )
#     (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (_blocks): ModuleList(
#       (0): MBConvBlock(
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           32, 8, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           8, 32, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (1): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#           (static_padding): ZeroPad2d((0, 1, 0, 1))
#         )
#         (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           96, 4, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           4, 96, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (2): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           144, 6, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           6, 144, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (3): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#           (static_padding): ZeroPad2d((1, 2, 1, 2))
#         )
#         (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           144, 6, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           6, 144, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (4): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           240, 10, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           10, 240, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (5): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           240, 240, kernel_size=(3, 3), stride=[2, 2], groups=240, bias=False
#           (static_padding): ZeroPad2d((0, 1, 0, 1))
#         )
#         (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           240, 10, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           10, 240, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (6-7): 2 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           480, 20, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           20, 480, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (8): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           480, 480, kernel_size=(5, 5), stride=[1, 1], groups=480, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           480, 20, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           20, 480, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (9-10): 2 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           672, 28, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           28, 672, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (11): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           672, 672, kernel_size=(5, 5), stride=[2, 2], groups=672, bias=False
#           (static_padding): ZeroPad2d((1, 2, 1, 2))
#         )
#         (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           672, 28, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           28, 672, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (12-14): 3 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1152, 48, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           48, 1152, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (15): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1152, 1152, kernel_size=(3, 3), stride=[1, 1], groups=1152, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1152, 48, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           48, 1152, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#     )
#     (_conv_head): Conv2dStaticSamePadding(
#       320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn1): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#     (_dropout): Dropout(p=0.2, inplace=False)
#     (_swish): MemoryEfficientSwish()
#   )
#   (decoder): UnetDecoder(
#     (center): Identity()
#     (blocks): ModuleList(
#       (0): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(432, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (1): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(296, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (2): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(152, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (3): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (4): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#     )
#   )
#   (segmentation_head): SegmentationHead(
#     (0): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Identity()
#     (2): Activation(
#       (activation): Identity()
#     )
#   )
# )

# %%
# Specify integer, starting at 1
init_epoch = None
if init_epoch != None:
    load_model(model, f"epoch_{init_epoch}_model.ckpt", optimizer)

# %%
def soft_dice(y_true, y_pred):
    smooth = 1
    intersection = torch.sum((y_true * y_pred))
    coeff = (2. * intersection + smooth) / (torch.sum(y_true) + torch.sum(y_pred) + smooth)
    return 1. - coeff


class soft_dice_cldice(nn.Module):
    def __init__(self, iter_=3, alpha=0.5, smooth=1.):
        super(soft_dice_cldice, self).__init__()
        self.iter = iter_
        self.smooth = smooth
        self.alpha = alpha

    def forward(self, y_pred, y_true):
        dice = soft_dice(y_true, y_pred)
        skel_pred = soft_skel(y_pred, self.iter)
        skel_true = soft_skel(y_true, self.iter)
        tprec = (torch.sum(torch.multiply(skel_pred, y_true)) + self.smooth) / (
                    torch.sum(skel_pred) + self.smooth)
        tsens = (torch.sum(torch.multiply(skel_true, y_pred)) + self.smooth) / (
                    torch.sum(skel_true) + self.smooth)
        cl_dice = 1. - 2.0 * (tprec * tsens) / (tprec + tsens)
        return (1.0 - self.alpha) * dice + self.alpha * cl_dice

class soft_cldice(nn.Module):
    def __init__(self, iter_=3, alpha=0.5, smooth=1.):
        super(soft_cldice, self).__init__()
        self.iter = iter_
        self.smooth = smooth
        self.alpha = alpha

    def forward(self, y_pred, y_true):
        skel_pred = soft_skel(y_pred, self.iter)
        skel_true = soft_skel(y_true, self.iter)
        tprec = (torch.sum(torch.multiply(skel_pred, y_true)) + self.smooth) / (
                    torch.sum(skel_pred) + self.smooth)
        tsens = (torch.sum(torch.multiply(skel_true, y_pred)) + self.smooth) / (
                    torch.sum(skel_true) + self.smooth)
        cl_dice = 1. - 2.0 * (tprec * tsens) / (tprec + tsens)
        return cl_dice

def soft_erode(img):
    if len(img.shape) == 4:
        p1 = -F.max_pool2d(-img, (3, 1), (1, 1), (1, 0))
        p2 = -F.max_pool2d(-img, (1, 3), (1, 1), (0, 1))
        return torch.min(p1, p2)
    elif len(img.shape) == 5:
        p1 = -F.max_pool3d(-img, (3, 1, 1), (1, 1, 1), (1, 0, 0))
        p2 = -F.max_pool3d(-img, (1, 3, 1), (1, 1, 1), (0, 1, 0))
        p3 = -F.max_pool3d(-img, (1, 1, 3), (1, 1, 1), (0, 0, 1))
        return torch.min(torch.min(p1, p2), p3)


def soft_dilate(img):
    if len(img.shape) == 4:
        return F.max_pool2d(img, (3, 3), (1, 1), (1, 1))
    elif len(img.shape) == 5:
        return F.max_pool3d(img, (3, 3, 3), (1, 1, 1), (1, 1, 1))


def soft_open(img):
    return soft_dilate(soft_erode(img))


def soft_skel(img, iter_):
    img1 = soft_open(img)
    skel = F.gelu(img - img1)
    for j in range(iter_):
        img = soft_erode(img)
        img1 = soft_open(img)
        delta = F.gelu(img - img1)
        skel = skel + F.gelu(delta - skel * delta)
    return skel


from skimage.morphology import skeletonize

def skel(img, iter_):
    img_tensor = img.detach().cpu().numpy()
    threshold = 0.5
    binary_image = (img_tensor > threshold).astype(np.uint8)
    skeletonized_tensor = torch.from_numpy(np.stack([skeletonize(im) for im in binary_image])).float().to('cuda:0')
    return skeletonized_tensor


class cldice(nn.Module):
    def __init__(self, iter_=3, alpha=0.5, smooth=1.):
        super(cldice, self).__init__()
        self.iter = iter_
        self.smooth = smooth
        self.alpha = alpha

    def forward(self, y_pred, y_true):
        skel_pred = skel(y_pred, self.iter)
        skel_true = skel(y_true, self.iter)
        tprec = (torch.sum(torch.multiply(skel_pred, y_true)) + self.smooth) / (
                    torch.sum(skel_pred) + self.smooth)
        tsens = (torch.sum(torch.multiply(skel_true, y_pred)) + self.smooth) / (
                    torch.sum(skel_true) + self.smooth)
        cl_dice = 1. - 2.0 * (tprec * tsens) / (tprec + tsens)
        return cl_dice

# %%
class persistence_loss(nn.Module):
    def __init__(self, dim=1, padding=2):
        super(persistence_loss, self).__init__()
        self.persistence_algo = CubicalComplex()
        self.loss_fn = WassersteinDistance(q=2)
        self.padding = padding

    def forward(self, y_pred, y_true):
        loss = 0.0
        batch_size = y_pred.size(0)
        y_pred_padded = F.pad(y_pred, (self.padding, self.padding, self.padding, self.padding), "constant", 1)
        y_true_padded = F.pad(y_true, (self.padding, self.padding, self.padding, self.padding), "constant", 1)
        for i in range(batch_size):
            pd_y_pred = self.persistence_algo(y_pred_padded[i])
            pd_y_pred = pd_y_pred[0]
            pd_y_true = self.persistence_algo(y_true_padded[i])[0]
            pd_y_true = pd_y_true[0]

            loss += self.loss_fn(pd_y_pred, pd_y_true)

        loss /= batch_size
        return loss

# %%
# Define loss and metrics
loss_1 = torch.nn.MSELoss(reduction="mean")
loss_2 = persistence_loss(dim=1)

# metrics = {"f1": torchmetrics.classification.F1Score(task='binary', num_classes=1, average="macro", mdmc_average="samplewise")}
metrics = {}

# %%
# Run training
train_history, val_history = training_loop(
    model=model,
    loss=[loss_1, loss_2],
    optimizer=optimizer,
    train_loader=train_loader,
    val_loader=test_loader,
    init_epoch=init_epoch,
    n_epochs=epochs,
    metrics_dict=metrics,
    save_path="model.ckpt",
    alpha=alpha
)
# Out:
# Epoch 1/200
#    -- Batch 1/22 / tensor(62.9433, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  4703.0835
#    -- Batch 2/22 / tensor(33.3561, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  176.84375
#    -- Batch 3/22 / tensor(43.0198, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  970.9716
#    -- Batch 4/22 / tensor(52.3539, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  951.18494
#    -- Batch 5/22 / tensor(54.4251, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  3154.5168
#    -- Batch 6/22 / tensor(44.2085, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  932.1889
#    -- Batch 7/22 / tensor(40.2031, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  419.17798
#    -- Batch 8/22 / tensor(56.3579, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  3418.408
#    -- Batch 9/22 / tensor(41.4425, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  416.89627
#    -- Batch 10/22 / tensor(42.7886, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1777.2833
#    -- Batch 11/22 / tensor(39.7616, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  492.0103
#    -- Batch 12/22 / tensor(40.4817, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  829.8593
#    -- Batch 13/22 / tensor(65.6942, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  5461.1523
#    -- Batch 14/22 / tensor(48.7553, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1369.811
#    -- Batch 15/22 / tensor(52.4588, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2321.8
#    -- Batch 16/22 / tensor(44.1362, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1714.5812
#    -- Batch 17/22 / tensor(40.4658, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  743.56305
#    -- Batch 18/22 / tensor(38.2064, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  444.47977
#    -- Batch 19/22 / tensor(76.0691, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  7025.0854
#    -- Batch 20/22 / tensor(45.1803, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1386.8885
#    -- Batch 21/22 / tensor(51.1469, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  912.72375
#    -- Batch 22/22 / tensor(43.1078, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  502.4373
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Streaming output truncated to the last 5000 lines.
#    Training:   {'loss': 794.3076}
#    Validation: {'loss': 2085.4848229795184}
# Epoch 99/200
#    -- Batch 1/22 / tensor(19.0231, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  59.835762
#    -- Batch 2/22 / tensor(43.5204, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  489.96335
#    -- Batch 3/22 / tensor(70.6026, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  3855.7842
#    -- Batch 4/22 / tensor(17.6955, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  111.66872
#    -- Batch 5/22 / tensor(45.6849, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1077.6875
#    -- Batch 6/22 / tensor(38.6110, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1027.6381
#    -- Batch 7/22 / tensor(39.4795, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  341.9679
#    -- Batch 8/22 / tensor(24.2062, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  59.974613
#    -- Batch 9/22 / tensor(23.8222, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  90.18725
#    -- Batch 10/22 / tensor(43.4360, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1054.8661
#    -- Batch 11/22 / tensor(52.4230, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1294.4854
#    -- Batch 12/22 / tensor(27.0839, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  110.928986
#    -- Batch 13/22 / tensor(61.3392, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2177.0098
#    -- Batch 14/22 / tensor(28.0479, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  116.31038
#    -- Batch 15/22 / tensor(23.5017, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  114.237236
#    -- Batch 16/22 / tensor(15.6927, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  104.21327
#    -- Batch 17/22 / tensor(61.9993, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2317.9387
#    -- Batch 18/22 / tensor(23.6996, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  111.846436
#    -- Batch 19/22 / tensor(54.9708, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1407.8508
#    -- Batch 20/22 / tensor(62.9272, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1390.858
#    -- Batch 21/22 / tensor(19.6539, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  54.850018
#    -- Batch 22/22 / tensor(104.7216, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  8639.214
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1182.2417}
#    Validation: {'loss': 2298.035949450084}
# Epoch 100/200
#    -- Batch 1/22 / tensor(51.4069, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1538.6129
#    -- Batch 2/22 / tensor(26.6130, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  210.0612
#    -- Batch 3/22 / tensor(23.3534, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  101.46323
#    -- Batch 4/22 / tensor(16.6283, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  50.81598
#    -- Batch 5/22 / tensor(47.1276, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  359.53317
#    -- Batch 6/22 / tensor(24.8356, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  83.69715
#    -- Batch 7/22 / tensor(27.1778, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  139.30475
#    -- Batch 8/22 / tensor(24.8631, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  243.00267
#    -- Batch 9/22 / tensor(63.5242, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2581.1694
#    -- Batch 10/22 / tensor(59.0989, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  903.3649
#    -- Batch 11/22 / tensor(14.7312, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  71.31249
#    -- Batch 12/22 / tensor(51.1573, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1463.4517
#    -- Batch 13/22 / tensor(32.2764, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  186.32663
#    -- Batch 14/22 / tensor(38.4504, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  559.4558
#    -- Batch 15/22 / tensor(62.0192, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2186.6409
#    -- Batch 16/22 / tensor(65.4982, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  3026.444
#    -- Batch 17/22 / tensor(57.5227, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1748.7148
#    -- Batch 18/22 / tensor(45.7755, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  690.76184
#    -- Batch 19/22 / tensor(33.2970, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  392.84955
#    -- Batch 20/22 / tensor(33.7017, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  183.36316
#    -- Batch 21/22 / tensor(46.7275, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  694.5067
#    -- Batch 22/22 / tensor(41.7990, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  218.29735
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 801.5068}
#    Validation: {'loss': 1490.5473243032186}
# Epoch 101/200
#    -- Batch 1/22 / tensor(29.8109, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  121.08265
#    -- Batch 2/22 / tensor(22.3919, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  79.4903
#    -- Batch 3/22 / tensor(18.6594, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  40.354675
#    -- Batch 4/22 / tensor(30.2821, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  225.78218
#    -- Batch 5/22 / tensor(27.1348, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  91.49635
#    -- Batch 6/22 / tensor(57.9846, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1568.7545
#    -- Batch 7/22 / tensor(45.0864, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  711.8855
#    -- Batch 8/22 / tensor(47.7006, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  700.4178
#    -- Batch 9/22 / tensor(47.6023, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  470.13306
#    -- Batch 10/22 / tensor(62.9255, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  3152.3706
#    -- Batch 11/22 / tensor(55.5369, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1394.6865
#    -- Batch 12/22 / tensor(43.0319, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  217.64719
#    -- Batch 13/22 / tensor(74.6120, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  3677.236
#    -- Batch 14/22 / tensor(31.2484, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  226.02824
#    -- Batch 15/22 / tensor(61.9234, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2994.5186
#    -- Batch 16/22 / tensor(18.8885, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  51.50635
#    -- Batch 17/22 / tensor(15.0358, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  44.496468
#    -- Batch 18/22 / tensor(53.7040, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  652.04486
#    -- Batch 19/22 / tensor(21.5257, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  70.19023
#    -- Batch 20/22 / tensor(18.5749, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  98.294624
#    -- Batch 21/22 / tensor(23.1503, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  141.59193
#    -- Batch 22/22 / tensor(51.6858, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  354.2365
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 776.5566}
#    Validation: {'loss': 1718.6162339829036}
# Epoch 102/200
#    -- Batch 1/22 / tensor(43.8463, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  498.97705
#    -- Batch 2/22 / tensor(44.1143, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  452.29263
#    -- Batch 3/22 / tensor(52.1923, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  858.7898
#    -- Batch 4/22 / tensor(12.1982, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  30.14017
#    -- Batch 5/22 / tensor(57.6952, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1655.7626
#    -- Batch 6/22 / tensor(29.5665, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  108.80072
#    -- Batch 7/22 / tensor(17.2834, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  88.37489
#    -- Batch 8/22 / tensor(37.7742, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  318.9447
#    -- Batch 9/22 / tensor(30.2113, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  188.05995
#    -- Batch 10/22 / tensor(42.7090, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  504.2785
#    -- Batch 11/22 / tensor(39.3167, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  249.04001
#    -- Batch 12/22 / tensor(64.6659, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2066.8882
#    -- Batch 13/22 / tensor(19.4441, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  195.89503
#    -- Batch 14/22 / tensor(21.2060, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  74.11422
#    -- Batch 15/22 / tensor(29.2653, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  180.52446
#    -- Batch 16/22 / tensor(61.4210, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  3016.2083
#    -- Batch 17/22 / tensor(59.4239, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1704.6488
#    -- Batch 18/22 / tensor(46.4818, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1069.1493
#    -- Batch 19/22 / tensor(61.2949, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1970.4702
#    -- Batch 20/22 / tensor(61.8676, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2625.7795
#    -- Batch 21/22 / tensor(25.3666, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  132.38948
#    -- Batch 22/22 / tensor(54.3299, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  298.6134
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 831.2791}
#    Validation: {'loss': 1871.471774990354}
# Epoch 103/200
#    -- Batch 1/22 / tensor(49.6309, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1072.7236
#    -- Batch 2/22 / tensor(40.8300, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  496.66623
#    -- Batch 3/22 / tensor(18.1410, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  84.92667
#    -- Batch 4/22 / tensor(47.6583, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1020.2418
#    -- Batch 5/22 / tensor(26.1610, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  117.46472
#    -- Batch 6/22 / tensor(39.2523, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  454.81705
#    -- Batch 7/22 / tensor(54.0079, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1138.3846
#    -- Batch 8/22 / tensor(49.8139, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1123.5582
#    -- Batch 9/22 / tensor(52.3485, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1159.4333
#    -- Batch 10/22 / tensor(44.3254, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  356.19528
#    -- Batch 11/22 / tensor(58.8917, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1739.5142
#    -- Batch 12/22 / tensor(61.8911, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1905.4587
#    -- Batch 13/22 / tensor(48.0519, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  652.5553
#    -- Batch 14/22 / tensor(16.4308, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  54.67498
#    -- Batch 15/22 / tensor(49.2389, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  629.2677
#    -- Batch 16/22 / tensor(31.1329, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  182.7323
#    -- Batch 17/22 / tensor(30.6522, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  197.1118
#    -- Batch 18/22 / tensor(47.8198, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  994.3
#    -- Batch 19/22 / tensor(17.5816, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  80.768166
#    -- Batch 20/22 / tensor(59.8967, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2024.5134
#    -- Batch 21/22 / tensor(53.9919, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1123.8296
#    -- Batch 22/22 / tensor(59.7622, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1424.9299
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 819.7304}
#    Validation: {'loss': 2133.376030515943}
# Epoch 104/200
#    -- Batch 1/22 / tensor(54.9396, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1299.0121
#    -- Batch 2/22 / tensor(18.4701, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  49.587864
#    -- Batch 3/22 / tensor(16.1714, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  34.747734
#    -- Batch 4/22 / tensor(22.5718, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  69.08422
#    -- Batch 5/22 / tensor(18.1509, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  34.781914
#    -- Batch 6/22 / tensor(23.9755, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  144.27576
#    -- Batch 7/22 / tensor(15.6788, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  60.223373
#    -- Batch 8/22 / tensor(49.6055, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1352.9166
#    -- Batch 9/22 / tensor(65.5306, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2024.1749
#    -- Batch 10/22 / tensor(44.2788, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  976.23553
#    -- Batch 11/22 / tensor(61.8641, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2212.6094
#    -- Batch 12/22 / tensor(27.4983, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  176.1351
#    -- Batch 13/22 / tensor(27.3722, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  151.17719
#    -- Batch 14/22 / tensor(63.6054, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2547.3604
#    -- Batch 15/22 / tensor(42.4691, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  351.38367
#    -- Batch 16/22 / tensor(19.6619, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  60.30091
#    -- Batch 17/22 / tensor(34.9310, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  242.71892
#    -- Batch 18/22 / tensor(50.5503, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1098.559
#    -- Batch 19/22 / tensor(46.8264, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1037.2955
#    -- Batch 20/22 / tensor(53.6278, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1261.4564
#    -- Batch 21/22 / tensor(43.6584, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  285.59998
#    -- Batch 22/22 / tensor(104.1252, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  8266.271
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1078.9048}
#    Validation: {'loss': 2281.951293999808}
# Epoch 105/200
#    -- Batch 1/22 / tensor(33.5123, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  218.47981
#    -- Batch 2/22 / tensor(15.8866, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  51.43588
#    -- Batch 3/22 / tensor(18.7274, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  101.61737
#    -- Batch 4/22 / tensor(61.4384, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1956.4104
#    -- Batch 5/22 / tensor(51.6238, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1049.077
#    -- Batch 6/22 / tensor(52.7705, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1211.7251
#    -- Batch 7/22 / tensor(37.2677, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  442.4247
#    -- Batch 8/22 / tensor(36.9964, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  603.3285
#    -- Batch 9/22 / tensor(18.2869, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  104.03888
#    -- Batch 10/22 / tensor(32.9459, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  172.62103
#    -- Batch 11/22 / tensor(42.6496, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  219.26254
#    -- Batch 12/22 / tensor(28.6002, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  224.05151
#    -- Batch 13/22 / tensor(25.8403, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  105.73179
#    -- Batch 14/22 / tensor(27.1412, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  164.26666
#    -- Batch 15/22 / tensor(52.2933, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1363.8384
#    -- Batch 16/22 / tensor(54.0687, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1372.7988
#    -- Batch 17/22 / tensor(22.9771, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  122.208824
#    -- Batch 18/22 / tensor(36.1246, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  208.33192
#    -- Batch 19/22 / tensor(52.0558, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1020.58844
#    -- Batch 20/22 / tensor(40.5210, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  337.0896
#    -- Batch 21/22 / tensor(38.7696, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  355.23596
#    -- Batch 22/22 / tensor(42.1540, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  181.25818
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 526.6283}
#    Validation: {'loss': 2264.7886714106967}
# Epoch 106/200
#    -- Batch 1/22 / tensor(42.8505, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  951.37054
#    -- Batch 2/22 / tensor(47.1906, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1002.25885
#    -- Batch 3/22 / tensor(34.7134, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  291.86255
#    -- Batch 4/22 / tensor(35.7388, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  314.08038
#    -- Batch 5/22 / tensor(54.6274, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1175.5653
#    -- Batch 6/22 / tensor(26.6493, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  126.3627
#    -- Batch 7/22 / tensor(21.2049, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  67.90488
#    -- Batch 8/22 / tensor(30.5348, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  196.72327
#    -- Batch 9/22 / tensor(55.0401, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1451.7659
#    -- Batch 10/22 / tensor(62.7769, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1637.7574
#    -- Batch 11/22 / tensor(36.6639, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  428.44412
#    -- Batch 12/22 / tensor(20.5573, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  86.18651
#    -- Batch 13/22 / tensor(16.0053, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  39.93297
#    -- Batch 14/22 / tensor(17.2519, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  51.079937
#    -- Batch 15/22 / tensor(39.5674, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  640.77545
#    -- Batch 16/22 / tensor(33.1230, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  260.28522
#    -- Batch 17/22 / tensor(29.2623, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  177.93962
#    -- Batch 18/22 / tensor(17.3504, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  48.034065
#    -- Batch 19/22 / tensor(19.7051, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  77.13696
#    -- Batch 20/22 / tensor(19.1543, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  52.859634
#    -- Batch 21/22 / tensor(60.6004, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1821.7654
#    -- Batch 22/22 / tensor(31.0386, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  174.14377
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 503.37433}
#    Validation: {'loss': 2043.0747482411525}
# Epoch 107/200
#    -- Batch 1/22 / tensor(32.6935, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  246.61513
#    -- Batch 2/22 / tensor(45.0614, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  532.2756
#    -- Batch 3/22 / tensor(42.9718, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  295.77548
#    -- Batch 4/22 / tensor(46.8565, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1054.3624
#    -- Batch 5/22 / tensor(58.6597, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1241.525
#    -- Batch 6/22 / tensor(40.7186, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  535.9627
#    -- Batch 7/22 / tensor(49.3332, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1120.7238
#    -- Batch 8/22 / tensor(43.1455, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  381.44467
#    -- Batch 9/22 / tensor(67.0226, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2915.2031
#    -- Batch 10/22 / tensor(36.3304, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  256.35764
#    -- Batch 11/22 / tensor(44.2298, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1026.1266
#    -- Batch 12/22 / tensor(45.0129, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  613.0137
#    -- Batch 13/22 / tensor(46.2296, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1113.5056
#    -- Batch 14/22 / tensor(45.7617, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  658.11255
#    -- Batch 15/22 / tensor(58.0294, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1435.2743
#    -- Batch 16/22 / tensor(25.7307, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  220.90144
#    -- Batch 17/22 / tensor(30.4632, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  153.31459
#    -- Batch 18/22 / tensor(36.8597, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  197.93175
#    -- Batch 19/22 / tensor(40.8399, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  497.8249
#    -- Batch 20/22 / tensor(21.5342, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  85.4924
#    -- Batch 21/22 / tensor(17.4960, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  53.347275
#    -- Batch 22/22 / tensor(40.8740, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  275.41425
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 677.75024}
#    Validation: {'loss': 2032.4998480475288}
# Epoch 108/200
#    -- Batch 1/22 / tensor(48.8649, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1031.3269
#    -- Batch 2/22 / tensor(34.0777, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  277.3765
#    -- Batch 3/22 / tensor(44.5955, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  450.0364
#    -- Batch 4/22 / tensor(62.9728, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2986.2334
#    -- Batch 5/22 / tensor(57.3683, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1465.468
#    -- Batch 6/22 / tensor(46.2316, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  448.06784
#    -- Batch 7/22 / tensor(39.3616, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  302.97513
#    -- Batch 8/22 / tensor(37.2958, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  279.60422
#    -- Batch 9/22 / tensor(45.9639, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  696.31525
#    -- Batch 10/22 / tensor(32.5325, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  203.57532
#    -- Batch 11/22 / tensor(62.8078, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1849.5851
#    -- Batch 12/22 / tensor(29.8345, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  302.8235
#    -- Batch 13/22 / tensor(21.4365, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  76.441505
#    -- Batch 14/22 / tensor(24.7969, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  114.41921
#    -- Batch 15/22 / tensor(47.8413, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  505.05255
#    -- Batch 16/22 / tensor(18.3320, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  54.178757
#    -- Batch 17/22 / tensor(42.7145, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  476.5401
#    -- Batch 18/22 / tensor(54.1235, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1174.7506
#    -- Batch 19/22 / tensor(29.5356, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  194.77332
#    -- Batch 20/22 / tensor(33.9879, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  260.2517
#    -- Batch 21/22 / tensor(34.2388, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  279.5763
#    -- Batch 22/22 / tensor(98.4679, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  8533.387
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 998.3072}
#    Validation: {'loss': 1888.0841990424565}
# Epoch 109/200
#    -- Batch 1/22 / tensor(29.4282, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  125.53625
#    -- Batch 2/22 / tensor(19.8887, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  53.164696
#    -- Batch 3/22 / tensor(42.1550, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  937.14886
#    -- Batch 4/22 / tensor(22.7592, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  59.890636
#    -- Batch 5/22 / tensor(31.2915, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  146.75119
#    -- Batch 6/22 / tensor(53.4659, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1305.4443
#    -- Batch 7/22 / tensor(33.2057, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  135.79494
#    -- Batch 8/22 / tensor(18.1308, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  62.003048
#    -- Batch 9/22 / tensor(40.6399, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  550.62463
#    -- Batch 10/22 / tensor(62.5569, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1986.827
#    -- Batch 11/22 / tensor(14.5939, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  37.410286
#    -- Batch 12/22 / tensor(19.6600, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  68.51381
#    -- Batch 13/22 / tensor(22.6155, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  98.88355
#    -- Batch 14/22 / tensor(21.2000, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  87.657776
#    -- Batch 15/22 / tensor(18.3954, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  53.18087
#    -- Batch 16/22 / tensor(26.2876, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  99.59821
#    -- Batch 17/22 / tensor(15.8159, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  103.32228
#    -- Batch 18/22 / tensor(26.5419, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  164.3524
#    -- Batch 19/22 / tensor(20.0956, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  61.719193
#    -- Batch 20/22 / tensor(47.6148, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1007.0328
#    -- Batch 21/22 / tensor(16.4747, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  40.70778
#    -- Batch 22/22 / tensor(46.7113, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  199.12772
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 335.66785}
#    Validation: {'loss': 1785.5162929303306}
# Epoch 110/200
#    -- Batch 1/22 / tensor(20.3218, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  93.33144
#    -- Batch 2/22 / tensor(55.6767, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1539.2678
#    -- Batch 3/22 / tensor(16.1419, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  59.32063
#    -- Batch 4/22 / tensor(65.6042, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2004.3759
#    -- Batch 5/22 / tensor(75.5607, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  3586.532
#    -- Batch 6/22 / tensor(62.3976, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1835.4547
#    -- Batch 7/22 / tensor(28.7746, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  152.76555
#    -- Batch 8/22 / tensor(25.2397, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  108.852646
#    -- Batch 9/22 / tensor(18.7359, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  112.79705
#    -- Batch 10/22 / tensor(20.4911, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  55.77375
#    -- Batch 11/22 / tensor(35.2550, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  539.3461
#    -- Batch 12/22 / tensor(16.9487, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  56.68838
#    -- Batch 13/22 / tensor(29.2771, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  237.76845
#    -- Batch 14/22 / tensor(20.6109, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  80.329575
#    -- Batch 15/22 / tensor(27.3881, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  171.65111
#    -- Batch 16/22 / tensor(37.9419, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  261.3306
#    -- Batch 17/22 / tensor(21.1246, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  55.657154
#    -- Batch 18/22 / tensor(47.9096, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  695.72064
#    -- Batch 19/22 / tensor(17.7262, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  39.23511
#    -- Batch 20/22 / tensor(27.6554, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  70.63504
#    -- Batch 21/22 / tensor(27.0239, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  142.25362
#    -- Batch 22/22 / tensor(105.7128, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  8234.96
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 915.18396}
#    Validation: {'loss': 1685.91979772595}
# Epoch 111/200
#    -- Batch 1/22 / tensor(43.0225, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  377.7251
#    -- Batch 2/22 / tensor(67.9880, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2844.121
#    -- Batch 3/22 / tensor(15.8659, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  30.958157
#    -- Batch 4/22 / tensor(23.0151, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  68.145065
#    -- Batch 5/22 / tensor(15.9462, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  42.011375
#    -- Batch 6/22 / tensor(66.9455, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1154.3745
#    -- Batch 7/22 / tensor(24.8624, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  194.72337
#    -- Batch 8/22 / tensor(14.6213, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  68.755394
#    -- Batch 9/22 / tensor(32.4654, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  156.74397
#    -- Batch 10/22 / tensor(72.0900, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  3344.2812
#    -- Batch 11/22 / tensor(46.1541, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  770.10846
#    -- Batch 12/22 / tensor(28.2696, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  292.15894
#    -- Batch 13/22 / tensor(23.5909, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  267.87573
#    -- Batch 14/22 / tensor(37.8256, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  355.81656
#    -- Batch 15/22 / tensor(46.6988, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  595.93475
#    -- Batch 16/22 / tensor(17.2862, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  40.1265
#    -- Batch 17/22 / tensor(35.4709, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  245.63817
#    -- Batch 18/22 / tensor(16.4714, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  50.41538
#    -- Batch 19/22 / tensor(29.9940, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  159.01395
#    -- Batch 20/22 / tensor(41.4883, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  961.7247
#    -- Batch 21/22 / tensor(68.7282, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  3112.7732
#    -- Batch 22/22 / tensor(44.8446, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  207.97697
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 697.3364}
#    Validation: {'loss': 1784.6269829030718}
# Epoch 112/200
#    -- Batch 1/22 / tensor(70.5564, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  3108.6047
#    -- Batch 2/22 / tensor(34.5729, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  262.68182
#    -- Batch 3/22 / tensor(21.6329, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  116.37096
#    -- Batch 4/22 / tensor(25.5856, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  130.49745
#    -- Batch 5/22 / tensor(28.5479, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  215.1327
#    -- Batch 6/22 / tensor(49.5962, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  750.9219
#    -- Batch 7/22 / tensor(66.7888, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1753.2942
#    -- Batch 8/22 / tensor(75.5865, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  3982.304
#    -- Batch 9/22 / tensor(63.8117, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1478.7235
#    -- Batch 10/22 / tensor(20.5195, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  98.62201
#    -- Batch 11/22 / tensor(59.3292, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2074.8486
#    -- Batch 12/22 / tensor(43.3409, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  924.0507
#    -- Batch 13/22 / tensor(32.3477, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  209.08781
#    -- Batch 14/22 / tensor(51.0187, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1630.0431
#    -- Batch 15/22 / tensor(51.2015, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1472.3335
#    -- Batch 16/22 / tensor(32.9562, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  207.38383
#    -- Batch 17/22 / tensor(84.3569, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  5027.964
#    -- Batch 18/22 / tensor(72.0177, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2224.6248
#    -- Batch 19/22 / tensor(38.0044, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  779.1316
#    -- Batch 20/22 / tensor(67.4264, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2367.281
#    -- Batch 21/22 / tensor(34.3122, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  278.80078
#    -- Batch 22/22 / tensor(62.3411, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  670.0603
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1352.8528}
#    Validation: {'loss': 1014.1907521283285}
# Epoch 113/200
#    -- Batch 1/22 / tensor(18.0250, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  50.531864
#    -- Batch 2/22 / tensor(48.2720, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  964.3089
#    -- Batch 3/22 / tensor(59.3349, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1412.3562
#    -- Batch 4/22 / tensor(31.1319, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  162.81142
#    -- Batch 5/22 / tensor(61.3687, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1866.1769
#    -- Batch 6/22 / tensor(67.9552, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2309.1145
#    -- Batch 7/22 / tensor(49.7429, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  487.71884
#    -- Batch 8/22 / tensor(21.1306, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  132.84238
#    -- Batch 9/22 / tensor(50.3644, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  669.9123
#    -- Batch 10/22 / tensor(24.7748, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  79.10659
#    -- Batch 11/22 / tensor(47.6507, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  958.8403
#    -- Batch 12/22 / tensor(21.4013, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  84.74201
#    -- Batch 13/22 / tensor(45.0364, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  414.28543
#    -- Batch 14/22 / tensor(22.4117, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  73.18289
#    -- Batch 15/22 / tensor(18.6537, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  84.74342
#    -- Batch 16/22 / tensor(14.6927, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  42.062557
#    -- Batch 17/22 / tensor(33.4594, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  294.31015
#    -- Batch 18/22 / tensor(19.6682, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  86.8657
#    -- Batch 19/22 / tensor(25.7205, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  221.54723
#    -- Batch 20/22 / tensor(59.8004, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2367.0571
#    -- Batch 21/22 / tensor(19.3326, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  49.107525
#    -- Batch 22/22 / tensor(48.6925, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  210.23062
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 591.9024}
#    Validation: {'loss': 2016.038110046114}
# Epoch 114/200
#    -- Batch 1/22 / tensor(21.3052, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  74.28322
#    -- Batch 2/22 / tensor(25.7747, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  193.04445
#    -- Batch 3/22 / tensor(19.1847, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  80.07527
#    -- Batch 4/22 / tensor(17.5575, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  66.47565
#    -- Batch 5/22 / tensor(61.4968, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2131.395
#    -- Batch 6/22 / tensor(34.4747, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  167.12178
#    -- Batch 7/22 / tensor(18.5231, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  64.731346
#    -- Batch 8/22 / tensor(18.9203, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  101.57185
#    -- Batch 9/22 / tensor(32.7174, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  210.70412
#    -- Batch 10/22 / tensor(47.4512, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1099.5547
#    -- Batch 11/22 / tensor(20.1781, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  61.57837
#    -- Batch 12/22 / tensor(14.7598, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  52.967247
#    -- Batch 13/22 / tensor(19.1972, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  50.93042
#    -- Batch 14/22 / tensor(21.4298, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  38.24926
#    -- Batch 15/22 / tensor(52.3692, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1196.7755
#    -- Batch 16/22 / tensor(36.3684, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  296.4371
#    -- Batch 17/22 / tensor(44.5937, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1411.2466
#    -- Batch 18/22 / tensor(19.8071, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  55.89239
#    -- Batch 19/22 / tensor(40.4319, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  886.6084
#    -- Batch 20/22 / tensor(68.5742, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1967.2903
#    -- Batch 21/22 / tensor(54.2530, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1599.7362
#    -- Batch 22/22 / tensor(38.1800, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  546.32574
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 561.49976}
#    Validation: {'loss': 778.9135018610273}
# Epoch 115/200
#    -- Batch 1/22 / tensor(77.9988, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  3844.1975
#    -- Batch 2/22 / tensor(42.9767, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  467.98764
#    -- Batch 3/22 / tensor(13.9111, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  104.9731
#    -- Batch 4/22 / tensor(30.4673, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  143.32362
#    -- Batch 5/22 / tensor(19.3399, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  88.84357
#    -- Batch 6/22 / tensor(42.3718, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  317.00842
#    -- Batch 7/22 / tensor(19.3802, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  49.513115
#    -- Batch 8/22 / tensor(65.7075, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2209.542
#    -- Batch 9/22 / tensor(42.0852, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  598.01086
#    -- Batch 10/22 / tensor(33.5899, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  204.21036
#    -- Batch 11/22 / tensor(38.6826, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  283.5368
#    -- Batch 12/22 / tensor(18.3168, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  71.593544
#    -- Batch 13/22 / tensor(16.9646, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  89.94349
#    -- Batch 14/22 / tensor(39.0455, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  263.71585
#    -- Batch 15/22 / tensor(67.2696, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  3095.8604
#    -- Batch 16/22 / tensor(32.8931, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  390.0602
#    -- Batch 17/22 / tensor(70.9299, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  3235.582
#    -- Batch 18/22 / tensor(36.8182, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  217.15207
#    -- Batch 19/22 / tensor(42.1812, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  430.61948
#    -- Batch 20/22 / tensor(25.3533, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  123.90225
#    -- Batch 21/22 / tensor(35.7065, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  303.52148
#    -- Batch 22/22 / tensor(50.0360, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  212.22272
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 761.15094}
#    Validation: {'loss': 1666.5328373960765}
# Epoch 116/200
#    -- Batch 1/22 / tensor(34.7303, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  850.41394
#    -- Batch 2/22 / tensor(43.5960, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  560.8394
#    -- Batch 3/22 / tensor(45.5700, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  972.26215
#    -- Batch 4/22 / tensor(18.1537, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  57.62574
#    -- Batch 5/22 / tensor(18.8115, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  71.75659
#    -- Batch 6/22 / tensor(22.4481, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  183.04128
#    -- Batch 7/22 / tensor(50.3713, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  990.4898
#    -- Batch 8/22 / tensor(22.5187, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  163.65155
#    -- Batch 9/22 / tensor(16.0657, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  45.865833
#    -- Batch 10/22 / tensor(48.0860, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1089.9727
#    -- Batch 11/22 / tensor(32.9961, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  194.2437
#    -- Batch 12/22 / tensor(43.3708, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  553.2675
#    -- Batch 13/22 / tensor(30.0181, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  365.26364
#    -- Batch 14/22 / tensor(38.3991, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  879.152
#    -- Batch 15/22 / tensor(56.6037, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1328.5237
#    -- Batch 16/22 / tensor(64.7072, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1320.4923
#    -- Batch 17/22 / tensor(21.0412, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  73.42134
#    -- Batch 18/22 / tensor(24.3037, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  47.7141
#    -- Batch 19/22 / tensor(47.3867, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  958.6098
#    -- Batch 20/22 / tensor(48.9632, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  945.8299
#    -- Batch 21/22 / tensor(52.9563, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  765.392
#    -- Batch 22/22 / tensor(56.2579, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  214.09935
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 574.17847}
#    Validation: {'loss': 1383.4502686805724}
# Epoch 117/200
#    -- Batch 1/22 / tensor(62.7259, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1419.4106
#    -- Batch 2/22 / tensor(21.8919, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  122.7325
#    -- Batch 3/22 / tensor(69.9338, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2010.5782
#    -- Batch 4/22 / tensor(41.5333, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  566.24603
#    -- Batch 5/22 / tensor(54.2857, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1151.5582
#    -- Batch 6/22 / tensor(49.4076, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  578.57544
#    -- Batch 7/22 / tensor(32.5011, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  166.52098
#    -- Batch 8/22 / tensor(35.3039, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  227.51698
#    -- Batch 9/22 / tensor(33.2264, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  166.69078
#    -- Batch 10/22 / tensor(16.5664, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  34.403896
#    -- Batch 11/22 / tensor(30.4397, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  134.22626
#    -- Batch 12/22 / tensor(57.5635, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1234.4003
#    -- Batch 13/22 / tensor(44.6505, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  396.97733
#    -- Batch 14/22 / tensor(20.8834, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  67.795715
#    -- Batch 15/22 / tensor(25.4187, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  146.8867
#    -- Batch 16/22 / tensor(58.0121, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1367.2821
#    -- Batch 17/22 / tensor(18.4288, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  47.927044
#    -- Batch 18/22 / tensor(52.4048, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  999.03766
#    -- Batch 19/22 / tensor(20.6077, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  78.48871
#    -- Batch 20/22 / tensor(27.7648, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  332.35184
#    -- Batch 21/22 / tensor(40.0287, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  850.1043
#    -- Batch 22/22 / tensor(61.0635, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  306.08188
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 563.89966}
#    Validation: {'loss': 2361.797398541042}
# Epoch 118/200
#    -- Batch 1/22 / tensor(43.2790, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  231.67911
#    -- Batch 2/22 / tensor(36.5800, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  314.25803
#    -- Batch 3/22 / tensor(19.7482, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  74.6716
#    -- Batch 4/22 / tensor(27.0715, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  118.90693
#    -- Batch 5/22 / tensor(72.4373, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2997.8926
#    -- Batch 6/22 / tensor(26.0562, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  99.76086
#    -- Batch 7/22 / tensor(61.9262, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1434.5087
#    -- Batch 8/22 / tensor(27.1567, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  241.0793
#    -- Batch 9/22 / tensor(35.9559, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  200.17592
#    -- Batch 10/22 / tensor(18.1030, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  55.909508
#    -- Batch 11/22 / tensor(24.9504, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  177.7693
#    -- Batch 12/22 / tensor(53.6359, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1183.6353
#    -- Batch 13/22 / tensor(29.6403, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  202.5479
#    -- Batch 14/22 / tensor(58.0868, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1541.6718
#    -- Batch 15/22 / tensor(31.4898, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  190.17758
#    -- Batch 16/22 / tensor(60.2471, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1778.4418
#    -- Batch 17/22 / tensor(19.0987, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  68.38583
#    -- Batch 18/22 / tensor(64.2998, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2228.0938
#    -- Batch 19/22 / tensor(65.6117, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1990.0912
#    -- Batch 20/22 / tensor(38.0714, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  206.6526
#    -- Batch 21/22 / tensor(33.2344, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  204.21774
#    -- Batch 22/22 / tensor(15.2895, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  19.742971
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 707.285}
#    Validation: {'loss': 578.6938517545973}
# Epoch 119/200
#    -- Batch 1/22 / tensor(40.2128, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  842.36414
#    -- Batch 2/22 / tensor(55.8093, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1064.411
#    -- Batch 3/22 / tensor(15.1587, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  45.21899
#    -- Batch 4/22 / tensor(53.6654, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1247.0115
#    -- Batch 5/22 / tensor(50.5911, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1006.31134
#    -- Batch 6/22 / tensor(47.6483, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1131.5104
#    -- Batch 7/22 / tensor(17.4108, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  40.65381
#    -- Batch 8/22 / tensor(30.3985, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  198.17123
#    -- Batch 9/22 / tensor(17.3558, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  40.418427
#    -- Batch 10/22 / tensor(35.8598, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  452.32806
#    -- Batch 11/22 / tensor(55.0054, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1022.1304
#    -- Batch 12/22 / tensor(23.9674, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  156.79756
#    -- Batch 13/22 / tensor(47.5094, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  646.7402
#    -- Batch 14/22 / tensor(13.2680, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  59.538033
#    -- Batch 15/22 / tensor(57.0167, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1607.1045
#    -- Batch 16/22 / tensor(56.6673, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  828.29517
# ...
# Loss:  55.310143
#    -- Batch 18/22 / tensor(21.1675, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  86.927795
#    -- Batch 19/22 / tensor(18.6869, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  47.187725
#    -- Batch 20/22 / tensor(26.3213, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  130.81747
#    -- Batch 21/22 / tensor(42.1686, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  704.84595
#    -- Batch 22/22 / tensor(21.3944, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  299.84827
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 257.5452}
#    Validation: {'loss': 1467.356237551008}
# Epoch 194/200
#    -- Batch 1/22 / tensor(59.4653, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  968.4151
#    -- Batch 2/22 / tensor(20.0163, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  73.48221
#    -- Batch 3/22 / tensor(20.8402, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  54.15168
#    -- Batch 4/22 / tensor(22.5299, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  79.067375
#    -- Batch 5/22 / tensor(31.4857, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  484.4684
#    -- Batch 6/22 / tensor(26.9405, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  130.82684
#    -- Batch 7/22 / tensor(29.5815, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  434.2094
#    -- Batch 8/22 / tensor(32.0232, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  490.07742
#    -- Batch 9/22 / tensor(17.6031, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  50.427982
#    -- Batch 10/22 / tensor(52.5935, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1084.3062
#    -- Batch 11/22 / tensor(37.5928, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  368.2692
#    -- Batch 12/22 / tensor(12.9482, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  35.59133
#    -- Batch 13/22 / tensor(21.3097, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  118.37829
#    -- Batch 14/22 / tensor(23.2894, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  114.85843
#    -- Batch 15/22 / tensor(19.4354, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  63.11687
#    -- Batch 16/22 / tensor(14.6996, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  40.298885
#    -- Batch 17/22 / tensor(30.0184, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  452.21976
#    -- Batch 18/22 / tensor(43.6395, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  178.5517
#    -- Batch 19/22 / tensor(41.8830, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  177.7412
#    -- Batch 20/22 / tensor(41.3000, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  483.45227
#    -- Batch 21/22 / tensor(34.4310, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  422.9969
#    -- Batch 22/22 / tensor(31.4931, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  737.64166
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 320.11584}
#    Validation: {'loss': 1151.495378880637}
# Epoch 195/200
#    -- Batch 1/22 / tensor(33.9971, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  426.79907
#    -- Batch 2/22 / tensor(34.1217, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  409.34653
#    -- Batch 3/22 / tensor(16.2274, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  49.55801
#    -- Batch 4/22 / tensor(36.7856, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  432.47058
#    -- Batch 5/22 / tensor(43.2699, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  502.12808
#    -- Batch 6/22 / tensor(34.5360, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  390.76538
#    -- Batch 7/22 / tensor(24.3362, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  108.690254
#    -- Batch 8/22 / tensor(16.8235, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  55.656494
#    -- Batch 9/22 / tensor(14.9713, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  41.322556
#    -- Batch 10/22 / tensor(38.7472, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  758.7101
#    -- Batch 11/22 / tensor(16.2443, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  78.35687
#    -- Batch 12/22 / tensor(36.5900, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  436.5647
#    -- Batch 13/22 / tensor(26.2792, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  104.142975
#    -- Batch 14/22 / tensor(48.2621, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  354.29865
#    -- Batch 15/22 / tensor(26.0230, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  241.73004
#    -- Batch 16/22 / tensor(17.4932, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  59.435184
#    -- Batch 17/22 / tensor(61.4285, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1526.1782
#    -- Batch 18/22 / tensor(20.1875, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  162.11969
#    -- Batch 19/22 / tensor(39.3395, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  311.5519
#    -- Batch 20/22 / tensor(17.6944, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  79.22504
#    -- Batch 21/22 / tensor(25.8005, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  115.8959
#    -- Batch 22/22 / tensor(60.4560, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  646.10114
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 331.41125}
#    Validation: {'loss': 1693.6467779587338}
# Epoch 196/200
#    -- Batch 1/22 / tensor(21.3849, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  243.77794
#    -- Batch 2/22 / tensor(22.5655, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  80.24018
#    -- Batch 3/22 / tensor(37.2542, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  502.48138
#    -- Batch 4/22 / tensor(20.0493, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  61.584686
#    -- Batch 5/22 / tensor(21.3216, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  187.39473
#    -- Batch 6/22 / tensor(29.3974, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  115.35684
#    -- Batch 7/22 / tensor(38.3080, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  509.80783
#    -- Batch 8/22 / tensor(26.8937, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  114.22032
#    -- Batch 9/22 / tensor(52.0544, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  835.8755
#    -- Batch 10/22 / tensor(24.8987, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  113.3133
#    -- Batch 11/22 / tensor(37.8834, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  427.62488
#    -- Batch 12/22 / tensor(19.7464, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  79.38311
#    -- Batch 13/22 / tensor(23.8873, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  73.33022
#    -- Batch 14/22 / tensor(87.9472, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  4634.469
#    -- Batch 15/22 / tensor(49.8757, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  909.46344
#    -- Batch 16/22 / tensor(18.4401, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  46.518604
#    -- Batch 17/22 / tensor(25.1461, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  204.29729
#    -- Batch 18/22 / tensor(21.7675, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  120.51435
#    -- Batch 19/22 / tensor(34.3219, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  288.12927
#    -- Batch 20/22 / tensor(21.7049, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  55.503742
#    -- Batch 21/22 / tensor(14.7443, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  40.323345
#    -- Batch 22/22 / tensor(105.0412, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  5896.335
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 706.36115}
#    Validation: {'loss': 1745.0884152265273}
# Epoch 197/200
#    -- Batch 1/22 / tensor(32.3993, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  118.23724
#    -- Batch 2/22 / tensor(14.7496, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  36.823017
#    -- Batch 3/22 / tensor(55.3824, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1044.4443
#    -- Batch 4/22 / tensor(36.1596, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  607.39075
#    -- Batch 5/22 / tensor(22.1702, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  130.62561
#    -- Batch 6/22 / tensor(19.4411, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  88.56567
#    -- Batch 7/22 / tensor(19.5013, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  82.22861
#    -- Batch 8/22 / tensor(27.3413, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  204.26299
#    -- Batch 9/22 / tensor(12.9930, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  56.74138
#    -- Batch 10/22 / tensor(15.0934, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  72.77539
#    -- Batch 11/22 / tensor(13.6655, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  40.816673
#    -- Batch 12/22 / tensor(18.9766, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  47.91231
#    -- Batch 13/22 / tensor(10.4841, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  27.321451
#    -- Batch 14/22 / tensor(22.9487, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  131.91557
#    -- Batch 15/22 / tensor(14.8993, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  36.121174
#    -- Batch 16/22 / tensor(17.7929, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  172.91248
#    -- Batch 17/22 / tensor(48.5316, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  843.4708
#    -- Batch 18/22 / tensor(38.0720, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  490.26727
#    -- Batch 19/22 / tensor(38.5845, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  555.7934
#    -- Batch 20/22 / tensor(16.5014, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  67.24142
#    -- Batch 21/22 / tensor(13.7564, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  25.743504
#    -- Batch 22/22 / tensor(45.6350, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  618.53394
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 250.00658}
#    Validation: {'loss': 1997.764069314412}
# Epoch 198/200
#    -- Batch 1/22 / tensor(48.1841, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  267.7467
#    -- Batch 2/22 / tensor(45.0148, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  621.34515
#    -- Batch 3/22 / tensor(35.5575, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  536.4906
#    -- Batch 4/22 / tensor(17.4110, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  52.285393
#    -- Batch 5/22 / tensor(23.2121, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  262.43616
#    -- Batch 6/22 / tensor(58.7609, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1313.2859
#    -- Batch 7/22 / tensor(43.0389, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  217.15706
#    -- Batch 8/22 / tensor(28.0033, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  445.8365
#    -- Batch 9/22 / tensor(14.0032, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  66.062195
#    -- Batch 10/22 / tensor(16.3742, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  120.75455
#    -- Batch 11/22 / tensor(23.7018, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  104.756195
#    -- Batch 12/22 / tensor(28.7297, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  223.62314
#    -- Batch 13/22 / tensor(37.8996, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  764.0258
#    -- Batch 14/22 / tensor(27.0619, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  164.24974
#    -- Batch 15/22 / tensor(38.4118, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1185.8123
#    -- Batch 16/22 / tensor(46.4293, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  723.5142
#    -- Batch 17/22 / tensor(15.5193, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  51.87972
#    -- Batch 18/22 / tensor(18.9009, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  31.437685
#    -- Batch 19/22 / tensor(34.4771, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  223.52293
#    -- Batch 20/22 / tensor(22.3016, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  101.9869
#    -- Batch 21/22 / tensor(78.7076, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2881.095
#    -- Batch 22/22 / tensor(60.6219, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  486.14996
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 492.9752}
#    Validation: {'loss': 1633.8831178858618}
# Epoch 199/200
#    -- Batch 1/22 / tensor(33.4767, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  212.27422
#    -- Batch 2/22 / tensor(39.4637, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  171.44765
#    -- Batch 3/22 / tensor(17.2802, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  43.622005
#    -- Batch 4/22 / tensor(24.4433, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  244.73099
#    -- Batch 5/22 / tensor(46.4753, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  799.7746
#    -- Batch 6/22 / tensor(56.3461, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1011.3739
#    -- Batch 7/22 / tensor(16.7783, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  59.38395
#    -- Batch 8/22 / tensor(62.3887, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1615.8446
#    -- Batch 9/22 / tensor(38.5845, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  481.21344
#    -- Batch 10/22 / tensor(43.6526, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  692.97986
#    -- Batch 11/22 / tensor(31.5363, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  393.80762
#    -- Batch 12/22 / tensor(64.1027, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1845.5697
#    -- Batch 13/22 / tensor(32.2074, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  121.27622
#    -- Batch 14/22 / tensor(62.0620, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1795.701
#    -- Batch 15/22 / tensor(33.8569, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  311.09027
#    -- Batch 16/22 / tensor(42.5156, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  716.72925
#    -- Batch 17/22 / tensor(15.0628, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  287.2765
#    -- Batch 18/22 / tensor(20.7752, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  158.017
#    -- Batch 19/22 / tensor(48.6335, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  243.51392
#    -- Batch 20/22 / tensor(18.9083, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  120.35649
#    -- Batch 21/22 / tensor(13.0931, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  41.3228
#    -- Batch 22/22 / tensor(18.6189, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  149.58112
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 523.4949}
#    Validation: {'loss': 561.578019807543}
# Epoch 200/200
#    -- Batch 1/22 / tensor(21.2662, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  65.76987
#    -- Batch 2/22 / tensor(16.7273, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  52.701065
#    -- Batch 3/22 / tensor(47.3850, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  680.5314
#    -- Batch 4/22 / tensor(20.3589, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  111.14315
#    -- Batch 5/22 / tensor(32.1761, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  126.320625
#    -- Batch 6/22 / tensor(47.8005, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  847.41205
#    -- Batch 7/22 / tensor(18.0251, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  139.7618
#    -- Batch 8/22 / tensor(19.9705, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  91.40288
#    -- Batch 9/22 / tensor(29.7074, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  214.07603
#    -- Batch 10/22 / tensor(14.6999, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  87.45533
#    -- Batch 11/22 / tensor(23.4312, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  73.84401
#    -- Batch 12/22 / tensor(30.3949, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  299.2408
#    -- Batch 13/22 / tensor(22.8218, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  59.035297
#    -- Batch 14/22 / tensor(72.5717, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1987.2518
#    -- Batch 15/22 / tensor(21.2604, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  42.676365
#    -- Batch 16/22 / tensor(12.9944, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  33.518112
#    -- Batch 17/22 / tensor(67.9561, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  2348.3645
#    -- Batch 18/22 / tensor(18.8466, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  73.5179
#    -- Batch 19/22 / tensor(13.8548, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  31.659843
#    -- Batch 20/22 / tensor(21.5404, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  83.82205
#    -- Batch 21/22 / tensor(24.6496, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  80.748024
#    -- Batch 22/22 / tensor(39.8577, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  253.68254
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 353.81525}
#    Validation: {'loss': 927.8447158342088}

# %%
plot_histories(train_history['loss'], val_history['loss'], label="Loss")
# plot_histories(train_history=None, val_history=val_history['f1'], label="F1 Score")
plt.show()

# %%
def center_crop(image, crop_size):
    h, w = image.shape
    ch, cw = crop_size

    if ch > h or cw > w:
        raise ValueError("Crop size must be smaller than the image size")

    start_h = (h - ch) // 3
    start_w = (w - cw) // 3

    cropped_image = image[start_h:start_h+ch, start_w:start_w+cw]

    return cropped_image

# %%
# Select a test image
x = torch.from_numpy(center_crop(datasets[0][0], (128, 128))).unsqueeze(0).float()
y = torch.from_numpy(center_crop(gen_label(datasets[0][0], 2500), (128, 128))).unsqueeze(0).float()
pred = evaluate_model_on_single_image(model, x)

# Plot the result
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 15))
ax1.set_title("True mask")
ax2.set_title("Predicted mask")
plot_image_with_segmentation(x, y, ax=ax1, model='gray', sdf=False)
plot_image_with_segmentation(x, pred, ax=ax2, model='gray', sdf=False)
plt.show()

# %%
class SegmentationMetric(object):
    def __init__(self, numClass):
        self.numClass = numClass
        self.confusionMatrix = np.zeros((self.numClass,) * 2)  # 混淆矩阵（空）

    def pixelAccuracy(self):
        # return all class overall pixel accuracy 正确的像素占总像素的比例
        #  PA = acc = (TP + TN) / (TP + TN + FP + TN)
        acc = np.diag(self.confusionMatrix).sum() / self.confusionMatrix.sum()
        return acc

    def classPixelAccuracy(self):
        # return each category pixel accuracy(A more accurate way to call it precision)
        # acc = (TP) / TP + FP
        classAcc = np.diag(self.confusionMatrix) / self.confusionMatrix.sum(axis=1)
        return classAcc  # 返回的是一个列表值，如：[0.90, 0.80, 0.96]，表示类别1 2 3各类别的预测准确率

    def meanPixelAccuracy(self):
        """
        Mean Pixel Accuracy(MPA，均像素精度)：是PA的一种简单提升，计算每个类内被正确分类像素数的比例，之后求所有类的平均。
        :return:
        """
        classAcc = self.classPixelAccuracy()
        meanAcc = np.nanmean(classAcc)  # np.nanmean 求平均值，nan表示遇到Nan类型，其值取为0
        return meanAcc  # 返回单个值，如：np.nanmean([0.90, 0.80, 0.96, nan, nan]) = (0.90 + 0.80 + 0.96） / 3 =  0.89

    def IntersectionOverUnion(self):
        # Intersection = TP Union = TP + FP + FN
        # IoU = TP / (TP + FP + FN)
        intersection = np.diag(self.confusionMatrix)  # 取对角元素的值，返回列表
        union = np.sum(self.confusionMatrix, axis=1) + np.sum(self.confusionMatrix, axis=0) - np.diag(
            self.confusionMatrix)  # axis = 1表示混淆矩阵行的值，返回列表； axis = 0表示取混淆矩阵列的值，返回列表
        IoU = intersection / union  # 返回列表，其值为各个类别的IoU
        return IoU

    def meanIntersectionOverUnion(self):
        mIoU = np.nanmean(self.IntersectionOverUnion())  # 求各类别IoU的平均
        return mIoU

    def genConfusionMatrix(self, imgPredict, imgLabel):  #
        """
        同FCN中score.py的fast_hist()函数,计算混淆矩阵
        :param imgPredict:
        :param imgLabel:
        :return: 混淆矩阵
        """
        # remove classes from unlabeled pixels in gt image and predict
        mask = (imgLabel >= 0) & (imgLabel < self.numClass)
        label = self.numClass * imgLabel[mask] + imgPredict[mask]
        count = np.bincount(label, minlength=self.numClass ** 2)
        confusionMatrix = count.reshape(self.numClass, self.numClass)
        # print(confusionMatrix)
        return confusionMatrix

    def Frequency_Weighted_Intersection_over_Union(self):
        """
        FWIoU，频权交并比:为MIoU的一种提升，这种方法根据每个类出现的频率为其设置权重。
        FWIOU =     [(TP+FN)/(TP+FP+TN+FN)] *[TP / (TP + FP + FN)]
        """
        freq = np.sum(self.confusion_matrix, axis=1) / np.sum(self.confusion_matrix)
        iu = np.diag(self.confusion_matrix) / (
                np.sum(self.confusion_matrix, axis=1) + np.sum(self.confusion_matrix, axis=0) -
                np.diag(self.confusion_matrix))
        FWIoU = (freq[freq > 0] * iu[freq > 0]).sum()
        return FWIoU

    def addBatch(self, imgPredict, imgLabel):
        assert imgPredict.shape == imgLabel.shape
        self.confusionMatrix += self.genConfusionMatrix(imgPredict, imgLabel)  # 得到混淆矩阵
        return self.confusionMatrix

    def reset(self):
        self.confusionMatrix = np.zeros((self.numClass, self.numClass))

# %%
def meanSkeletonAccuracy(x, y):
    skel_x = soft_skel(x)
    skel_y = soft_skel(y)
    metric = SegmentationMetric(2)
    hist = metric.addBatch(skel_x, skel_y)

    return metric.pixelAccuracy()

# %%
threshold = 0.5

# imLst_train = train_set.show()
# imLst_test = test_set.show()

eval_loss_func = cldice()

# %%
mean_metric_train = {'IoU':[], 'PA':[], 'clDice':[]}

for i, (x, y) in enumerate(train_set):
    pred = evaluate_model_on_single_image(model, x)

    # print(imLst_train[i]+':')

    # Plot the result
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 10))
    ax1.set_title("True mask")
    ax2.set_title("Predicted mask")
    plot_image_with_segmentation(x, y, ax=ax1, model='gray', sdf=False, threshold=threshold)
    plot_image_with_segmentation(x, pred, ax=ax2, model='gray', sdf=False, threshold=threshold)
    ax1.axis('off')
    ax2.axis('off')
    plt.show()

    # save result
    segm = pred.cpu().detach().numpy()
    segm[segm < threshold] = 0
    segm[segm >= threshold] = 255
    mask = segm.squeeze()

    cldice = eval_loss_func(pred.to(device), y.unsqueeze(0).to(device)).cpu().detach().numpy().item()

    pred_mask = torch.where(pred > threshold, torch.ones_like(pred), torch.zeros_like(pred))
    pred_mask, real_mask = pred_mask.cpu().numpy().squeeze(), y.cpu().numpy().squeeze()
    pred_mask, real_mask = pred_mask.astype(np.int32), real_mask.astype(np.int32)

    metric = SegmentationMetric(2)
    hist = metric.addBatch(pred_mask, real_mask)
    pa = metric.pixelAccuracy()
    cpa = metric.classPixelAccuracy()
    mpa = metric.meanPixelAccuracy()
    IoU = metric.IntersectionOverUnion()
    mIoU = metric.meanIntersectionOverUnion()
    print('hist:\n{},\niou:{},\nmiou:{},\nPA:{},\ncPA:{},\nmPA:{}'.format(hist, IoU, mIoU, pa, cpa, mpa))
    print('clDice:', cldice)
    print('--'*20)

    mean_metric_train['IoU'].append(mIoU)
    mean_metric_train['PA'].append(pa)
    mean_metric_train['clDice'].append(cldice)

    # result = Image.fromarray(mask)
    # result = result.convert('L')
    # result.save("/content/drive/MyDrive/code/Post-Processing/unet/AngioData/train/result/"+"threshold_"+str(threshold)+"/"+imLst_train[i])



# IoU_list = mean_metric_train['IoU']
# PA_list = mean_metric_train['PA']
# clDice_list = mean_metric_train['clDice']
# print('IoU: segm')
# print('  Min IoU: {:.4f}, \n  0.25 IoU: {:.4f}, \n  0.5 IoU: {:.4f}, \n  0.75 IoU: {:.4f}, \n  Max IoU: {:.4f}, \n  mIoU: {:.4f}'
#     .format(np.min(IoU_list), statistics.quantiles(IoU_list, n=4)[0], statistics.quantiles(IoU_list, n=4)[1], statistics.quantiles(IoU_list, n=4)[2], np.max(IoU_list), np.mean(IoU_list)))
# print('PA: segm')
# print('  Min PA: {:.4f}, \n  0.25 PA: {:.4f}, \n  0.5 PA: {:.4f}, \n  0.75 PA: {:.4f}, \n  Max PA: {:.4f}, \n  mPA: {:.4f}'
#     .format(np.min(PA_list), statistics.quantiles(PA_list, n=4)[0], statistics.quantiles(PA_list, n=4)[1], statistics.quantiles(PA_list, n=4)[2], np.max(PA_list), np.mean(PA_list)))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
toPIL = transforms.ToPILImage()
mean_metric_test = {'IoU':[], 'PA':[], 'clDice':[]}
for i, (x, y) in enumerate(test_set):
    pred = evaluate_model_on_single_image(model, x)

    # print(imLst_test[i]+':')

    # Plot the result
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 10))
    ax1.set_title("True mask")
    ax2.set_title("Predicted mask")
    plot_image_with_segmentation(x, y, ax=ax1, model='gray', sdf=False, threshold=threshold)
    plot_image_with_segmentation(x, pred, ax=ax2, model='gray', sdf=False, threshold=threshold)
    ax1.axis('off')
    ax2.axis('off')
    plt.show()

    # save result
    segm = pred.cpu().detach().numpy()
    segm[segm < threshold] = 0
    segm[segm >= threshold] = 255
    mask = segm.squeeze()

    pred_mask = torch.where(pred > threshold, torch.ones_like(pred), torch.zeros_like(pred))
    pred_mask, real_mask = pred_mask.cpu().numpy().squeeze(), y.cpu().numpy().squeeze()
    pred_mask, real_mask = pred_mask.astype(np.int32), real_mask.astype(np.int32)

    cldice = eval_loss_func(pred.to(device), y.unsqueeze(0).to(device)).cpu().detach().numpy().item()

    metric = SegmentationMetric(2)
    hist = metric.addBatch(pred_mask, real_mask)
    pa = metric.pixelAccuracy()
    cpa = metric.classPixelAccuracy()
    mpa = metric.meanPixelAccuracy()
    IoU = metric.IntersectionOverUnion()
    mIoU = metric.meanIntersectionOverUnion()
    print('hist:\n{},\niou:{},\nmiou:{},\nPA:{},\ncPA:{},\nmPA:{}'.format(hist, IoU, mIoU, pa, cpa, mpa))
    print('clDice:', cldice)
    print('--'*20)

    mean_metric_test['IoU'].append(mIoU)
    mean_metric_test['PA'].append(pa)
    mean_metric_test['clDice'].append(cldice)

    # result = Image.fromarray(mask)
    # result = result.convert('L')
    # result.save("/content/drive/MyDrive/code/Post-Processing/unet/AngioData/test/result/"+"threshold_"+str(threshold)+"/"+imLst_test[i])

# IoU_list = mean_metric_test['IoU']
# PA_list = mean_metric_test['PA']
# clDice_list = mean_metric_test['clDice']
# print('IoU: segm')
# print('  Min IoU: {:.4f}, \n  0.25 IoU: {:.4f}, \n  0.5 IoU: {:.4f}, \n  0.75 IoU: {:.4f}, \n  Max IoU: {:.4f}, \n  mIoU: {:.4f}'
#     .format(np.min(IoU_list), statistics.quantiles(IoU_list, n=4)[0], statistics.quantiles(IoU_list, n=4)[1], statistics.quantiles(IoU_list, n=4)[2], np.max(IoU_list), np.mean(IoU_list)))
# print('PA: segm')
# print('  Min PA: {:.4f}, \n  0.25 PA: {:.4f}, \n  0.5 PA: {:.4f}, \n  0.75 PA: {:.4f}, \n  Max PA: {:.4f}, \n  mPA: {:.4f}'
#     .format(np.min(PA_list), statistics.quantiles(PA_list, n=4)[0], statistics.quantiles(PA_list, n=4)[1], statistics.quantiles(PA_list, n=4)[2], np.max(PA_list), np.mean(PA_list)))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# print('threshold:', threshold)
print(mean_metric_train)
print(mean_metric_test)
# print('--'*20)
# Out:
# {'IoU': [0.0012578616352201257, 0.08702956989247312, nan, nan, 0.005326231691078562, nan, 0.21875, 0.009596928982725527, 0.019720101781170483, 1.0, 0.1655196145905024, 0.05212677231025855, nan, 0.027615780445969126, 0.021467391304347827, nan, 0.0, 1.0, 0.0858700590640618, 1.0, nan, 0.30603448275862066, 0.06342088404868675, 1.0, 1.0, 0.027615062761506277, 0.27358490566037735, 0.0535405872193437, 0.2789473684210526, 0.34328358208955223, 1.0, 1.0, 0.24484944532488115, 1.0, 0.47619047619047616, nan, 0.0683111954459203, 0.3452194357366771, 1.0, 0.04627313656828414, 1.0, 0.48265895953757226, 0.01904761904761905, 0.0011806375442739079, 0.3851276359600444, 0.001049317943336831, nan, 0.005095541401273885, 0.02374581939799331, 0.0, 1.0, 0.1455787203450755, 0.10039761431411531, 0.1844106463878327, 0.32806324110671936, 0.0013458950201884253, 0.0019973368841544607, 0.09741309620048505, 0.0677257525083612, 0.02219945355191257, 0.02164366373902133, 0.020682148040638608, 0.008121827411167513, 0.08355367530407191, 0.009850275807722617, 0.009142053445850914, 0.001059322033898305, 0.04369682907965971, 0.0391304347826087, nan, 0.078125, nan, 0.4879120879120879, 0.49557522123893805, 0.4140625, 0.3101529902642559, 0.29514321295143214, 0.28064243448858833, 0.06171875, 0.034643734643734644, nan, 0.2289156626506024, 0.047139141742522754, 0.06318681318681318, nan], 'PA': [0.0025157232704402514, 0.17405913978494625, nan, nan, 0.010652463382157125, nan, 0.4375, 0.019193857965451054, 0.039440203562340966, 1.0, 0.3310392291810048, 0.1042535446205171, nan, 0.05523156089193825, 0.042934782608695654, nan, 0.0, 1.0, 0.1717401181281236, 1.0, nan, 0.6120689655172413, 0.1268417680973735, 1.0, 1.0, 0.055230125523012555, 0.5471698113207547, 0.1070811744386874, 0.5578947368421052, 0.6865671641791045, 1.0, 1.0, 0.4896988906497623, 1.0, 0.9523809523809523, nan, 0.1366223908918406, 0.6904388714733543, 1.0, 0.09254627313656828, 1.0, 0.9653179190751445, 0.0380952380952381, 0.0023612750885478157, 0.7702552719200888, 0.002098635886673662, nan, 0.01019108280254777, 0.04749163879598662, 0.0, 1.0, 0.291157440690151, 0.20079522862823063, 0.3688212927756654, 0.6561264822134387, 0.0026917900403768506, 0.0039946737683089215, 0.1948261924009701, 0.1354515050167224, 0.04439890710382514, 0.04328732747804266, 0.041364296081277216, 0.016243654822335026, 0.16710735060814383, 0.019700551615445233, 0.01828410689170183, 0.00211864406779661, 0.08739365815931942, 0.0782608695652174, nan, 0.15625, nan, 0.9758241758241758, 0.9911504424778761, 0.828125, 0.6203059805285118, 0.5902864259028643, 0.5612848689771767, 0.1234375, 0.06928746928746929, nan, 0.4578313253012048, 0.09427828348504551, 0.12637362637362637, nan], 'clDice': [729.9343872070312, 16.269969940185547, -1.0260570049285889, -1.03648042678833, 55.11027908325195, -1.0330629348754883, -5.653628349304199, 36.488101959228516, 76.0133056640625, 21.59623146057129, -3.548421859741211, 5.311827182769775, -1.032597541809082, -24.893409729003906, 80.18621826171875, -1.0181818008422852, 373.9712829589844, 14.317692756652832, -11.303323745727539, -8.345710754394531, -1.0350534915924072, 0.48848438262939453, -573.1320190429688, -3.579249382019043, -246.2581024169922, 12.051355361938477, 0.6549590229988098, -90.85179138183594, 0.16382282972335815, -3.923738479614258, 19.23668670654297, -6.23069429397583, -0.6654698848724365, -2884.89990234375, 1.1113379001617432, -1.0328915119171143, -5.481410980224609, -2.54833984375, 163.1547088623047, -66.31397247314453, 10.436466217041016, 14.727824211120605, 8.147930145263672, 294.2518005371094, -1.8405430316925049, 56.92702865600586, -1.0172269344329834, -87.27613830566406, 72.5438232421875, 78.91862487792969, -226.0327911376953, 2.225327491760254, 84.90811157226562, 59.437530517578125, -4.492323875427246, -827.3359375, 55.602664947509766, 124.87830352783203, 2.2262048721313477, 119.98019409179688, -137.05108642578125, 48.08294677734375, -59.338592529296875, -135.8447723388672, 202.01614379882812, 32.5619010 ...
# {'IoU': [0.0, 0.0, 0.005792903692976104, 0.0, 0.0017158544955387784, 0.0, nan, 0.051846231664137585, 0.41729323308270677, 1.0, nan, 0.3537666174298375, 0.15255376344086022, 0.24707602339181287, 1.0, 0.0914380714879468, 0.42911877394636017, 0.07391763463569166, nan, 0.13864306784660768, 0.4982142857142857, nan, 0.4468822170900693, 0.44642857142857145, 0.15995397008055237, nan, nan, 0.4839901477832512, nan, 1.0, 1.0, 0.4746031746031746, nan, 0.33969465648854963, nan], 'PA': [0.0, 0.0, 0.011585807385952208, 0.0, 0.0034317089910775567, 0.0, nan, 0.10369246332827517, 0.8345864661654135, 1.0, nan, 0.707533234859675, 0.30510752688172044, 0.49415204678362573, 1.0, 0.1828761429758936, 0.8582375478927203, 0.14783526927138332, nan, 0.27728613569321536, 0.9964285714285714, nan, 0.8937644341801386, 0.8928571428571429, 0.31990794016110474, nan, nan, 0.9679802955665024, nan, 1.0, 1.0, 0.9492063492063492, nan, 0.6793893129770993, nan], 'clDice': [33.23807907104492, 145.41940307617188, 806.5575561523438, 28.419937133789062, 24.45852279663086, 47.22254943847656, -1.0183768272399902, -125.15821838378906, 4.717458724975586, 80.50445556640625, -1.022819995880127, -1.5678298473358154, 0.3754122853279114, -4.573939323425293, 114.38339233398438, 3.0922155380249023, 21.079727172851562, 9.036260604858398, -1.0330870151519775, -1.896188735961914, 1.5010886192321777, -1.022554874420166, 49.43105697631836, 139.37046813964844, -0.303206205368042, -1.0240256786346436, -1.0258588790893555, 12.427501678466797, -1.0694851875305176, -5.174838542938232, -11401.560546875, 4.732212066650391, -1.0465703010559082, -2.750762462615967, -1.027148723602295]}

# %%
box_1, box_2, box_3 = mean_metric_test['IoU'], mean_metric_test['PA'], mean_metric_test['clDice']

plt.figure(figsize=(10,5))
# plt.title('Examples of boxplot',fontsize=15)
labels = ['IoU','PA','clDice']
plt.boxplot([box_1, box_2, box_3], labels = labels, showmeans=True)
# plt.legend()
plt.show()

# %%
def remove_outliers(data, min, max):
    # 确保数据是 NumPy 数组
    data = np.array(data)

    # 计算第5和第95百分位数
    q_low = np.percentile(data, min)
    q_high = np.percentile(data, max)

    # 过滤掉低于第5百分位和高于第95百分位的数据点
    filtered_data = data[(data >= q_low) & (data <= q_high)]
    return filtered_data

# %%
iou_clean = mean_metric_test['IoU']
pa_clean = mean_metric_test['PA']
cldice_clean = remove_outliers(mean_metric_test['clDice'], 30, 70)

# %%
print(np.nanmean(iou_clean))
print(np.nanmean(pa_clean))
print(np.mean(cldice_clean))
# Out:
# 0.3389588153193435
# 0.5240714767925332
# 2.3434851582233724

# %%
print(np.nanmedian(iou_clean))
print(np.nanmedian(pa_clean))
print(np.nanmedian(cldice_clean))
# Out:
# 0.29338533994018123
# 0.5867706798803625
# 0.3754122853279114

# %%
box_1, box_2 = iou_clean, pa_clean

plt.figure(figsize=(10,5))
# plt.title('Examples of boxplot',fontsize=15)
labels = ['IoU','PA']
plt.boxplot([box_1, box_2], labels = labels, showmeans=True)
# plt.legend()
plt.show()

# %%
box_1 = cldice_clean

plt.figure(figsize=(10,5))
# plt.title('Examples of boxplot',fontsize=15)
labels = ['clDice']
plt.boxplot([box_1], labels = labels, showmeans=True)
# plt.legend()
plt.show()

# %%
print(np.nanstd(iou_clean))
print(np.nanstd(pa_clean))
print(np.nanstd(cldice_clean))
# Out:
# 0.33189373622005114
# 0.4049651196994903
# 4.17527405452735
