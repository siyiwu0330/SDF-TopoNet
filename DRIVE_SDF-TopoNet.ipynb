# %%
import sys
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install torchmetrics segmentation-models-pytorch &> /dev/null

# %%
# !pip install -U giotto-tda &> /dev/null
# !pip install torch_topological &> /dev/null

# %%
import torch
from torch import nn as nn
from torchvision import transforms as T
from torchvision.transforms import functional as TF
from torchvision.datasets.utils import download_url

from torch import Tensor

import torchmetrics
import segmentation_models_pytorch as smp

import random
import numpy as np
import matplotlib.pyplot as plt

from pprint import pformat
from skimage.transform import resize
from pathlib import Path
from glob import glob
from matplotlib.pyplot import imread
from collections import defaultdict

from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import DataLoader, random_split
from torchvision import transforms
import statistics
import cv2

import torch.nn.functional as F

from torch_topological.nn import AlphaComplex, VietorisRipsComplex, CubicalComplex, WassersteinDistance, SignatureLoss
from scipy.ndimage import distance_transform_edt

import os

# %%
# import h5py
# from scipy.io import loadmat

# %%
gpu = torch.cuda.is_available()
device = torch.device("cuda:0" if gpu else "cpu")
print("device:", device)
# Out:
# device: cuda:0

# %%
data_path = '/content/drive/MyDrive/code/datasets'

batch_size = 4

epochs = 100

lr = 0.001

# loss = loss_1 * alpha + loss_2 * (1-alpha)
alpha = 1.0

# sample_size = 10

crop_size = (64,64)

padding = 2

# %%
class DriveDataset(Dataset):
    def __init__(self, root: str, data_type: str, crop_size=(60, 60), padding=2, enable_sdf=True):
        super(DriveDataset, self).__init__()
        self.flag = data_type
        self.crop_size = crop_size
        self.padding = padding
        self.enable_sdf = enable_sdf

        data_root = os.path.join(root, "DRIVE", self.flag)
        assert os.path.exists(data_root), f"path '{data_root}' does not exist."
        img_names = [i for i in os.listdir(os.path.join(data_root, "images")) if i.endswith(".tif")]
        self.img_list = [os.path.join(data_root, "images", i) for i in img_names]
        self.manual_list = [os.path.join(data_root, "1st_manual", i.split("_")[0] + "_manual1.gif") for i in img_names]
        self.roi_mask = [os.path.join(data_root, "mask", i.split("_")[0] + f"_{self.flag}_mask.gif") for i in img_names]

        self.imLst = [i for i in img_names]

    def __getitem__(self, idx):
        img = np.array(Image.open(self.img_list[idx]))
        manual = np.array(Image.open(self.manual_list[idx]))
        # mask = np.array(Image.open(self.roi_mask[idx]))

        img_width = img.shape[0]
        img_height = img.shape[1]
        start_i = (img_height - self.crop_size[1]) // 6
        start_j = (img_width - self.crop_size[0]) // 2

        if self.enable_sdf:
            manual = distance_transform_edt(manual) - distance_transform_edt(255 - manual)
            # manual = manual / self.crop_size[0]

        # img = img * mask
        # manual = manual * mask

        img = T.functional.to_tensor(img).float()
        manual = T.functional.to_tensor(manual).float()
        # mask = T.functional.to_tensor(mask).float()

        img = TF.crop(img, start_i, start_j, self.crop_size[1], self.crop_size[0])
        manual = TF.crop(manual, start_i, start_j, self.crop_size[1], self.crop_size[0])
        # mask = TF.crop(mask, start_i, start_j, self.crop_size[1], self.crop_size[0])

        # padding = self.padding
        # img = TF.pad(img, padding=[padding, padding, padding, padding], fill=1)
        # manual = TF.pad(manual, padding=[padding, padding, padding, padding], fill=1)
        # mask = TF.pad(mask, padding=[padding, padding, padding, padding], fill=0)

        return img, manual

    def __len__(self):
        return len(self.img_list)

    def show(self):
        return self.imLst

# %%
train_set = DriveDataset(data_path, data_type="training", crop_size=crop_size, padding = padding)
test_set = DriveDataset(data_path, data_type="test", crop_size=crop_size, padding = padding)

print(len(train_set))
print(len(test_set))

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, batch_size=1, shuffle=False)
# Out:
# 20
# 20

# %%
for batch_x, batch_y in train_loader:
    print(batch_x.size())
    print(batch_y.size())
    plt.subplot(1, 3, 1)
    plt.imshow(batch_x[0].numpy().transpose(1,2,0))
    plt.axis("off")
    plt.subplot(1, 3, 2)
    plt.imshow(batch_y[0][0], cmap=plt.get_cmap('gray'))
    plt.axis("off")
    plt.subplot(1, 3, 3)
    plt.imshow(batch_y[0][0]>0, cmap=plt.get_cmap('gray'))
    plt.axis("off")
    plt.show()

    print(np.max(batch_y[0].numpy()))
    print(np.min(batch_y[0].numpy()))
    print(batch_y[0].dtype)

    break
# Out:
# torch.Size([4, 3, 64, 64])
# torch.Size([4, 1, 64, 64])
# 5.0
# -16.763054
# torch.float32

# %%
def plot_image_with_segmentation(image, segmentation, ax=None, model='gray', sdf=True, threshold=0.5):
    """
    Plots an image with overlayed segmentation mask. Segmentation is thresholded at 0.5

    Returns: plt.fig and ax objects
    """
    if ax is None:
        fig = plt.figure(figsize=(8, 8))
        ax = fig.add_subplot(111)
        ax.axis("off")

    im = image.cpu().detach().numpy()
    segm = segmentation.cpu().detach().numpy()
    if model == 'gray':
        ax.imshow(im.squeeze(), cmap="gray")
    elif model == 'rgb':
        ax.imshow(np.transpose(im.squeeze(), (1, 2, 0)))
    if sdf == True:
        mask = segm
    else:
        mask = segm < threshold
    ax.imshow(mask.squeeze(), cmap="Set1", alpha=0.5)
    return plt.gcf(), ax

# %%
def evaluate_model_on_single_image(model, x, device=device):
    """
    Evaluate a model on a single data point on the device.

    Returns: model(x)
    """
    with torch.no_grad():
        x = x.to(device)
        return model(x.view(1, *x.shape))

# %%
def evaluate_model(model, data_loader, metrics_dict, reduction=True, device=device, alpha=0.5):
    """
    Evaluate a model 'model' on all batches of a torch DataLoader 'data_loader'.
    On each batch, compute all metric functions stored in dictionary 'metrics_dict'.

    Returns: dict of metric_name: (list of batch-wise metrics if reduction == False, else single scalar)
    """

    # defaultdict(list) returns a dictionary-like object with default_factory list.
    # When a new key is encountered, an entry is automatically created of type default_factory.
    metrics = defaultdict(list)
    with torch.no_grad():
        for i, (batch_x, batch_y) in enumerate(data_loader):
            # Predict on batch
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)
            logits = model(batch_x)

            if alpha == 0.0:
                for metric_name, metric_func in metrics_dict.items():
                    value_1 = 0
                    value_2 = metric_func[1](logits.cpu(), batch_y.cpu()).item()

                    value = value_2

                    metrics[metric_name].append(value)

            elif alpha == 1.0:
                for metric_name, metric_func in metrics_dict.items():
                    value_1 = metric_func[0](logits.cpu(), batch_y.cpu()).item() #.cpu().numpy()
                    value_2 = 0

                    value = value_1

                    metrics[metric_name].append(value)

            else:
                for metric_name, metric_func in metrics_dict.items():
                    value_1 = metric_func[0](logits.cpu(), batch_y.cpu()).item() #.cpu().numpy()
                    value_2 = metric_func[1](logits.cpu(), batch_y.cpu()).item()

                    value = alpha*value_1 + (1-alpha)*value_2

                    metrics[metric_name].append(value)

    if reduction == True:
        # Return mean values
        return {key: np.mean(value) for key, value in metrics.items()}
    else:
        return metrics

# %%
def save_model(model, path, optimizer=None):
    """
    Saves the state_dict of a torch model and optional optimizer to 'path'
    Returns: None
    """
    state = {"model": model.state_dict()}
    if optimizer is not None:
        state["optimizer"] = optimizer.state_dict()
    torch.save(state, path)


def load_model(model, path, optimizer=None):
    """
    Loads the state_dict of a torch model and optional optimizer from 'path'
    Returns: None
    """
    state = torch.load(path)
    model.load_state_dict(state["model"])
    if optimizer is not None:
        optimizer.load_state_dict(state["optimizer"])

# %%
def plot_histories(train_history=None, val_history=None, label="Loss"):
    """
    Takes a list of training and/or validation metrics and plots them
    Returns: plt.figure and ax objects
    """
    if not train_history and not val_history:
        raise ValueError("Must specify at least one of 'train_histories' and 'val_histories'")
    fig = plt.figure(figsize=(5, 3))
    ax = fig.add_subplot(111)

    epochs = np.arange(len(train_history or val_history))
    if train_history:
        ax.plot(epochs, train_history, label="Training", color="black")
    if val_history:
        ax.plot(epochs, val_history, label="Validation", color="darkred")

    ax.set_xlabel("Epoch")
    ax.set_ylabel(label)
    ax.legend(loc=0)

    return fig, ax

# %%
def run_one_epoch(model, loss, optimizer, train_loader, val_loader, n_epochs, metrics_dict, device=device, alpha=0.5):
    """
    Run 1 epoch of training
    Changes to model parameters and optimizer occour internally (state updates)
    Returns:
        two dictionaries, training and a validation metrics
    """
    train_losses = []
    for i, (batch_x, batch_y) in enumerate(train_loader):
        # Zero out stored gradients for all parameters
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)
        optimizer.zero_grad()

        print(f"   -- Batch {i+1}/{len(train_loader)}", end=" / ")
        # Predict on batch
        logits = model(batch_x)

        if alpha == 0.0:
            loss_tensor_1 = 0
            loss_tensor_2 = loss[1](logits, batch_y)
        elif alpha == 1.0:
            loss_tensor_1 = loss[0](logits, batch_y)
            loss_tensor_2 = 0
        else:
            # Compute loss function
            loss_tensor_1 = loss[0](logits, batch_y)
            loss_tensor_2 = loss[1](logits, batch_y)

            print(loss_tensor_2)

        loss_tensor = alpha*loss_tensor_1 + (1-alpha)*loss_tensor_2
        loss_scalar = loss_tensor.detach().cpu().numpy()

        train_losses.append(loss_scalar)
        print("Loss: ", loss_scalar)

        # Backprop and step
        loss_tensor.backward()
        optimizer.step()

    # Run validation
    print("   Validation running...")
    val_metrics = evaluate_model(
        model=model,
        data_loader=val_loader,
        metrics_dict=metrics_dict,
        alpha=alpha
    )
    # Return loss and metrics as dicts
    return {"loss": np.mean(train_losses)}, val_metrics


def merge_list_of_dicts(list_of_dicts):
    """
    Takes a list of dictionaries and merges them into a single dictionary pointing to lists

    E.g. [{"loss": 5}, {"loss": 3}, {"loss": -2, "F1": 0.5}] --> {"loss": [5, 3, -2], "F1": [0.5]}

    Returns: dict
    """
    merged = defaultdict(list)
    for dict_ in list_of_dicts:
        for value, key in dict_.items():
            merged[value].append(key)
    return merged


def training_loop(model, loss, optimizer, train_loader, val_loader, n_epochs, init_epoch=None, metrics_dict=None, save_path=None, alpha=0.5):
    """
    Run training of a model given a loss function, optimizer and a set of training and validation data.
    Supports computing additional metrics on the validation set (only) via the metrics_dict param.
    Specify save_path to store the model at each epoch.

    Returns:
        Two lists of metric dictionaries for each epoch for training and validation, specifically
    """
    train_history, val_history = [], []

    metrics_with_loss = {"loss": loss}
    if metrics_dict is not None:
        metrics_with_loss.update(metrics_dict)

    if init_epoch == None:
        init_epoch = 0
    try:
        for i in range(init_epoch, n_epochs):
            print(f"Epoch {i+1}/{n_epochs}")
            train_metrics, val_metrics = run_one_epoch(
                model=model,
                loss=loss,
                optimizer=optimizer,
                train_loader=train_loader,
                val_loader=val_loader,
                n_epochs=n_epochs,
                metrics_dict=metrics_with_loss,
                alpha=alpha
            )
            print("   Mean epoch metrics:")
            print(f"   Training:   {pformat(train_metrics)}")
            print(f"   Validation: {pformat(val_metrics)}")
            train_history.append(train_metrics), val_history.append(val_metrics)

            # wandb.log({'epoch': n_epochs+1, 'loss': train_metrics['loss'], 'val_loss': val_metrics['loss']})
            # wandb.watch(model, loss, log="all")

            # if save_path:
            #     save_path_epoch = f"epoch_{i+1}_{save_path}"
            #     print(f"   Saving to: {save_path_epoch}")
            #     save_model(model, save_path_epoch, optimizer)
            #     old_path_epoch = f"epoch_{i}_{save_path}"
            #     if os.path.exists(old_path_epoch):
            #         os.remove(old_path_epoch)

    except KeyboardInterrupt:
        print("Training stopped.")
        pass

    # Merge list of training and validation dicts into single dicts
    return merge_list_of_dicts(train_history), merge_list_of_dicts(val_history)

# %%
# Init U-Net model
model = smp.Unet(encoder_name='efficientnet-b0',in_channels=3,classes=1)

model.to(device)

# Define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

print(model)
# Out:
# Unet(
#   (encoder): EfficientNetEncoder(
#     (_conv_stem): Conv2dStaticSamePadding(
#       3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#       (static_padding): ZeroPad2d((0, 1, 0, 1))
#     )
#     (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (_blocks): ModuleList(
#       (0): MBConvBlock(
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           32, 8, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           8, 32, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (1): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#           (static_padding): ZeroPad2d((0, 1, 0, 1))
#         )
#         (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           96, 4, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           4, 96, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (2): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           144, 6, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           6, 144, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (3): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#           (static_padding): ZeroPad2d((1, 2, 1, 2))
#         )
#         (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           144, 6, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           6, 144, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (4): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           240, 10, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           10, 240, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (5): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           240, 240, kernel_size=(3, 3), stride=[2, 2], groups=240, bias=False
#           (static_padding): ZeroPad2d((0, 1, 0, 1))
#         )
#         (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           240, 10, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           10, 240, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (6-7): 2 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           480, 20, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           20, 480, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (8): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           480, 480, kernel_size=(5, 5), stride=[1, 1], groups=480, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           480, 20, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           20, 480, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (9-10): 2 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           672, 28, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           28, 672, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (11): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           672, 672, kernel_size=(5, 5), stride=[2, 2], groups=672, bias=False
#           (static_padding): ZeroPad2d((1, 2, 1, 2))
#         )
#         (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           672, 28, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           28, 672, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (12-14): 3 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1152, 48, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           48, 1152, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (15): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1152, 1152, kernel_size=(3, 3), stride=[1, 1], groups=1152, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1152, 48, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           48, 1152, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#     )
#     (_conv_head): Conv2dStaticSamePadding(
#       320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn1): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#     (_dropout): Dropout(p=0.2, inplace=False)
#     (_swish): MemoryEfficientSwish()
#   )
#   (decoder): UnetDecoder(
#     (center): Identity()
#     (blocks): ModuleList(
#       (0): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(432, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (1): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(296, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (2): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(152, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (3): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (4): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#     )
#   )
#   (segmentation_head): SegmentationHead(
#     (0): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Identity()
#     (2): Activation(
#       (activation): Identity()
#     )
#   )
# )

# %%
# Specify integer, starting at 1
init_epoch = None
if init_epoch != None:
    load_model(model, f"epoch_{init_epoch}_model.ckpt", optimizer)

# %%
def soft_dice(y_true, y_pred):
    smooth = 1
    intersection = torch.sum((y_true * y_pred))
    coeff = (2. * intersection + smooth) / (torch.sum(y_true) + torch.sum(y_pred) + smooth)
    return 1. - coeff


class soft_dice_cldice(nn.Module):
    def __init__(self, iter_=3, alpha=0.5, smooth=1.):
        super(soft_dice_cldice, self).__init__()
        self.iter = iter_
        self.smooth = smooth
        self.alpha = alpha

    def forward(self, y_pred, y_true):
        dice = soft_dice(y_true, y_pred)
        skel_pred = soft_skel(y_pred, self.iter)
        skel_true = soft_skel(y_true, self.iter)
        tprec = (torch.sum(torch.multiply(skel_pred, y_true)) + self.smooth) / (
                    torch.sum(skel_pred) + self.smooth)
        tsens = (torch.sum(torch.multiply(skel_true, y_pred)) + self.smooth) / (
                    torch.sum(skel_true) + self.smooth)
        cl_dice = 1. - 2.0 * (tprec * tsens) / (tprec + tsens)
        return (1.0 - self.alpha) * dice + self.alpha * cl_dice

class soft_cldice(nn.Module):
    def __init__(self, iter_=3, alpha=0.5, smooth=1.):
        super(soft_cldice, self).__init__()
        self.iter = iter_
        self.smooth = smooth
        self.alpha = alpha

    def forward(self, y_pred, y_true):
        skel_pred = soft_skel(y_pred, self.iter)
        skel_true = soft_skel(y_true, self.iter)
        tprec = (torch.sum(torch.multiply(skel_pred, y_true)) + self.smooth) / (
                    torch.sum(skel_pred) + self.smooth)
        tsens = (torch.sum(torch.multiply(skel_true, y_pred)) + self.smooth) / (
                    torch.sum(skel_true) + self.smooth)
        cl_dice = 1. - 2.0 * (tprec * tsens) / (tprec + tsens)
        return cl_dice

def soft_erode(img):
    if len(img.shape) == 4:
        p1 = -F.max_pool2d(-img, (3, 1), (1, 1), (1, 0))
        p2 = -F.max_pool2d(-img, (1, 3), (1, 1), (0, 1))
        return torch.min(p1, p2)
    elif len(img.shape) == 5:
        p1 = -F.max_pool3d(-img, (3, 1, 1), (1, 1, 1), (1, 0, 0))
        p2 = -F.max_pool3d(-img, (1, 3, 1), (1, 1, 1), (0, 1, 0))
        p3 = -F.max_pool3d(-img, (1, 1, 3), (1, 1, 1), (0, 0, 1))
        return torch.min(torch.min(p1, p2), p3)


def soft_dilate(img):
    if len(img.shape) == 4:
        return F.max_pool2d(img, (3, 3), (1, 1), (1, 1))
    elif len(img.shape) == 5:
        return F.max_pool3d(img, (3, 3, 3), (1, 1, 1), (1, 1, 1))


def soft_open(img):
    return soft_dilate(soft_erode(img))


def soft_skel(img, iter_):
    img1 = soft_open(img)
    skel = F.gelu(img - img1)
    for j in range(iter_):
        img = soft_erode(img)
        img1 = soft_open(img)
        delta = F.gelu(img - img1)
        skel = skel + F.gelu(delta - skel * delta)
    return skel

from skimage.morphology import skeletonize

def skel(img, iter_):
    img_tensor = img.detach().cpu().numpy()
    threshold = 0.5
    binary_image = (img_tensor > threshold).astype(np.uint8)
    skeletonized_tensor = torch.from_numpy(np.stack([skeletonize(im) for im in binary_image])).float().to('cuda:0')
    return skeletonized_tensor


class cldice(nn.Module):
    def __init__(self, iter_=3, alpha=0.5, smooth=1.):
        super(cldice, self).__init__()
        self.iter = iter_
        self.smooth = smooth
        self.alpha = alpha

    def forward(self, y_pred, y_true):
        skel_pred = skel(y_pred, self.iter)
        skel_true = skel(y_true, self.iter)
        tprec = (torch.sum(torch.multiply(skel_pred, y_true)) + self.smooth) / (
                    torch.sum(skel_pred) + self.smooth)
        tsens = (torch.sum(torch.multiply(skel_true, y_pred)) + self.smooth) / (
                    torch.sum(skel_true) + self.smooth)
        cl_dice = 1. - 2.0 * (tprec * tsens) / (tprec + tsens)
        return cl_dice

# %%
class persistence_loss(nn.Module):
    def __init__(self, dim=1, padding=2):
        super(persistence_loss, self).__init__()
        self.persistence_algo = CubicalComplex()
        self.loss_fn = WassersteinDistance(q=2)
        self.padding = padding

    def forward(self, y_pred, y_true):
        loss = 0.0
        batch_size = y_pred.size(0)
        y_pred_padded = F.pad(y_pred, (self.padding, self.padding, self.padding, self.padding), "constant", 1)
        y_true_padded = F.pad(y_true, (self.padding, self.padding, self.padding, self.padding), "constant", 1)
        for i in range(batch_size):
            pd_y_pred = self.persistence_algo(y_pred_padded[i])
            pd_y_pred = pd_y_pred[0]
            pd_y_true = self.persistence_algo(y_true_padded[i])[0]
            pd_y_true = pd_y_true[0]

            loss += self.loss_fn(pd_y_pred, pd_y_true)

        loss /= batch_size
        return loss

# %%
# Define loss and metrics
loss_1 = torch.nn.MSELoss(reduction="mean")
loss_2 = persistence_loss()

# metrics = {"f1": torchmetrics.classification.F1Score(task='binary', num_classes=1, average="macro", mdmc_average="samplewise")}
metrics = {}

# %%
# Run training
train_history, val_history = training_loop(
    model=model,
    loss=[loss_1, loss_2],
    optimizer=optimizer,
    train_loader=train_loader,
    val_loader=test_loader,
    init_epoch=init_epoch,
    n_epochs=epochs,
    metrics_dict=metrics,
    save_path="model.ckpt",
    alpha=alpha
)
# Out:
# Epoch 1/100
#    -- Batch 1/5 / Loss:  56.38614
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#    -- Batch 2/5 / Loss:  54.1394
#    -- Batch 3/5 / Loss:  84.32727
#    -- Batch 4/5 / Loss:  73.70743
#    -- Batch 5/5 / Loss:  80.99052
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 69.91015}
#    Validation: {'loss': 62.45798349380493}
# Epoch 2/100
#    -- Batch 1/5 / Loss:  74.572174
#    -- Batch 2/5 / Loss:  63.701904
#    -- Batch 3/5 / Loss:  36.67929
#    -- Batch 4/5 / Loss:  72.83823
#    -- Batch 5/5 / Loss:  60.973927
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 61.753105}
#    Validation: {'loss': 56.48793535232544}
# Epoch 3/100
#    -- Batch 1/5 / Loss:  35.96616
#    -- Batch 2/5 / Loss:  78.41031
#    -- Batch 3/5 / Loss:  48.206497
#    -- Batch 4/5 / Loss:  49.78483
#    -- Batch 5/5 / Loss:  64.636444
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 55.40085}
#    Validation: {'loss': 51.37071046829224}
# Epoch 4/100
#    -- Batch 1/5 / Loss:  26.86472
#    -- Batch 2/5 / Loss:  66.2329
#    -- Batch 3/5 / Loss:  45.828056
#    -- Batch 4/5 / Loss:  47.4466
#    -- Batch 5/5 / Loss:  60.84356
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 49.44317}
#    Validation: {'loss': 47.406764602661134}
# Epoch 5/100
#    -- Batch 1/5 / Loss:  47.09208
#    -- Batch 2/5 / Loss:  55.11647
#    -- Batch 3/5 / Loss:  40.449673
#    -- Batch 4/5 / Loss:  33.142433
#    -- Batch 5/5 / Loss:  42.651283
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 43.690388}
#    Validation: {'loss': 44.64587349891663}
# Epoch 6/100
#    -- Batch 1/5 / Loss:  25.167452
#    -- Batch 2/5 / Loss:  26.849371
#    -- Batch 3/5 / Loss:  50.568615
#    -- Batch 4/5 / Loss:  41.645035
#    -- Batch 5/5 / Loss:  47.03121
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 38.25234}
#    Validation: {'loss': 41.523120927810666}
# Epoch 7/100
#    -- Batch 1/5 / Loss:  31.186756
#    -- Batch 2/5 / Loss:  28.49252
#    -- Batch 3/5 / Loss:  35.733536
#    -- Batch 4/5 / Loss:  36.702087
#    -- Batch 5/5 / Loss:  31.393642
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 32.70171}
#    Validation: {'loss': 39.888457727432254}
# Epoch 8/100
#    -- Batch 1/5 / Loss:  23.60996
#    -- Batch 2/5 / Loss:  30.729197
#    -- Batch 3/5 / Loss:  31.663218
#    -- Batch 4/5 / Loss:  17.848068
#    -- Batch 5/5 / Loss:  43.714005
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 29.51289}
#    Validation: {'loss': 36.12770266532898}
# Epoch 9/100
#    -- Batch 1/5 / Loss:  24.341425
#    -- Batch 2/5 / Loss:  25.455273
#    -- Batch 3/5 / Loss:  30.953653
#    -- Batch 4/5 / Loss:  24.783087
#    -- Batch 5/5 / Loss:  26.642113
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 26.43511}
#    Validation: {'loss': 33.71921892166138}
# Epoch 10/100
#    -- Batch 1/5 / Loss:  23.308567
#    -- Batch 2/5 / Loss:  10.668488
#    -- Batch 3/5 / Loss:  31.37915
#    -- Batch 4/5 / Loss:  32.330956
#    -- Batch 5/5 / Loss:  15.680159
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 22.673464}
#    Validation: {'loss': 31.82901382446289}
# Epoch 11/100
#    -- Batch 1/5 / Loss:  16.932358
#    -- Batch 2/5 / Loss:  32.04327
#    -- Batch 3/5 / Loss:  19.427727
#    -- Batch 4/5 / Loss:  18.986946
#    -- Batch 5/5 / Loss:  10.0328865
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 19.484638}
#    Validation: {'loss': 28.746504068374634}
# Epoch 12/100
#    -- Batch 1/5 / Loss:  30.998898
#    -- Batch 2/5 / Loss:  28.063961
#    -- Batch 3/5 / Loss:  9.08214
#    -- Batch 4/5 / Loss:  8.25172
#    -- Batch 5/5 / Loss:  16.005177
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 18.480377}
#    Validation: {'loss': 28.387271761894226}
# Epoch 13/100
#    -- Batch 1/5 / Loss:  12.238119
#    -- Batch 2/5 / Loss:  10.634464
#    -- Batch 3/5 / Loss:  9.815133
#    -- Batch 4/5 / Loss:  12.449504
#    -- Batch 5/5 / Loss:  31.068737
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 15.241193}
#    Validation: {'loss': 26.62540273666382}
# Epoch 14/100
#    -- Batch 1/5 / Loss:  15.007874
#    -- Batch 2/5 / Loss:  17.130346
#    -- Batch 3/5 / Loss:  7.7078905
#    -- Batch 4/5 / Loss:  11.217312
#    -- Batch 5/5 / Loss:  13.300722
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 12.8728285}
#    Validation: {'loss': 26.927788043022154}
# Epoch 15/100
#    -- Batch 1/5 / Loss:  6.823809
#    -- Batch 2/5 / Loss:  18.230995
#    -- Batch 3/5 / Loss:  9.707819
#    -- Batch 4/5 / Loss:  9.661453
#    -- Batch 5/5 / Loss:  14.692993
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 11.823414}
#    Validation: {'loss': 25.560607433319092}
# Epoch 16/100
#    -- Batch 1/5 / Loss:  8.240355
#    -- Batch 2/5 / Loss:  10.630223
#    -- Batch 3/5 / Loss:  8.927512
#    -- Batch 4/5 / Loss:  7.046095
#    -- Batch 5/5 / Loss:  12.999111
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 9.568659}
#    Validation: {'loss': 24.298438668251038}
# Epoch 17/100
#    -- Batch 1/5 / Loss:  7.13171
#    -- Batch 2/5 / Loss:  4.175823
#    -- Batch 3/5 / Loss:  6.4515476
#    -- Batch 4/5 / Loss:  11.061321
#    -- Batch 5/5 / Loss:  18.164688
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 9.397018}
#    Validation: {'loss': 24.67128190994263}
# Epoch 18/100
#    -- Batch 1/5 / Loss:  11.093527
#    -- Batch 2/5 / Loss:  9.226555
#    -- Batch 3/5 / Loss:  7.2218227
#    -- Batch 4/5 / Loss:  4.6439705
#    -- Batch 5/5 / Loss:  8.152102
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 8.0675955}
#    Validation: {'loss': 24.489333057403563}
# Epoch 19/100
#    -- Batch 1/5 / Loss:  5.0811806
#    -- Batch 2/5 / Loss:  6.260932
#    -- Batch 3/5 / Loss:  4.0349255
#    -- Batch 4/5 / Loss:  4.7948494
#    -- Batch 5/5 / Loss:  12.502995
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 6.534976}
#    Validation: {'loss': 22.427702260017394}
# Epoch 20/100
#    -- Batch 1/5 / Loss:  5.30507
#    -- Batch 2/5 / Loss:  3.7391777
#    -- Batch 3/5 / Loss:  9.314186
#    -- Batch 4/5 / Loss:  3.833522
#    -- Batch 5/5 / Loss:  8.200939
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 6.078579}
#    Validation: {'loss': 22.04290375709534}
# Epoch 21/100
#    -- Batch 1/5 / Loss:  4.4839716
#    -- Batch 2/5 / Loss:  3.8246622
#    -- Batch 3/5 / Loss:  4.350913
#    -- Batch 4/5 / Loss:  9.143469
#    -- Batch 5/5 / Loss:  3.328063
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 5.026216}
#    Validation: {'loss': 21.681122255325317}
# Epoch 22/100
#    -- Batch 1/5 / Loss:  3.184029
#    -- Batch 2/5 / Loss:  6.028304
#    -- Batch 3/5 / Loss:  4.9165955
#    -- Batch 4/5 / Loss:  4.326839
#    -- Batch 5/5 / Loss:  4.079978
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 4.5071497}
#    Validation: {'loss': 21.7566180229187}
# Epoch 23/100
#    -- Batch 1/5 / Loss:  2.5065134
#    -- Batch 2/5 / Loss:  2.9073255
#    -- Batch 3/5 / Loss:  3.8187604
#    -- Batch 4/5 / Loss:  2.7371686
#    -- Batch 5/5 / Loss:  20.068598
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 6.407673}
#    Validation: {'loss': 19.7715491771698}
# Epoch 24/100
#    -- Batch 1/5 / Loss:  2.894922
#    -- Batch 2/5 / Loss:  7.547553
#    -- Batch 3/5 / Loss:  2.384593
#    -- Batch 4/5 / Loss:  3.1061113
#    -- Batch 5/5 / Loss:  3.7453952
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 3.9357152}
#    Validation: {'loss': 22.28617868423462}
# Epoch 25/100
#    -- Batch 1/5 / Loss:  2.2588394
#    -- Batch 2/5 / Loss:  6.1796417
#    -- Batch 3/5 / Loss:  3.4607852
#    -- Batch 4/5 / Loss:  2.58283
#    -- Batch 5/5 / Loss:  2.6175072
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 3.4199207}
#    Validation: {'loss': 21.633856678009032}
# Epoch 26/100
#    -- Batch 1/5 / Loss:  2.3358583
#    -- Batch 2/5 / Loss:  2.9944067
#    -- Batch 3/5 / Loss:  2.5296106
#    -- Batch 4/5 / Loss:  2.353309
#    -- Batch 5/5 / Loss:  5.345692
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 3.1117752}
#    Validation: {'loss': 20.409210896492006}
# Epoch 27/100
#    -- Batch 1/5 / Loss:  2.589158
#    -- Batch 2/5 / Loss:  2.0605226
#    -- Batch 3/5 / Loss:  2.2503672
#    -- Batch 4/5 / Loss:  2.3589191
#    -- Batch 5/5 / Loss:  3.555978
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 2.5629888}
#    Validation: {'loss': 21.2726509809494}
# Epoch 28/100
#    -- Batch 1/5 / Loss:  7.728324
#    -- Batch 2/5 / Loss:  2.489755
#    -- Batch 3/5 / Loss:  2.3191688
#    -- Batch 4/5 / Loss:  2.1147323
#    -- Batch 5/5 / Loss:  2.900467
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 3.5104892}
#    Validation: {'loss': 19.34201467037201}
# Epoch 29/100
#    -- Batch 1/5 / Loss:  3.012968
#    -- Batch 2/5 / Loss:  2.22943
#    -- Batch 3/5 / Loss:  5.340998
#    -- Batch 4/5 / Loss:  1.6572356
#    -- Batch 5/5 / Loss:  3.121047
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 3.072336}
#    Validation: {'loss': 20.564853191375732}
# Epoch 30/100
#    -- Batch 1/5 / Loss:  4.0710363
#    -- Batch 2/5 / Loss:  2.5708206
#    -- Batch 3/5 / Loss:  10.502789
#    -- Batch 4/5 / Loss:  2.2604837
#    -- Batch 5/5 / Loss:  2.8365843
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 4.4483423}
#    Validation: {'loss': 19.397687220573424}
# Epoch 31/100
#    -- Batch 1/5 / Loss:  1.4247212
#    -- Batch 2/5 / Loss:  1.4244349
#    -- Batch 3/5 / Loss:  1.7065616
#    -- Batch 4/5 / Loss:  2.6266632
#    -- Batch 5/5 / Loss:  1.9515524
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.8267866}
#    Validation: {'loss': 20.719720816612245}
# Epoch 32/100
#    -- Batch 1/5 / Loss:  2.1882267
#    -- Batch 2/5 / Loss:  1.4440941
#    -- Batch 3/5 / Loss:  1.5799431
#    -- Batch 4/5 / Loss:  1.6541424
#    -- Batch 5/5 / Loss:  1.6814332
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.709568}
#    Validation: {'loss': 20.51623191833496}
# Epoch 33/100
#    -- Batch 1/5 / Loss:  2.026071
#    -- Batch 2/5 / Loss:  1.5638908
#    -- Batch 3/5 / Loss:  5.545558
#    -- Batch 4/5 / Loss:  1.6774809
#    -- Batch 5/5 / Loss:  4.6560717
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 3.0938144}
#    Validation: {'loss': 19.782331705093384}
# Epoch 34/100
#    -- Batch 1/5 / Loss:  2.4873872
#    -- Batch 2/5 / Loss:  1.8400276
#    -- Batch 3/5 / Loss:  1.3329079
#    -- Batch 4/5 / Loss:  1.4689465
#    -- Batch 5/5 / Loss:  1.6478705
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.755428}
#    Validation: {'loss': 19.290629434585572}
# Epoch 35/100
#    -- Batch 1/5 / Loss:  1.1760799
#    -- Batch 2/5 / Loss:  1.6903589
#    -- Batch 3/5 / Loss:  1.1249529
#    -- Batch 4/5 / Loss:  2.2895885
#    -- Batch 5/5 / Loss:  1.5177627
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.5597485}
#    Validation: {'loss': 20.076457142829895}
# Epoch 36/100
#    -- Batch 1/5 / Loss:  1.5510185
#    -- Batch 2/5 / Loss:  1.4529974
#    -- Batch 3/5 / Loss:  5.2631216
#    -- Batch 4/5 / Loss:  1.7297945
#    -- Batch 5/5 / Loss:  3.9791398
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 2.7952144}
#    Validation: {'loss': 19.617879986763}
# Epoch 37/100
#    -- Batch 1/5 / Loss:  3.4285345
#    -- Batch 2/5 / Loss:  2.1279516
#    -- Batch 3/5 / Loss:  1.5771766
#    -- Batch 4/5 / Loss:  1.3563592
#    -- Batch 5/5 / Loss:  4.3372245
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 2.5654492}
#    Validation: {'loss': 19.638401341438293}
# Epoch 38/100
#    -- Batch 1/5 / Loss:  1.2007596
#    -- Batch 2/5 / Loss:  3.1203992
#    -- Batch 3/5 / Loss:  1.9051914
#    -- Batch 4/5 / Loss:  2.094857
#    -- Batch 5/5 / Loss:  2.771887
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 2.2186189}
#    Validation: {'loss': 20.130651116371155}
# Epoch 39/100
#    -- Batch 1/5 / Loss:  1.8311014
#    -- Batch 2/5 / Loss:  1.3448184
#    -- Batch 3/5 / Loss:  4.808087
#    -- Batch 4/5 / Loss:  2.6466284
#    -- Batch 5/5 / Loss:  1.4296153
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 2.41205}
#    Validation: {'loss': 19.87624135017395}
# Epoch 40/100
#    -- Batch 1/5 / Loss:  1.493751
#    -- Batch 2/5 / Loss:  2.736864
#    -- Batch 3/5 / Loss:  1.4249271
#    -- Batch 4/5 / Loss:  3.479919
#    -- Batch 5/5 / Loss:  3.1194098
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 2.4509742}
#    Validation: {'loss': 19.53030083179474}
# Epoch 41/100
#    -- Batch 1/5 / Loss:  1.1414578
#    -- Batch 2/5 / Loss:  1.4275562
#    -- Batch 3/5 / Loss:  1.3843263
#    -- Batch 4/5 / Loss:  0.9799554
#    -- Batch 5/5 / Loss:  1.3157498
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.249809}
#    Validation: {'loss': 19.889889526367188}
# Epoch 42/100
#    -- Batch 1/5 / Loss:  2.0224907
#    -- Batch 2/5 / Loss:  1.4918531
#    -- Batch 3/5 / Loss:  1.0542455
#    -- Batch 4/5 / Loss:  2.2751436
#    -- Batch 5/5 / Loss:  1.3514204
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.6390307}
#    Validation: {'loss': 19.48041925430298}
# Epoch 43/100
#    -- Batch 1/5 / Loss:  1.4930058
#    -- Batch 2/5 / Loss:  0.9340998
#    -- Batch 3/5 / Loss:  1.1706051
#    -- Batch 4/5 / Loss:  1.172167
#    -- Batch 5/5 / Loss:  2.4132166
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.4366188}
#    Validation: {'loss': 19.74433214664459}
# Epoch 44/100
#    -- Batch 1/5 / Loss:  3.1069303
#    -- Batch 2/5 / Loss:  2.396717
#    -- Batch 3/5 / Loss:  1.6762065
#    -- Batch 4/5 / Loss:  1.1522917
#    -- Batch 5/5 / Loss:  1.0393143
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.874292}
#    Validation: {'loss': 18.61678502559662}
# Epoch 45/100
#    -- Batch 1/5 / Loss:  0.9356962
#    -- Batch 2/5 / Loss:  0.83692986
#    -- Batch 3/5 / Loss:  1.0911057
#    -- Batch 4/5 / Loss:  1.5803268
#    -- Batch 5/5 / Loss:  1.3033261
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.1494769}
#    Validation: {'loss': 18.803183150291442}
# Epoch 46/100
#    -- Batch 1/5 / Loss:  1.3689795
#    -- Batch 2/5 / Loss:  1.9212866
#    -- Batch 3/5 / Loss:  0.9693086
#    -- Batch 4/5 / Loss:  0.9654964
#    -- Batch 5/5 / Loss:  1.3522356
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.3154614}
#    Validation: {'loss': 19.130008506774903}
# Epoch 47/100
#    -- Batch 1/5 / Loss:  2.945489
#    -- Batch 2/5 / Loss:  1.4250969
#    -- Batch 3/5 / Loss:  2.2593558
#    -- Batch 4/5 / Loss:  1.0599092
#    -- Batch 5/5 / Loss:  1.2247982
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.78293}
#    Validation: {'loss': 19.39974400997162}
# Epoch 48/100
#    -- Batch 1/5 / Loss:  1.0735368
#    -- Batch 2/5 / Loss:  0.97639644
#    -- Batch 3/5 / Loss:  1.0617256
#    -- Batch 4/5 / Loss:  1.0219705
#    -- Batch 5/5 / Loss:  0.94633853
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.0159936}
#    Validation: {'loss': 19.26432867050171}
# Epoch 49/100
#    -- Batch 1/5 / Loss:  1.4509361
#    -- Batch 2/5 / Loss:  1.8237748
#    -- Batch 3/5 / Loss:  1.0139762
#    -- Batch 4/5 / Loss:  2.031492
#    -- Batch 5/5 / Loss:  1.456241
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.555284}
#    Validation: {'loss': 19.25570077896118}
# Epoch 50/100
#    -- Batch 1/5 / Loss:  1.9295257
#    -- Batch 2/5 / Loss:  2.5396922
#    -- Batch 3/5 / Loss:  1.2471007
#    -- Batch 4/5 / Loss:  0.9335479
#    -- Batch 5/5 / Loss:  0.9613581
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.5222449}
#    Validation: {'loss': 18.953551840782165}
# Epoch 51/100
#    -- Batch 1/5 / Loss:  1.1772163
#    -- Batch 2/5 / Loss:  5.834899
#    -- Batch 3/5 / Loss:  0.98338294
#    -- Batch 4/5 / Loss:  2.5197506
#    -- Batch 5/5 / Loss:  0.7786838
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 2.2587867}
#    Validation: {'loss': 18.59328179359436}
# Epoch 52/100
#    -- Batch 1/5 / Loss:  3.4491048
#    -- Batch 2/5 / Loss:  2.4694247
#    -- Batch 3/5 / Loss:  0.98448765
#    -- Batch 4/5 / Loss:  0.8119579
#    -- Batch 5/5 / Loss:  0.90874743
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.7247444}
#    Validation: {'loss': 20.18376522064209}
# Epoch 53/100
#    -- Batch 1/5 / Loss:  3.6161237
#    -- Batch 2/5 / Loss:  1.0815473
#    -- Batch 3/5 / Loss:  0.90982115
#    -- Batch 4/5 / Loss:  1.4443489
#    -- Batch 5/5 / Loss:  4.843063
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 2.3789806}
#    Validation: {'loss': 18.326925683021546}
# Epoch 54/100
#    -- Batch 1/5 / Loss:  2.0177104
#    -- Batch 2/5 / Loss:  2.3056583
#    -- Batch 3/5 / Loss:  2.777882
#    -- Batch 4/5 / Loss:  1.1437526
#    -- Batch 5/5 / Loss:  2.3227072
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 2.113542}
#    Validation: {'loss': 19.768930530548097}
# Epoch 55/100
#    -- Batch 1/5 / Loss:  0.99751484
#    -- Batch 2/5 / Loss:  2.1474433
#    -- Batch 3/5 / Loss:  1.2797701
#    -- Batch 4/5 / Loss:  2.720386
#    -- Batch 5/5 / Loss:  1.1816661
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.665356}
#    Validation: {'loss': 19.148754143714903}
# Epoch 56/100
#    -- Batch 1/5 / Loss:  1.5447873
#    -- Batch 2/5 / Loss:  5.5136623
#    -- Batch 3/5 / Loss:  3.991128
#    -- Batch 4/5 / Loss:  1.5837576
#    -- Batch 5/5 / Loss:  1.1404144
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 2.7547498}
#    Validation: {'loss': 19.28517210483551}
# Epoch 57/100
#    -- Batch 1/5 / Loss:  1.1891379
#    -- Batch 2/5 / Loss:  0.9267481
#    -- Batch 3/5 / Loss:  1.5509305
#    -- Batch 4/5 / Loss:  1.1913908
#    -- Batch 5/5 / Loss:  0.9543804
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.1625175}
#    Validation: {'loss': 19.22490861415863}
# Epoch 58/100
#    -- Batch 1/5 / Loss:  1.2729652
#    -- Batch 2/5 / Loss:  1.6370338
#    -- Batch 3/5 / Loss:  1.2354863
#    -- Batch 4/5 / Loss:  1.3089876
#    -- Batch 5/5 / Loss:  2.0202587
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.4949462}
#    Validation: {'loss': 19.960202264785767}
# Epoch 59/100
#    -- Batch 1/5 / Loss:  1.429981
#    -- Batch 2/5 / Loss:  1.0859716
#    -- Batch 3/5 / Loss:  0.8550713
#    -- Batch 4/5 / Loss:  1.5862279
#    -- Batch 5/5 / Loss:  2.5848489
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.5084201}
#    Validation: {'loss': 19.146764731407167}
# Epoch 60/100
#    -- Batch 1/5 / Loss:  1.0390244
#    -- Batch 2/5 / Loss:  1.5460455
#    -- Batch 3/5 / Loss:  1.3070652
#    -- Batch 4/5 / Loss:  1.1193085
#    -- Batch 5/5 / Loss:  0.9826207
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.1988128}
#    Validation: {'loss': 20.208440351486207}
# Epoch 61/100
#    -- Batch 1/5 / Loss:  3.966596
#    -- Batch 2/5 / Loss:  2.9869027
#    -- Batch 3/5 / Loss:  0.75216854
#    -- Batch 4/5 / Loss:  1.5436226
#    -- Batch 5/5 / Loss:  0.7212744
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.994113}
#    Validation: {'loss': 19.191819858551025}
# Epoch 62/100
#    -- Batch 1/5 / Loss:  2.5611567
#    -- Batch 2/5 / Loss:  0.7672956
#    -- Batch 3/5 / Loss:  0.8276304
#    -- Batch 4/5 / Loss:  0.968676
#    -- Batch 5/5 / Loss:  4.3505936
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.8950704}
#    Validation: {'loss': 19.8325257062912}
# Epoch 63/100
#    -- Batch 1/5 / Loss:  1.9755496
#    -- Batch 2/5 / Loss:  1.5633398
#    -- Batch 3/5 / Loss:  0.940305
#    -- Batch 4/5 / Loss:  3.3651867
#    -- Batch 5/5 / Loss:  2.3910909
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 2.0470943}
#    Validation: {'loss': 19.73252866268158}
# Epoch 64/100
#    -- Batch 1/5 / Loss:  1.1245731
#    -- Batch 2/5 / Loss:  0.7872075
#    -- Batch 3/5 / Loss:  2.3871548
#    -- Batch 4/5 / Loss:  2.3566234
#    -- Batch 5/5 / Loss:  1.4606581
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.6232433}
#    Validation: {'loss': 19.449998760223387}
# Epoch 65/100
#    -- Batch 1/5 / Loss:  0.7207955
#    -- Batch 2/5 / Loss:  0.77104604
#    -- Batch 3/5 / Loss:  1.142141
#    -- Batch 4/5 / Loss:  1.6660101
#    -- Batch 5/5 / Loss:  0.8195368
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.0239059}
#    Validation: {'loss': 19.039559412002564}
# Epoch 66/100
#    -- Batch 1/5 / Loss:  1.6151365
#    -- Batch 2/5 / Loss:  1.0345166
#    -- Batch 3/5 / Loss:  1.8203261
#    -- Batch 4/5 / Loss:  1.2003537
#    -- Batch 5/5 / Loss:  1.3833001
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.4107265}
#    Validation: {'loss': 19.483847284317015}
# Epoch 67/100
#    -- Batch 1/5 / Loss:  3.8352802
#    -- Batch 2/5 / Loss:  1.0596576
#    -- Batch 3/5 / Loss:  2.0833683
#    -- Batch 4/5 / Loss:  1.0177647
#    -- Batch 5/5 / Loss:  1.1912637
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.8374668}
#    Validation: {'loss': 19.33415925502777}
# Epoch 68/100
#    -- Batch 1/5 / Loss:  1.634195
#    -- Batch 2/5 / Loss:  0.5834842
#    -- Batch 3/5 / Loss:  0.7066432
#    -- Batch 4/5 / Loss:  0.68873966
#    -- Batch 5/5 / Loss:  1.0584738
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.9343071}
#    Validation: {'loss': 19.95120015144348}
# Epoch 69/100
#    -- Batch 1/5 / Loss:  1.0953999
#    -- Batch 2/5 / Loss:  1.145017
#    -- Batch 3/5 / Loss:  0.8296932
#    -- Batch 4/5 / Loss:  1.0257397
#    -- Batch 5/5 / Loss:  0.72059906
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.96328986}
#    Validation: {'loss': 19.0318562746048}
# Epoch 70/100
#    -- Batch 1/5 / Loss:  1.1618117
#    -- Batch 2/5 / Loss:  1.0106122
#    -- Batch 3/5 / Loss:  1.7568295
#    -- Batch 4/5 / Loss:  1.5230935
#    -- Batch 5/5 / Loss:  1.0024942
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.2909682}
#    Validation: {'loss': 19.558936190605163}
# Epoch 71/100
#    -- Batch 1/5 / Loss:  0.97955644
#    -- Batch 2/5 / Loss:  2.3970008
#    -- Batch 3/5 / Loss:  1.8364112
#    -- Batch 4/5 / Loss:  2.7520635
#    -- Batch 5/5 / Loss:  0.9186199
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.7767305}
#    Validation: {'loss': 19.805513405799864}
# Epoch 72/100
#    -- Batch 1/5 / Loss:  1.4647975
#    -- Batch 2/5 / Loss:  1.3427992
#    -- Batch 3/5 / Loss:  1.569137
#    -- Batch 4/5 / Loss:  1.0249987
#    -- Batch 5/5 / Loss:  0.76182425
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.2327113}
#    Validation: {'loss': 19.98956060409546}
# Epoch 73/100
#    -- Batch 1/5 / Loss:  2.02465
#    -- Batch 2/5 / Loss:  6.069886
#    -- Batch 3/5 / Loss:  0.6969496
#    -- Batch 4/5 / Loss:  1.2492759
#    -- Batch 5/5 / Loss:  1.9955926
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 2.407271}
#    Validation: {'loss': 19.468501329421997}
# Epoch 74/100
#    -- Batch 1/5 / Loss:  0.944407
#    -- Batch 2/5 / Loss:  1.2447388
#    -- Batch 3/5 / Loss:  1.5649036
#    -- Batch 4/5 / Loss:  1.9550126
#    -- Batch 5/5 / Loss:  0.74382764
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.2905779}
#    Validation: {'loss': 20.29252209663391}
# Epoch 75/100
#    -- Batch 1/5 / Loss:  1.0590899
#    -- Batch 2/5 / Loss:  0.79782116
#    -- Batch 3/5 / Loss:  0.7115042
#    -- Batch 4/5 / Loss:  0.8144066
#    -- Batch 5/5 / Loss:  0.9412184
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.8648081}
#    Validation: {'loss': 19.470297694206238}
# Epoch 76/100
#    -- Batch 1/5 / Loss:  1.3082438
#    -- Batch 2/5 / Loss:  0.72925043
#    -- Batch 3/5 / Loss:  0.7124636
#    -- Batch 4/5 / Loss:  0.55772793
#    -- Batch 5/5 / Loss:  1.8786733
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.0372719}
#    Validation: {'loss': 20.34966688156128}
# Epoch 77/100
#    -- Batch 1/5 / Loss:  0.96835
#    -- Batch 2/5 / Loss:  1.443917
#    -- Batch 3/5 / Loss:  0.8762463
#    -- Batch 4/5 / Loss:  0.7421049
#    -- Batch 5/5 / Loss:  1.2320993
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.0525434}
#    Validation: {'loss': 19.511771059036256}
# Epoch 78/100
#    -- Batch 1/5 / Loss:  0.7597399
#    -- Batch 2/5 / Loss:  0.66917634
#    -- Batch 3/5 / Loss:  0.91422343
#    -- Batch 4/5 / Loss:  1.5276855
#    -- Batch 5/5 / Loss:  0.7174321
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.9176515}
#    Validation: {'loss': 19.962552404403688}
# Epoch 79/100
#    -- Batch 1/5 / Loss:  0.8594729
#    -- Batch 2/5 / Loss:  0.7393633
#    -- Batch 3/5 / Loss:  1.5412562
#    -- Batch 4/5 / Loss:  1.0332155
#    -- Batch 5/5 / Loss:  0.75071
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.98480356}
#    Validation: {'loss': 19.512938475608827}
# Epoch 80/100
#    -- Batch 1/5 / Loss:  0.6402519
#    -- Batch 2/5 / Loss:  0.555017
#    -- Batch 3/5 / Loss:  0.7684367
#    -- Batch 4/5 / Loss:  0.96427643
#    -- Batch 5/5 / Loss:  0.6991781
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.72543204}
#    Validation: {'loss': 19.893782019615173}
# Epoch 81/100
#    -- Batch 1/5 / Loss:  0.93425894
#    -- Batch 2/5 / Loss:  0.82617235
#    -- Batch 3/5 / Loss:  1.0366256
#    -- Batch 4/5 / Loss:  0.75963485
#    -- Batch 5/5 / Loss:  0.80531037
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.8724004}
#    Validation: {'loss': 19.24894211292267}
# Epoch 82/100
#    -- Batch 1/5 / Loss:  0.5489477
#    -- Batch 2/5 / Loss:  0.5328735
#    -- Batch 3/5 / Loss:  3.8961005
#    -- Batch 4/5 / Loss:  3.4406674
#    -- Batch 5/5 / Loss:  0.7386044
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.8314387}
#    Validation: {'loss': 20.20419087409973}
# Epoch 83/100
#    -- Batch 1/5 / Loss:  0.9313375
#    -- Batch 2/5 / Loss:  1.3873532
#    -- Batch 3/5 / Loss:  2.4791548
#    -- Batch 4/5 / Loss:  1.2357358
#    -- Batch 5/5 / Loss:  0.73894227
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.3545048}
#    Validation: {'loss': 19.308580255508424}
# Epoch 84/100
#    -- Batch 1/5 / Loss:  0.5383803
#    -- Batch 2/5 / Loss:  1.2529302
#    -- Batch 3/5 / Loss:  0.71748686
#    -- Batch 4/5 / Loss:  0.63258195
#    -- Batch 5/5 / Loss:  1.3685932
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.9019945}
#    Validation: {'loss': 19.7486741065979}
# Epoch 85/100
#    -- Batch 1/5 / Loss:  0.715055
#    -- Batch 2/5 / Loss:  2.4751306
#    -- Batch 3/5 / Loss:  0.77203315
#    -- Batch 4/5 / Loss:  2.8794625
#    -- Batch 5/5 / Loss:  0.9380039
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.555937}
#    Validation: {'loss': 18.868323802947998}
# Epoch 86/100
#    -- Batch 1/5 / Loss:  1.6650808
#    -- Batch 2/5 / Loss:  0.76173395
#    -- Batch 3/5 / Loss:  1.7278297
#    -- Batch 4/5 / Loss:  0.9002638
#    -- Batch 5/5 / Loss:  0.8672209
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.1844258}
#    Validation: {'loss': 19.49241840839386}
# Epoch 87/100
#    -- Batch 1/5 / Loss:  1.5794156
#    -- Batch 2/5 / Loss:  0.93509513
#    -- Batch 3/5 / Loss:  0.617563
#    -- Batch 4/5 / Loss:  1.3254685
#    -- Batch 5/5 / Loss:  1.6254237
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.2165931}
#    Validation: {'loss': 19.426141333580016}
# Epoch 88/100
#    -- Batch 1/5 / Loss:  0.7859276
#    -- Batch 2/5 / Loss:  0.8297944
#    -- Batch 3/5 / Loss:  1.1496742
#    -- Batch 4/5 / Loss:  1.1686598
#    -- Batch 5/5 / Loss:  0.7820529
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.94322175}
#    Validation: {'loss': 19.357177782058717}
# Epoch 89/100
#    -- Batch 1/5 / Loss:  1.7827632
#    -- Batch 2/5 / Loss:  1.2538621
#    -- Batch 3/5 / Loss:  2.0700192
#    -- Batch 4/5 / Loss:  0.90283173
#    -- Batch 5/5 / Loss:  0.63333356
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.328562}
#    Validation: {'loss': 19.57935588359833}
# Epoch 90/100
#    -- Batch 1/5 / Loss:  1.0153661
#    -- Batch 2/5 / Loss:  0.66890264
#    -- Batch 3/5 / Loss:  1.7480505
#    -- Batch 4/5 / Loss:  0.85448825
#    -- Batch 5/5 / Loss:  0.7400272
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.0053669}
#    Validation: {'loss': 18.78193681240082}
# Epoch 91/100
#    -- Batch 1/5 / Loss:  3.1160104
#    -- Batch 2/5 / Loss:  1.0534532
#    -- Batch 3/5 / Loss:  0.78810453
#    -- Batch 4/5 / Loss:  1.4271021
#    -- Batch 5/5 / Loss:  0.98921084
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.4747763}
#    Validation: {'loss': 20.658842396736144}
# Epoch 92/100
#    -- Batch 1/5 / Loss:  2.0457597
#    -- Batch 2/5 / Loss:  0.9053703
#    -- Batch 3/5 / Loss:  0.58901626
#    -- Batch 4/5 / Loss:  0.58787316
#    -- Batch 5/5 / Loss:  2.2160702
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.2688179}
#    Validation: {'loss': 19.4482524394989}
# Epoch 93/100
#    -- Batch 1/5 / Loss:  1.0935344
#    -- Batch 2/5 / Loss:  1.2722182
#    -- Batch 3/5 / Loss:  0.88067526
#    -- Batch 4/5 / Loss:  0.7618603
#    -- Batch 5/5 / Loss:  1.1604309
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.0337439}
#    Validation: {'loss': 19.848208475112916}
# Epoch 94/100
#    -- Batch 1/5 / Loss:  0.6440115
#    -- Batch 2/5 / Loss:  0.69658923
#    -- Batch 3/5 / Loss:  1.6589878
#    -- Batch 4/5 / Loss:  1.0925605
#    -- Batch 5/5 / Loss:  0.629456
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.944321}
#    Validation: {'loss': 19.55235662460327}
# Epoch 95/100
#    -- Batch 1/5 / Loss:  1.2547123
#    -- Batch 2/5 / Loss:  0.5916201
#    -- Batch 3/5 / Loss:  0.9895461
#    -- Batch 4/5 / Loss:  0.8202305
#    -- Batch 5/5 / Loss:  0.7355001
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.8783218}
#    Validation: {'loss': 19.856417322158812}
# Epoch 96/100
#    -- Batch 1/5 / Loss:  0.67889273
#    -- Batch 2/5 / Loss:  0.9717345
#    -- Batch 3/5 / Loss:  0.58861566
#    -- Batch 4/5 / Loss:  0.69977
#    -- Batch 5/5 / Loss:  0.48262712
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.684328}
#    Validation: {'loss': 19.185772514343263}
# Epoch 97/100
#    -- Batch 1/5 / Loss:  0.9903697
#    -- Batch 2/5 / Loss:  0.8675747
#    -- Batch 3/5 / Loss:  0.6239203
#    -- Batch 4/5 / Loss:  1.2266699
#    -- Batch 5/5 / Loss:  1.2992615
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.0015593}
#    Validation: {'loss': 19.882841753959656}
# Epoch 98/100
#    -- Batch 1/5 / Loss:  0.40332237
#    -- Batch 2/5 / Loss:  1.540606
#    -- Batch 3/5 / Loss:  0.5070262
#    -- Batch 4/5 / Loss:  0.5849974
#    -- Batch 5/5 / Loss:  1.9214756
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.9914855}
#    Validation: {'loss': 18.69092149734497}
# Epoch 99/100
#    -- Batch 1/5 / Loss:  0.641009
#    -- Batch 2/5 / Loss:  0.9389867
#    -- Batch 3/5 / Loss:  1.4118115
#    -- Batch 4/5 / Loss:  2.5914779
#    -- Batch 5/5 / Loss:  0.9829432
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.3132455}
#    Validation: {'loss': 20.203979992866515}
# Epoch 100/100
#    -- Batch 1/5 / Loss:  0.7646795
#    -- Batch 2/5 / Loss:  0.5627384
#    -- Batch 3/5 / Loss:  1.5596458
#    -- Batch 4/5 / Loss:  1.0728819
#    -- Batch 5/5 / Loss:  0.9825252
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.9884941}
#    Validation: {'loss': 19.979094791412354}

# %%
plot_histories(train_history['loss'], val_history['loss'], label="Loss")
# plot_histories(train_history=None, val_history=val_history['f1'], label="F1 Score")
plt.show()

# %%
# Select a test image
x,y = test_set[0]
pred = evaluate_model_on_single_image(model, x)

# Plot the result
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 15))
ax1.set_title("True mask")
ax2.set_title("Predicted mask")
plot_image_with_segmentation(x, y, ax=ax1, model='rgb')
plot_image_with_segmentation(x, pred, ax=ax2, model='rgb')
plt.show()

# %%
mask_pred = pred[0][0].cpu()
plt.figure(figsize=(25,5))
plt.subplot(1,5,1)
plt.imshow(mask_pred > 0.0, cmap='gray')
plt.axis("off")
plt.subplot(1,5,2)
plt.imshow(mask_pred > -1.0, cmap='gray')
plt.axis("off")
plt.subplot(1,5,3)
plt.imshow(mask_pred > -2.0, cmap='gray')
plt.axis("off")
plt.subplot(1,5,4)
plt.imshow(mask_pred > -3.0, cmap='gray')
plt.axis("off")
plt.subplot(1,5,5)
plt.imshow(mask_pred > -4.0, cmap='gray')
plt.axis("off")
plt.show()

# %%
class ThresholdNet(nn.Module):
    def __init__(self, input_channels):
        super(ThresholdNet, self).__init__()
        # self.pool = nn.AdaptiveAvgPool2d(1)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(input_channels * 64 * 64, 128)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.relu(x)
        threshold = self.fc2(x)

        return threshold

# %%
class DynamicThresholdLayer(nn.Module):
    def __init__(self, input_channels):
        super(DynamicThresholdLayer, self).__init__()
        self.threshold_net = ThresholdNet(input_channels)

    def forward(self, x):
        threshold = self.threshold_net(x)
        # print(threshold)
        binary_mask = torch.tanh(x - threshold.view(-1, 1, 1, 1))
        # plt.imshow(binary_mask[0][0].cpu().detach().numpy()>0, cmap='gray')
        # plt.show()
        return binary_mask

# %%
model.segmentation_head = nn.Sequential(
    nn.Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
    nn.Identity(),
    DynamicThresholdLayer(1)
)

model.segmentation_head.to(device)
# Out:
# Sequential(
#   (0): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): Identity()
#   (2): DynamicThresholdLayer(
#     (threshold_net): ThresholdNet(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=4096, out_features=128, bias=True)
#       (relu): ReLU()
#       (fc2): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )

# %%
# 冻结所有层的参数，除了ThresholdNet
for name, param in model.named_parameters():
    if 'segmentation_head' in name:
        param.requires_grad = True
    else:
        param.requires_grad = False

# 检查冻结情况
for name, param in model.named_parameters():
    print(name, param.requires_grad)

# 确保模型正确添加并其他层已冻结
print(model)
# Out:
# encoder._conv_stem.weight False
# encoder._bn0.weight False
# encoder._bn0.bias False
# encoder._blocks.0._depthwise_conv.weight False
# encoder._blocks.0._bn1.weight False
# encoder._blocks.0._bn1.bias False
# encoder._blocks.0._se_reduce.weight False
# encoder._blocks.0._se_reduce.bias False
# encoder._blocks.0._se_expand.weight False
# encoder._blocks.0._se_expand.bias False
# encoder._blocks.0._project_conv.weight False
# encoder._blocks.0._bn2.weight False
# encoder._blocks.0._bn2.bias False
# encoder._blocks.1._expand_conv.weight False
# encoder._blocks.1._bn0.weight False
# encoder._blocks.1._bn0.bias False
# encoder._blocks.1._depthwise_conv.weight False
# encoder._blocks.1._bn1.weight False
# encoder._blocks.1._bn1.bias False
# encoder._blocks.1._se_reduce.weight False
# encoder._blocks.1._se_reduce.bias False
# encoder._blocks.1._se_expand.weight False
# encoder._blocks.1._se_expand.bias False
# encoder._blocks.1._project_conv.weight False
# encoder._blocks.1._bn2.weight False
# encoder._blocks.1._bn2.bias False
# encoder._blocks.2._expand_conv.weight False
# encoder._blocks.2._bn0.weight False
# encoder._blocks.2._bn0.bias False
# encoder._blocks.2._depthwise_conv.weight False
# encoder._blocks.2._bn1.weight False
# encoder._blocks.2._bn1.bias False
# encoder._blocks.2._se_reduce.weight False
# encoder._blocks.2._se_reduce.bias False
# encoder._blocks.2._se_expand.weight False
# encoder._blocks.2._se_expand.bias False
# encoder._blocks.2._project_conv.weight False
# encoder._blocks.2._bn2.weight False
# encoder._blocks.2._bn2.bias False
# encoder._blocks.3._expand_conv.weight False
# encoder._blocks.3._bn0.weight False
# encoder._blocks.3._bn0.bias False
# encoder._blocks.3._depthwise_conv.weight False
# encoder._blocks.3._bn1.weight False
# encoder._blocks.3._bn1.bias False
# encoder._blocks.3._se_reduce.weight False
# encoder._blocks.3._se_reduce.bias False
# encoder._blocks.3._se_expand.weight False
# encoder._blocks.3._se_expand.bias False
# encoder._blocks.3._project_conv.weight False
# encoder._blocks.3._bn2.weight False
# encoder._blocks.3._bn2.bias False
# encoder._blocks.4._expand_conv.weight False
# encoder._blocks.4._bn0.weight False
# encoder._blocks.4._bn0.bias False
# encoder._blocks.4._depthwise_conv.weight False
# encoder._blocks.4._bn1.weight False
# encoder._blocks.4._bn1.bias False
# encoder._blocks.4._se_reduce.weight False
# encoder._blocks.4._se_reduce.bias False
# encoder._blocks.4._se_expand.weight False
# encoder._blocks.4._se_expand.bias False
# encoder._blocks.4._project_conv.weight False
# encoder._blocks.4._bn2.weight False
# encoder._blocks.4._bn2.bias False
# encoder._blocks.5._expand_conv.weight False
# encoder._blocks.5._bn0.weight False
# encoder._blocks.5._bn0.bias False
# encoder._blocks.5._depthwise_conv.weight False
# encoder._blocks.5._bn1.weight False
# encoder._blocks.5._bn1.bias False
# encoder._blocks.5._se_reduce.weight False
# encoder._blocks.5._se_reduce.bias False
# encoder._blocks.5._se_expand.weight False
# encoder._blocks.5._se_expand.bias False
# encoder._blocks.5._project_conv.weight False
# encoder._blocks.5._bn2.weight False
# encoder._blocks.5._bn2.bias False
# encoder._blocks.6._expand_conv.weight False
# encoder._blocks.6._bn0.weight False
# encoder._blocks.6._bn0.bias False
# encoder._blocks.6._depthwise_conv.weight False
# encoder._blocks.6._bn1.weight False
# encoder._blocks.6._bn1.bias False
# encoder._blocks.6._se_reduce.weight False
# encoder._blocks.6._se_reduce.bias False
# encoder._blocks.6._se_expand.weight False
# encoder._blocks.6._se_expand.bias False
# encoder._blocks.6._project_conv.weight False
# encoder._blocks.6._bn2.weight False
# encoder._blocks.6._bn2.bias False
# encoder._blocks.7._expand_conv.weight False
# encoder._blocks.7._bn0.weight False
# encoder._blocks.7._bn0.bias False
# encoder._blocks.7._depthwise_conv.weight False
# encoder._blocks.7._bn1.weight False
# encoder._blocks.7._bn1.bias False
# encoder._blocks.7._se_reduce.weight False
# encoder._blocks.7._se_reduce.bias False
# encoder._blocks.7._se_expand.weight False
# encoder._blocks.7._se_expand.bias False
# encoder._blocks.7._project_conv.weight False
# encoder._blocks.7._bn2.weight False
# encoder._blocks.7._bn2.bias False
# encoder._blocks.8._expand_conv.weight False
# encoder._blocks.8._bn0.weight False
# encoder._blocks.8._bn0.bias False
# encoder._blocks.8._depthwise_conv.weight False
# encoder._blocks.8._bn1.weight False
# encoder._blocks.8._bn1.bias False
# encoder._blocks.8._se_reduce.weight False
# encoder._blocks.8._se_reduce.bias False
# encoder._blocks.8._se_expand.weight False
# encoder._blocks.8._se_expand.bias False
# encoder._blocks.8._project_conv.weight False
# encoder._blocks.8._bn2.weight False
# encoder._blocks.8._bn2.bias False
# encoder._blocks.9._expand_conv.weight False
# encoder._blocks.9._bn0.weight False
# encoder._blocks.9._bn0.bias False
# encoder._blocks.9._depthwise_conv.weight False
# encoder._blocks.9._bn1.weight False
# encoder._blocks.9._bn1.bias False
# encoder._blocks.9._se_reduce.weight False
# encoder._blocks.9._se_reduce.bias False
# encoder._blocks.9._se_expand.weight False
# encoder._blocks.9._se_expand.bias False
# encoder._blocks.9._project_conv.weight False
# encoder._blocks.9._bn2.weight False
# encoder._blocks.9._bn2.bias False
# encoder._blocks.10._expand_conv.weight False
# encoder._blocks.10._bn0.weight False
# encoder._blocks.10._bn0.bias False
# encoder._blocks.10._depthwise_conv.weight False
# encoder._blocks.10._bn1.weight False
# encoder._blocks.10._bn1.bias False
# encoder._blocks.10._se_reduce.weight False
# encoder._blocks.10._se_reduce.bias False
# encoder._blocks.10._se_expand.weight False
# encoder._blocks.10._se_expand.bias False
# encoder._blocks.10._project_conv.weight False
# encoder._blocks.10._bn2.weight False
# encoder._blocks.10._bn2.bias False
# encoder._blocks.11._expand_conv.weight False
# encoder._blocks.11._bn0.weight False
# encoder._blocks.11._bn0.bias False
# encoder._blocks.11._depthwise_conv.weight False
# encoder._blocks.11._bn1.weight False
# encoder._blocks.11._bn1.bias False
# encoder._blocks.11._se_reduce.weight False
# encoder._blocks.11._se_reduce.bias False
# encoder._blocks.11._se_expand.weight False
# encoder._blocks.11._se_expand.bias False
# encoder._blocks.11._project_conv.weight False
# encoder._blocks.11._bn2.weight False
# encoder._blocks.11._bn2.bias False
# encoder._blocks.12._expand_conv.weight False
# encoder._blocks.12._bn0.weight False
# encoder._blocks.12._bn0.bias False
# encoder._blocks.12._depthwise_conv.weight False
# encoder._blocks.12._bn1.weight False
# encoder._blocks.12._bn1.bias False
# encoder._blocks.12._se_reduce.weight False
# encoder._blocks.12._se_reduce.bias False
# encoder._blocks.12._se_expand.weight False
# encoder._blocks.12._se_expand.bias False
# encoder._blocks.12._project_conv.weight False
# encoder._blocks.12._bn2.weight False
# encoder._blocks.12._bn2.bias False
# encoder._blocks.13._expand_conv.weight False
# encoder._blocks.13._bn0.weight False
# encoder._blocks.13._bn0.bias False
# encoder._blocks.13._depthwise_conv.weight False
# encoder._blocks.13._bn1.weight False
# encoder._blocks.13._bn1.bias False
# encoder._blocks.13._se_reduce.weight False
# encoder._blocks.13._se_reduce.bias False
# encoder._blocks.13._se_expand.weight False
# encoder._blocks.13._se_expand.bias False
# encoder._blocks.13._project_conv.weight False
# encoder._blocks.13._bn2.weight False
# encoder._blocks.13._bn2.bias False
# encoder._blocks.14._expand_conv.weight False
# encoder._blocks.14._bn0.weight False
# encoder._blocks.14._bn0.bias False
# encoder._blocks.14._depthwise_conv.weight False
# encoder._blocks.14._bn1.weight False
# encoder._blocks.14._bn1.bias False
# encoder._blocks.14._se_reduce.weight False
# encoder._blocks.14._se_reduce.bias False
# encoder._blocks.14._se_expand.weight False
# encoder._blocks.14._se_expand.bias False
# encoder._blocks.14._project_conv.weight False
# encoder._blocks.14._bn2.weight False
# encoder._blocks.14._bn2.bias False
# encoder._blocks.15._expand_conv.weight False
# encoder._blocks.15._bn0.weight False
# encoder._blocks.15._bn0.bias False
# encoder._blocks.15._depthwise_conv.weight False
# encoder._blocks.15._bn1.weight False
# encoder._blocks.15._bn1.bias False
# encoder._blocks.15._se_reduce.weight False
# encoder._blocks.15._se_reduce.bias False
# encoder._blocks.15._se_expand.weight False
# encoder._blocks.15._se_expand.bias False
# encoder._blocks.15._project_conv.weight False
# encoder._blocks.15._bn2.weight False
# encoder._blocks.15._bn2.bias False
# encoder._conv_head.weight False
# encoder._bn1.weight False
# encoder._bn1.bias False
# decoder.blocks.0.conv1.0.weight False
# decoder.blocks.0.conv1.1.weight False
# decoder.blocks.0.conv1.1.bias False
# decoder.blocks.0.conv2.0.weight False
# decoder.blocks.0.conv2.1.weight False
# decoder.blocks.0.conv2.1.bias False
# decoder.blocks.1.conv1.0.weight False
# decoder.blocks.1.conv1.1.weight False
# decoder.blocks.1.conv1.1.bias False
# decoder.blocks.1.conv2.0.weight False
# decoder.blocks.1.conv2.1.weight False
# decoder.blocks.1.conv2.1.bias False
# decoder.blocks.2.conv1.0.weight False
# decoder.blocks.2.conv1.1.weight False
# decoder.blocks.2.conv1.1.bias False
# decoder.blocks.2.conv2.0.weight False
# decoder.blocks.2.conv2.1.weight False
# decoder.blocks.2.conv2.1.bias False
# decoder.blocks.3.conv1.0.weight False
# decoder.blocks.3.conv1.1.weight False
# decoder.blocks.3.conv1.1.bias False
# decoder.blocks.3.conv2.0.weight False
# decoder.blocks.3.conv2.1.weight False
# decoder.blocks.3.conv2.1.bias False
# decoder.blocks.4.conv1.0.weight False
# decoder.blocks.4.conv1.1.weight False
# decoder.blocks.4.conv1.1.bias False
# decoder.blocks.4.conv2.0.weight False
# decoder.blocks.4.conv2.1.weight False
# decoder.blocks.4.conv2.1.bias False
# segmentation_head.0.weight True
# segmentation_head.0.bias True
# segmentation_head.2.threshold_net.fc1.weight True
# segmentation_head.2.threshold_net.fc1.bias True
# segmentation_head.2.threshold_net.fc2.weight True
# segmentation_head.2.threshold_net.fc2.bias True
# Unet(
#   (encoder): EfficientNetEncoder(
#     (_conv_stem): Conv2dStaticSamePadding(
#       3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#       (static_padding): ZeroPad2d((0, 1, 0, 1))
#     )
#     (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (_blocks): ModuleList(
#       (0): MBConvBlock(
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           32, 8, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           8, 32, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (1): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#           (static_padding): ZeroPad2d((0, 1, 0, 1))
#         )
#         (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           96, 4, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           4, 96, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (2): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           144, 6, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           6, 144, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (3): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#           (static_padding): ZeroPad2d((1, 2, 1, 2))
#         )
#         (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           144, 6, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           6, 144, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (4): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           240, 10, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           10, 240, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (5): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           240, 240, kernel_size=(3, 3), stride=[2, 2], groups=240, bias=False
#           (static_padding): ZeroPad2d((0, 1, 0, 1))
#         )
#         (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           240, 10, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           10, 240, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (6-7): 2 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           480, 20, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           20, 480, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (8): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           480, 480, kernel_size=(5, 5), stride=[1, 1], groups=480, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           480, 20, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           20, 480, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (9-10): 2 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           672, 28, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           28, 672, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (11): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           672, 672, kernel_size=(5, 5), stride=[2, 2], groups=672, bias=False
#           (static_padding): ZeroPad2d((1, 2, 1, 2))
#         )
#         (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           672, 28, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           28, 672, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (12-14): 3 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1152, 48, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           48, 1152, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (15): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1152, 1152, kernel_size=(3, 3), stride=[1, 1], groups=1152, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1152, 48, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           48, 1152, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#     )
#     (_conv_head): Conv2dStaticSamePadding(
#       320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn1): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#     (_dropout): Dropout(p=0.2, inplace=False)
#     (_swish): MemoryEfficientSwish()
#   )
#   (decoder): UnetDecoder(
#     (center): Identity()
#     (blocks): ModuleList(
#       (0): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(432, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (1): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(296, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (2): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(152, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (3): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (4): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#     )
#   )
#   (segmentation_head): Sequential(
#     (0): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Identity()
#     (2): DynamicThresholdLayer(
#       (threshold_net): ThresholdNet(
#         (flatten): Flatten(start_dim=1, end_dim=-1)
#         (fc1): Linear(in_features=4096, out_features=128, bias=True)
#         (relu): ReLU()
#         (fc2): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#   )
# )

# %%
train_set_tda = DriveDataset(data_path, data_type="training", crop_size=crop_size, padding = padding, enable_sdf = False)
test_set_tda = DriveDataset(data_path, data_type="test", crop_size=crop_size, padding = padding, enable_sdf = False)

print(len(train_set_tda))
print(len(test_set_tda))

train_loader_tda = DataLoader(train_set_tda, batch_size=batch_size, shuffle=True)
test_loader_tda = DataLoader(test_set_tda, batch_size=1, shuffle=False)
# Out:
# 20
# 20

# %%
# Define loss and metrics
loss_1 = torch.nn.MSELoss(reduction="mean")
loss_2 = persistence_loss()

# Define optimizer
optimizer = torch.optim.Adam(model.segmentation_head.parameters(), lr=0.0001)

# metrics = {"f1": torchmetrics.classification.F1Score(task='binary', num_classes=1, average="macro", mdmc_average="samplewise")}
metrics = {}

# %%
# Run training
train_history, val_history = training_loop(
    model=model,
    loss=[loss_1, loss_2],
    optimizer=optimizer,
    train_loader=train_loader_tda,
    val_loader=test_loader_tda,
    init_epoch=init_epoch,
    n_epochs=150,
    metrics_dict=metrics,
    save_path="unet_with_threshold.ckpt",
    alpha=1.
)
# Out:
# Epoch 1/150
#    -- Batch 1/5 / Loss:  0.30849695
#    -- Batch 2/5 / Loss:  0.3313766
#    -- Batch 3/5 / Loss:  0.22410107
#    -- Batch 4/5 / Loss:  0.25681716
#    -- Batch 5/5 / Loss:  0.20753822
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.265666}
#    Validation: {'loss': 0.21962599828839302}
# Epoch 2/150
#    -- Batch 1/5 / Loss:  0.20413664
#    -- Batch 2/5 / Loss:  0.19583538
#    -- Batch 3/5 / Loss:  0.24259883
#    -- Batch 4/5 / Loss:  0.24135605
#    -- Batch 5/5 / Loss:  0.2585659
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.22849855}
#    Validation: {'loss': 0.21409392394125462}
# Epoch 3/150
#    -- Batch 1/5 / Loss:  0.24628755
#    -- Batch 2/5 / Loss:  0.21245667
#    -- Batch 3/5 / Loss:  0.1637985
#    -- Batch 4/5 / Loss:  0.21019566
#    -- Batch 5/5 / Loss:  0.20060986
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20666966}
#    Validation: {'loss': 0.19213659614324569}
# Epoch 4/150
#    -- Batch 1/5 / Loss:  0.2303143
#    -- Batch 2/5 / Loss:  0.20041102
#    -- Batch 3/5 / Loss:  0.16513038
#    -- Batch 4/5 / Loss:  0.17995733
#    -- Batch 5/5 / Loss:  0.1705365
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.18926992}
#    Validation: {'loss': 0.1827602431178093}
# Epoch 5/150
#    -- Batch 1/5 / Loss:  0.17719209
#    -- Batch 2/5 / Loss:  0.19493255
#    -- Batch 3/5 / Loss:  0.18932524
#    -- Batch 4/5 / Loss:  0.1890951
#    -- Batch 5/5 / Loss:  0.14912447
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17993388}
#    Validation: {'loss': 0.17163366861641408}
# Epoch 6/150
#    -- Batch 1/5 / Loss:  0.14020476
#    -- Batch 2/5 / Loss:  0.17598486
#    -- Batch 3/5 / Loss:  0.18875891
#    -- Batch 4/5 / Loss:  0.16160463
#    -- Batch 5/5 / Loss:  0.16414517
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16613966}
#    Validation: {'loss': 0.16280806735157966}
# Epoch 7/150
#    -- Batch 1/5 / Loss:  0.17361784
#    -- Batch 2/5 / Loss:  0.14937794
#    -- Batch 3/5 / Loss:  0.17905082
#    -- Batch 4/5 / Loss:  0.15739647
#    -- Batch 5/5 / Loss:  0.116892904
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1552672}
#    Validation: {'loss': 0.15527419485151767}
# Epoch 8/150
#    -- Batch 1/5 / Loss:  0.14781284
#    -- Batch 2/5 / Loss:  0.15670729
#    -- Batch 3/5 / Loss:  0.15312955
#    -- Batch 4/5 / Loss:  0.14723392
#    -- Batch 5/5 / Loss:  0.1320093
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1473786}
#    Validation: {'loss': 0.1489375477656722}
# Epoch 9/150
#    -- Batch 1/5 / Loss:  0.14062983
#    -- Batch 2/5 / Loss:  0.11842563
#    -- Batch 3/5 / Loss:  0.13776278
#    -- Batch 4/5 / Loss:  0.14824302
#    -- Batch 5/5 / Loss:  0.1728439
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10265275}
#    Validation: {'loss': 0.11708629168570042}
# Epoch 20/150
#    -- Batch 1/5 / Loss:  0.11584228
#    -- Batch 2/5 / Loss:  0.11678195
#    -- Batch 3/5 / Loss:  0.08882584
#    -- Batch 4/5 / Loss:  0.09113606
#    -- Batch 5/5 / Loss:  0.09147751
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10081272}
#    Validation: {'loss': 0.11568507812917232}
# Epoch 21/150
#    -- Batch 1/5 / Loss:  0.10574518
#    -- Batch 2/5 / Loss:  0.11530045
#    -- Batch 3/5 / Loss:  0.089459926
#    -- Batch 4/5 / Loss:  0.09968288
#    -- Batch 5/5 / Loss:  0.09105873
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10024943}
#    Validation: {'loss': 0.11388887576758862}
# Epoch 22/150
#    -- Batch 1/5 / Loss:  0.08541993
#    -- Batch 2/5 / Loss:  0.0951576
#    -- Batch 3/5 / Loss:  0.097033024
#    -- Batch 4/5 / Loss:  0.1077871
#    -- Batch 5/5 / Loss:  0.10789871
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09865927}
#    Validation: {'loss': 0.11340822800993919}
# Epoch 23/150
#    -- Batch 1/5 / Loss:  0.09304316
#    -- Batch 2/5 / Loss:  0.09478247
#    -- Batch 3/5 / Loss:  0.10287851
#    -- Batch 4/5 / Loss:  0.09226653
#    -- Batch 5/5 / Loss:  0.093419015
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.095277935}
#    Validation: {'loss': 0.11156844794750213}
# Epoch 24/150
#    -- Batch 1/5 / Loss:  0.089184664
#    -- Batch 2/5 / Loss:  0.09040414
#    -- Batch 3/5 / Loss:  0.11271745
#    -- Batch 4/5 / Loss:  0.08981469
#    -- Batch 5/5 / Loss:  0.09313477
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09505114}
#    Validation: {'loss': 0.11017358005046844}
# Epoch 25/150
#    -- Batch 1/5 / Loss:  0.097469635
#    -- Batch 2/5 / Loss:  0.095930085
#    -- Batch 3/5 / Loss:  0.093063615
#    -- Batch 4/5 / Loss:  0.088435024
#    -- Batch 5/5 / Loss:  0.07865274
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09071022}
#    Validation: {'loss': 0.10912746898829936}
# Epoch 26/150
#    -- Batch 1/5 / Loss:  0.08824377
#    -- Batch 2/5 / Loss:  0.09290242
#    -- Batch 3/5 / Loss:  0.08881133
#    -- Batch 4/5 / Loss:  0.08961122
#    -- Batch 5/5 / Loss:  0.08864593
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08964293}
#    Validation: {'loss': 0.1080987237393856}
# Epoch 27/150
#    -- Batch 1/5 / Loss:  0.08900167
#    -- Batch 2/5 / Loss:  0.07863406
#    -- Batch 3/5 / Loss:  0.08759235
#    -- Batch 4/5 / Loss:  0.114850014
#    -- Batch 5/5 / Loss:  0.082564354
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.090528496}
#    Validation: {'loss': 0.10707371719181538}
# Epoch 28/150
#    -- Batch 1/5 / Loss:  0.09088223
#    -- Batch 2/5 / Loss:  0.09475966
#    -- Batch 3/5 / Loss:  0.089294836
#    -- Batch 4/5 / Loss:  0.0824596
#    -- Batch 5/5 / Loss:  0.08050342
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08757995}
#    Validation: {'loss': 0.1057600237429142}
# Epoch 29/150
#    -- Batch 1/5 / Loss:  0.07407507
#    -- Batch 2/5 / Loss:  0.10359517
#    -- Batch 3/5 / Loss:  0.09175127
#    -- Batch 4/5 / Loss:  0.08739374
#    -- Batch 5/5 / Loss:  0.08453359
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08826977}
#    Validation: {'loss': 0.1054093673825264}
# Epoch 30/150
#    -- Batch 1/5 / Loss:  0.08028525
#    -- Batch 2/5 / Loss:  0.0931504
#    -- Batch 3/5 / Loss:  0.08060529
#    -- Batch 4/5 / Loss:  0.09075664
#    -- Batch 5/5 / Loss:  0.090024166
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.086964354}
#    Validation: {'loss': 0.1037751067429781}
# Epoch 31/150
#    -- Batch 1/5 / Loss:  0.084196866
#    -- Batch 2/5 / Loss:  0.08105612
#    -- Batch 3/5 / Loss:  0.08558511
#    -- Batch 4/5 / Loss:  0.095640525
#    -- Batch 5/5 / Loss:  0.07652978
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.084601685}
#    Validation: {'loss': 0.10329512022435665}
# Epoch 32/150
#    -- Batch 1/5 / Loss:  0.083719
#    -- Batch 2/5 / Loss:  0.080362104
#    -- Batch 3/5 / Loss:  0.08019153
#    -- Batch 4/5 / Loss:  0.09209184
#    -- Batch 5/5 / Loss:  0.07878883
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.083030656}
#    Validation: {'loss': 0.10272268913686275}
# Epoch 33/150
#    -- Batch 1/5 / Loss:  0.07764959
#    -- Batch 2/5 / Loss:  0.08341181
#    -- Batch 3/5 / Loss:  0.10378015
#    -- Batch 4/5 / Loss:  0.07486062
#    -- Batch 5/5 / Loss:  0.079600036
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08386044}
#    Validation: {'loss': 0.10212212949991226}
# Epoch 34/150
#    -- Batch 1/5 / Loss:  0.07558562
#    -- Batch 2/5 / Loss:  0.073855445
#    -- Batch 3/5 / Loss:  0.08636543
#    -- Batch 4/5 / Loss:  0.105145656
#    -- Batch 5/5 / Loss:  0.079285234
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08404748}
#    Validation: {'loss': 0.10093684829771518}
# Epoch 35/150
#    -- Batch 1/5 / Loss:  0.07422674
#    -- Batch 2/5 / Loss:  0.09040054
#    -- Batch 3/5 / Loss:  0.07834147
#    -- Batch 4/5 / Loss:  0.09286242
#    -- Batch 5/5 / Loss:  0.07751975
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08267018}
#    Validation: {'loss': 0.10047308877110481}
# Epoch 36/150
#    -- Batch 1/5 / Loss:  0.07513102
#    -- Batch 2/5 / Loss:  0.07332726
#    -- Batch 3/5 / Loss:  0.0776515
#    -- Batch 4/5 / Loss:  0.08338551
#    -- Batch 5/5 / Loss:  0.07965486
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07783003}
#    Validation: {'loss': 0.10064856335520744}
# Epoch 37/150
#    -- Batch 1/5 / Loss:  0.07392822
#    -- Batch 2/5 / Loss:  0.080773965
#    -- Batch 3/5 / Loss:  0.07201214
#    -- Batch 4/5 / Loss:  0.0952573
#    -- Batch 5/5 / Loss:  0.076764226
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07974717}
#    Validation: {'loss': 0.09929410740733147}
# Epoch 38/150
#    -- Batch 1/5 / Loss:  0.080766134
#    -- Batch 2/5 / Loss:  0.070663095
#    -- Batch 3/5 / Loss:  0.072255604
#    -- Batch 4/5 / Loss:  0.09452458
#    -- Batch 5/5 / Loss:  0.078115195
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.079264924}
#    Validation: {'loss': 0.09815713800489903}
# Epoch 39/150
#    -- Batch 1/5 / Loss:  0.08675293
#    -- Batch 2/5 / Loss:  0.06915115
#    -- Batch 3/5 / Loss:  0.07690574
#    -- Batch 4/5 / Loss:  0.07238448
#    -- Batch 5/5 / Loss:  0.07834768
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0767084}
#    Validation: {'loss': 0.09959203936159611}
# Epoch 40/150
#    -- Batch 1/5 / Loss:  0.087064594
#    -- Batch 2/5 / Loss:  0.076785415
#    -- Batch 3/5 / Loss:  0.070105106
#    -- Batch 4/5 / Loss:  0.07508078
#    -- Batch 5/5 / Loss:  0.07121276
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07604973}
#    Validation: {'loss': 0.09845259003341197}
# Epoch 41/150
#    -- Batch 1/5 / Loss:  0.08269665
#    -- Batch 2/5 / Loss:  0.07160324
#    -- Batch 3/5 / Loss:  0.08066567
#    -- Batch 4/5 / Loss:  0.07191619
#    -- Batch 5/5 / Loss:  0.06842157
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.075060666}
#    Validation: {'loss': 0.0967453233897686}
# Epoch 42/150
#    -- Batch 1/5 / Loss:  0.077283874
#    -- Batch 2/5 / Loss:  0.06983237
#    -- Batch 3/5 / Loss:  0.07731221
#    -- Batch 4/5 / Loss:  0.07505236
#    -- Batch 5/5 / Loss:  0.06853925
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07360401}
#    Validation: {'loss': 0.09632145278155804}
# Epoch 43/150
#    -- Batch 1/5 / Loss:  0.0631833
#    -- Batch 2/5 / Loss:  0.08159426
#    -- Batch 3/5 / Loss:  0.069355324
#    -- Batch 4/5 / Loss:  0.07035424
#    -- Batch 5/5 / Loss:  0.075309016
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07195923}
#    Validation: {'loss': 0.09659165851771831}
# Epoch 44/150
#    -- Batch 1/5 / Loss:  0.06679499
#    -- Batch 2/5 / Loss:  0.08444562
#    -- Batch 3/5 / Loss:  0.07780038
#    -- Batch 4/5 / Loss:  0.08047495
#    -- Batch 5/5 / Loss:  0.07398416
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07670002}
#    Validation: {'loss': 0.09535282775759697}
# Epoch 45/150
#    -- Batch 1/5 / Loss:  0.07447555
#    -- Batch 2/5 / Loss:  0.06885666
#    -- Batch 3/5 / Loss:  0.06929311
#    -- Batch 4/5 / Loss:  0.08538695
#    -- Batch 5/5 / Loss:  0.070636675
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07372979}
#    Validation: {'loss': 0.09496961422264576}
# Epoch 46/150
#    -- Batch 1/5 / Loss:  0.06974095
#    -- Batch 2/5 / Loss:  0.08802344
#    -- Batch 3/5 / Loss:  0.06622493
#    -- Batch 4/5 / Loss:  0.07488024
#    -- Batch 5/5 / Loss:  0.062842466
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0723424}
#    Validation: {'loss': 0.09355616644024849}
# Epoch 47/150
#    -- Batch 1/5 / Loss:  0.06934759
#    -- Batch 2/5 / Loss:  0.06506193
#    -- Batch 3/5 / Loss:  0.06853468
#    -- Batch 4/5 / Loss:  0.069279805
#    -- Batch 5/5 / Loss:  0.07114455
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.068673715}
#    Validation: {'loss': 0.09342393353581428}
# Epoch 48/150
#    -- Batch 1/5 / Loss:  0.082421385
#    -- Batch 2/5 / Loss:  0.06777747
#    -- Batch 3/5 / Loss:  0.07125451
#    -- Batch 4/5 / Loss:  0.06832291
#    -- Batch 5/5 / Loss:  0.06579666
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.071114585}
#    Validation: {'loss': 0.09353112690150737}
# Epoch 49/150
#    -- Batch 1/5 / Loss:  0.08661177
#    -- Batch 2/5 / Loss:  0.0705494
#    -- Batch 3/5 / Loss:  0.06728424
#    -- Batch 4/5 / Loss:  0.065602444
#    -- Batch 5/5 / Loss:  0.063125305
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07063463}
#    Validation: {'loss': 0.09340877011418343}
# Epoch 50/150
#    -- Batch 1/5 / Loss:  0.08506814
#    -- Batch 2/5 / Loss:  0.061948508
#    -- Batch 3/5 / Loss:  0.083903745
#    -- Batch 4/5 / Loss:  0.06359275
#    -- Batch 5/5 / Loss:  0.08650698
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.076204024}
#    Validation: {'loss': 0.09237675629556179}
# Epoch 51/150
#    -- Batch 1/5 / Loss:  0.06520042
#    -- Batch 2/5 / Loss:  0.08544746
#    -- Batch 3/5 / Loss:  0.071723685
#    -- Batch 4/5 / Loss:  0.061870337
#    -- Batch 5/5 / Loss:  0.0667336
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0701951}
#    Validation: {'loss': 0.09292053431272507}
# Epoch 52/150
#    -- Batch 1/5 / Loss:  0.06833631
#    -- Batch 2/5 / Loss:  0.064544424
#    -- Batch 3/5 / Loss:  0.066650644
#    -- Batch 4/5 / Loss:  0.06043897
#    -- Batch 5/5 / Loss:  0.079063855
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06780684}
#    Validation: {'loss': 0.09293239861726761}
# Epoch 53/150
#    -- Batch 1/5 / Loss:  0.07530907
#    -- Batch 2/5 / Loss:  0.06773952
#    -- Batch 3/5 / Loss:  0.063554265
#    -- Batch 4/5 / Loss:  0.07591012
#    -- Batch 5/5 / Loss:  0.06055336
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06861327}
#    Validation: {'loss': 0.09119031764566898}
# Epoch 54/150
#    -- Batch 1/5 / Loss:  0.062372223
#    -- Batch 2/5 / Loss:  0.06465859
#    -- Batch 3/5 / Loss:  0.05884202
#    -- Batch 4/5 / Loss:  0.08179565
#    -- Batch 5/5 / Loss:  0.06467533
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06646876}
#    Validation: {'loss': 0.09126570709049701}
# Epoch 55/150
#    -- Batch 1/5 / Loss:  0.06748177
#    -- Batch 2/5 / Loss:  0.07345851
#    -- Batch 3/5 / Loss:  0.05795134
#    -- Batch 4/5 / Loss:  0.059135027
#    -- Batch 5/5 / Loss:  0.07031007
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.065667346}
#    Validation: {'loss': 0.09135498516261578}
# Epoch 56/150
#    -- Batch 1/5 / Loss:  0.074220955
#    -- Batch 2/5 / Loss:  0.06756115
#    -- Batch 3/5 / Loss:  0.06180219
#    -- Batch 4/5 / Loss:  0.06129121
#    -- Batch 5/5 / Loss:  0.06858468
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06669204}
#    Validation: {'loss': 0.09153370708227157}
# Epoch 57/150
#    -- Batch 1/5 / Loss:  0.073354766
#    -- Batch 2/5 / Loss:  0.06671956
#    -- Batch 3/5 / Loss:  0.06300362
#    -- Batch 4/5 / Loss:  0.06518105
#    -- Batch 5/5 / Loss:  0.09087171
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06696742}
#    Validation: {'loss': 0.08897770326584578}
# Epoch 68/150
#    -- Batch 1/5 / Loss:  0.058638874
#    -- Batch 2/5 / Loss:  0.059155595
#    -- Batch 3/5 / Loss:  0.06948953
#    -- Batch 4/5 / Loss:  0.061340757
#    -- Batch 5/5 / Loss:  0.07779682
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06528431}
#    Validation: {'loss': 0.08902453705668449}
# Epoch 69/150
#    -- Batch 1/5 / Loss:  0.05607812
#    -- Batch 2/5 / Loss:  0.0633647
#    -- Batch 3/5 / Loss:  0.05841253
#    -- Batch 4/5 / Loss:  0.09578246
#    -- Batch 5/5 / Loss:  0.06661331
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06805022}
#    Validation: {'loss': 0.08881175871938467}
# Epoch 70/150
#    -- Batch 1/5 / Loss:  0.07315838
#    -- Batch 2/5 / Loss:  0.072115466
#    -- Batch 3/5 / Loss:  0.0684803
#    -- Batch 4/5 / Loss:  0.06143429
#    -- Batch 5/5 / Loss:  0.06371146
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06777998}
#    Validation: {'loss': 0.08823698088526725}
# Epoch 71/150
#    -- Batch 1/5 / Loss:  0.06362523
#    -- Batch 2/5 / Loss:  0.06612747
#    -- Batch 3/5 / Loss:  0.05565778
#    -- Batch 4/5 / Loss:  0.058710493
#    -- Batch 5/5 / Loss:  0.06581567
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06198733}
#    Validation: {'loss': 0.0888555957004428}
# Epoch 72/150
#    -- Batch 1/5 / Loss:  0.077459045
#    -- Batch 2/5 / Loss:  0.054698825
#    -- Batch 3/5 / Loss:  0.059911273
#    -- Batch 4/5 / Loss:  0.060565654
#    -- Batch 5/5 / Loss:  0.060350217
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.062597}
#    Validation: {'loss': 0.08933947309851646}
# Epoch 73/150
#    -- Batch 1/5 / Loss:  0.05260492
#    -- Batch 2/5 / Loss:  0.072441556
#    -- Batch 3/5 / Loss:  0.06745608
#    -- Batch 4/5 / Loss:  0.058093727
#    -- Batch 5/5 / Loss:  0.07980389
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.066080034}
#    Validation: {'loss': 0.08831185642629862}
# Epoch 74/150
#    -- Batch 1/5 / Loss:  0.06057812
#    -- Batch 2/5 / Loss:  0.055564478
#    -- Batch 3/5 / Loss:  0.06562308
#    -- Batch 4/5 / Loss:  0.059689153
#    -- Batch 5/5 / Loss:  0.054825403
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.059256047}
#    Validation: {'loss': 0.08723342008888721}
# Epoch 75/150
#    -- Batch 1/5 / Loss:  0.060763404
#    -- Batch 2/5 / Loss:  0.054151315
#    -- Batch 3/5 / Loss:  0.058248185
#    -- Batch 4/5 / Loss:  0.06346674
#    -- Batch 5/5 / Loss:  0.056243684
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.058574665}
#    Validation: {'loss': 0.08744062315672636}
# Epoch 76/150
#    -- Batch 1/5 / Loss:  0.060087018
#    -- Batch 2/5 / Loss:  0.06118176
#    -- Batch 3/5 / Loss:  0.06893179
#    -- Batch 4/5 / Loss:  0.060303673
#    -- Batch 5/5 / Loss:  0.058961947
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.061893243}
#    Validation: {'loss': 0.0877972288057208}
# Epoch 77/150
#    -- Batch 1/5 / Loss:  0.06450595
#    -- Batch 2/5 / Loss:  0.059033386
#    -- Batch 3/5 / Loss:  0.063992366
#    -- Batch 4/5 / Loss:  0.08006637
#    -- Batch 5/5 / Loss:  0.05451612
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.064422846}
#    Validation: {'loss': 0.08830804545432329}
# Epoch 78/150
#    -- Batch 1/5 / Loss:  0.058499414
#    -- Batch 2/5 / Loss:  0.06221981
#    -- Batch 3/5 / Loss:  0.05354534
#    -- Batch 4/5 / Loss:  0.05656216
#    -- Batch 5/5 / Loss:  0.053145412
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.056794427}
#    Validation: {'loss': 0.08753114975988865}
# Epoch 79/150
#    -- Batch 1/5 / Loss:  0.053781517
#    -- Batch 2/5 / Loss:  0.08474007
#    -- Batch 3/5 / Loss:  0.054882634
#    -- Batch 4/5 / Loss:  0.05240557
#    -- Batch 5/5 / Loss:  0.054567777
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06007551}
#    Validation: {'loss': 0.08688699509948491}
# Epoch 80/150
#    -- Batch 1/5 / Loss:  0.051734887
#    -- Batch 2/5 / Loss:  0.069466755
#    -- Batch 3/5 / Loss:  0.060078986
#    -- Batch 4/5 / Loss:  0.0610509
#    -- Batch 5/5 / Loss:  0.061707012
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.060807712}
#    Validation: {'loss': 0.08688281904906034}
# Epoch 81/150
#    -- Batch 1/5 / Loss:  0.054929364
#    -- Batch 2/5 / Loss:  0.060176954
#    -- Batch 3/5 / Loss:  0.05677671
#    -- Batch 4/5 / Loss:  0.05753146
#    -- Batch 5/5 / Loss:  0.06541312
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.058965515}
#    Validation: {'loss': 0.08667273968458175}
# Epoch 82/150
#    -- Batch 1/5 / Loss:  0.053897575
#    -- Batch 2/5 / Loss:  0.06906188
#    -- Batch 3/5 / Loss:  0.056321442
#    -- Batch 4/5 / Loss:  0.057367794
#    -- Batch 5/5 / Loss:  0.0592874
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.059187222}
#    Validation: {'loss': 0.08698195423930884}
# Epoch 83/150
#    -- Batch 1/5 / Loss:  0.05427845
#    -- Batch 2/5 / Loss:  0.05682324
#    -- Batch 3/5 / Loss:  0.070696406
#    -- Batch 4/5 / Loss:  0.060733624
#    -- Batch 5/5 / Loss:  0.06946838
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06240002}
#    Validation: {'loss': 0.08603602536022663}
# Epoch 84/150
#    -- Batch 1/5 / Loss:  0.063730106
#    -- Batch 2/5 / Loss:  0.050401814
#    -- Batch 3/5 / Loss:  0.06273875
#    -- Batch 4/5 / Loss:  0.054015998
#    -- Batch 5/5 / Loss:  0.05779612
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.057736557}
#    Validation: {'loss': 0.08517656326293946}
# Epoch 85/150
#    -- Batch 1/5 / Loss:  0.062828004
#    -- Batch 2/5 / Loss:  0.053477746
#    -- Batch 3/5 / Loss:  0.059085645
#    -- Batch 4/5 / Loss:  0.069007725
#    -- Batch 5/5 / Loss:  0.062062897
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.061292402}
#    Validation: {'loss': 0.08482484761625528}
# Epoch 86/150
#    -- Batch 1/5 / Loss:  0.07395318
#    -- Batch 2/5 / Loss:  0.07105614
#    -- Batch 3/5 / Loss:  0.04872936
#    -- Batch 4/5 / Loss:  0.058668345
#    -- Batch 5/5 / Loss:  0.057092756
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.061899953}
#    Validation: {'loss': 0.08524687420576811}
# Epoch 87/150
#    -- Batch 1/5 / Loss:  0.0639575
#    -- Batch 2/5 / Loss:  0.06446488
#    -- Batch 3/5 / Loss:  0.087818906
#    -- Batch 4/5 / Loss:  0.060252298
#    -- Batch 5/5 / Loss:  0.050077043
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.06531413}
#    Validation: {'loss': 0.08445746637880802}
# Epoch 88/150
#    -- Batch 1/5 / Loss:  0.060266897
#    -- Batch 2/5 / Loss:  0.061910104
#    -- Batch 3/5 / Loss:  0.059238397
#    -- Batch 4/5 / Loss:  0.06633781
#    -- Batch 5/5 / Loss:  0.053782202
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.060307086}
#    Validation: {'loss': 0.08371422458440066}
# Epoch 89/150
#    -- Batch 1/5 / Loss:  0.062216856
#    -- Batch 2/5 / Loss:  0.075344615
#    -- Batch 3/5 / Loss:  0.054054473
#    -- Batch 4/5 / Loss:  0.049993463
#    -- Batch 5/5 / Loss:  0.052511506
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.05882418}
#    Validation: {'loss': 0.08396298196166754}
# Epoch 90/150
#    -- Batch 1/5 / Loss:  0.058778603
#    -- Batch 2/5 / Loss:  0.053605326
#    -- Batch 3/5 / Loss:  0.05156172
#    -- Batch 4/5 / Loss:  0.054723963
#    -- Batch 5/5 / Loss:  0.07256952
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.058247827}
#    Validation: {'loss': 0.08517169989645482}
# Epoch 91/150
#    -- Batch 1/5 / Loss:  0.05368509
#    -- Batch 2/5 / Loss:  0.055198744
#    -- Batch 3/5 / Loss:  0.06914685
#    -- Batch 4/5 / Loss:  0.067496106
#    -- Batch 5/5 / Loss:  0.049047496
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.05891486}
#    Validation: {'loss': 0.08428392391651869}
# Epoch 92/150
#    -- Batch 1/5 / Loss:  0.060359783
#    -- Batch 2/5 / Loss:  0.056082346
#    -- Batch 3/5 / Loss:  0.058287933
#    -- Batch 4/5 / Loss:  0.050603405
#    -- Batch 5/5 / Loss:  0.05481037
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.056028765}
#    Validation: {'loss': 0.08385052792727947}
# Epoch 93/150
#    -- Batch 1/5 / Loss:  0.054135196
#    -- Batch 2/5 / Loss:  0.07681676
#    -- Batch 3/5 / Loss:  0.051102024
#    -- Batch 4/5 / Loss:  0.05104257
#    -- Batch 5/5 / Loss:  0.06481165
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.059581637}
#    Validation: {'loss': 0.08348347805440426}
# Epoch 94/150
#    -- Batch 1/5 / Loss:  0.05637791
#    -- Batch 2/5 / Loss:  0.05583722
#    -- Batch 3/5 / Loss:  0.058516458
#    -- Batch 4/5 / Loss:  0.050867736
#    -- Batch 5/5 / Loss:  0.057440996
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.055808067}
#    Validation: {'loss': 0.08344860337674617}
# Epoch 95/150
#    -- Batch 1/5 / Loss:  0.050791137
#    -- Batch 2/5 / Loss:  0.05208809
#    -- Batch 3/5 / Loss:  0.057007723
#    -- Batch 4/5 / Loss:  0.06946291
#    -- Batch 5/5 / Loss:  0.055306055
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.056931186}
#    Validation: {'loss': 0.08368384186178446}
# Epoch 96/150
#    -- Batch 1/5 / Loss:  0.05157966
#    -- Batch 2/5 / Loss:  0.054356895
#    -- Batch 3/5 / Loss:  0.06445226
#    -- Batch 4/5 / Loss:  0.04943791
#    -- Batch 5/5 / Loss:  0.0557628
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.055117905}
#    Validation: {'loss': 0.08383292257785797}
# Epoch 97/150
#    -- Batch 1/5 / Loss:  0.05045309
#    -- Batch 2/5 / Loss:  0.06518671
#    -- Batch 3/5 / Loss:  0.05666715
#    -- Batch 4/5 / Loss:  0.05227474
#    -- Batch 5/5 / Loss:  0.07269698
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.059455734}
#    Validation: {'loss': 0.08374017793685198}
# Epoch 98/150
#    -- Batch 1/5 / Loss:  0.054105893
#    -- Batch 2/5 / Loss:  0.063796654
#    -- Batch 3/5 / Loss:  0.054493047
#    -- Batch 4/5 / Loss:  0.053492464
#    -- Batch 5/5 / Loss:  0.049852602
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.055148132}
#    Validation: {'loss': 0.08320989068597555}
# Epoch 99/150
#    -- Batch 1/5 / Loss:  0.05520162
#    -- Batch 2/5 / Loss:  0.05380584
#    -- Batch 3/5 / Loss:  0.054678116
#    -- Batch 4/5 / Loss:  0.051695477
#    -- Batch 5/5 / Loss:  0.08612603
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.060301416}
#    Validation: {'loss': 0.08261772226542234}
# Epoch 100/150
#    -- Batch 1/5 / Loss:  0.04864282
#    -- Batch 2/5 / Loss:  0.07272272
#    -- Batch 3/5 / Loss:  0.054558575
#    -- Batch 4/5 / Loss:  0.056368064
#    -- Batch 5/5 / Loss:  0.06311047
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.05908053}
#    Validation: {'loss': 0.08289035614579916}
# Epoch 101/150
#    -- Batch 1/5 / Loss:  0.053364653
#    -- Batch 2/5 / Loss:  0.053025812
#    -- Batch 3/5 / Loss:  0.060419597
#    -- Batch 4/5 / Loss:  0.0711652
#    -- Batch 5/5 / Loss:  0.04830503
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.05725606}
#    Validation: {'loss': 0.08371461518108844}
# Epoch 102/150
#    -- Batch 1/5 / Loss:  0.062278297
#    -- Batch 2/5 / Loss:  0.06402375
#    -- Batch 3/5 / Loss:  0.054837108
#    -- Batch 4/5 / Loss:  0.04971044
#    -- Batch 5/5 / Loss:  0.050933823
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.05635668}
#    Validation: {'loss': 0.08337981309741735}
# Epoch 103/150
#    -- Batch 1/5 / Loss:  0.04918252
#    -- Batch 2/5 / Loss:  0.05527781
#    -- Batch 3/5 / Loss:  0.052785933
#    -- Batch 4/5 / Loss:  0.05129976
#    -- Batch 5/5 / Loss:  0.08931324
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.05957185}
#    Validation: {'loss': 0.08271614499390126}
# Epoch 104/150
#    -- Batch 1/5 / Loss:  0.049522206
#    -- Batch 2/5 / Loss:  0.05079776
#    -- Batch 3/5 / Loss:  0.049517035
#    -- Batch 4/5 / Loss:  0.06366456
#    -- Batch 5/5 / Loss:  0.05762752
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.05422582}
#    Validation: {'loss': 0.08283546175807714}
# Epoch 105/150
#    -- Batch 1/5 / Loss:  0.060357284
#    -- Batch 2/5 / Loss:  0.052949354
#    -- Batch 3/5 / Loss:  0.053078536
#    -- Batch 4/5 / Loss:  0.06337875
#    -- Batch 5/5 / Loss:  0.050995577
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.056151904}
#    Validation: {'loss': 0.08331567384302616}
# Epoch 106/150
#    -- Batch 1/5 / Loss:  0.06633116
#    -- Batch 2/5 / Loss:  0.055077966
#    -- Batch 3/5 / Loss:  0.05165577
#    -- Batch 4/5 / Loss:  0.054852422
#    -- Batch 5/5 / Loss:  0.052896462
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.053233754}
#    Validation: {'loss': 0.08091155197471381}
# Epoch 126/150
#    -- Batch 1/5 / Loss:  0.050414354
#    -- Batch 2/5 / Loss:  0.044774648
#    -- Batch 3/5 / Loss:  0.0473083
#    -- Batch 4/5 / Loss:  0.068071604
#    -- Batch 5/5 / Loss:  0.052164562
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.05254669}
#    Validation: {'loss': 0.08104794304817915}
# Epoch 127/150
#    -- Batch 1/5 / Loss:  0.062227763
#    -- Batch 2/5 / Loss:  0.0455673
#    -- Batch 3/5 / Loss:  0.04616283
#    -- Batch 4/5 / Loss:  0.045718104
#    -- Batch 5/5 / Loss:  0.050643004
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0500638}
#    Validation: {'loss': 0.08115894440561533}
# Epoch 128/150
#    -- Batch 1/5 / Loss:  0.0633468
#    -- Batch 2/5 / Loss:  0.044802167
#    -- Batch 3/5 / Loss:  0.058358554
#    -- Batch 4/5 / Loss:  0.05036251
#    -- Batch 5/5 / Loss:  0.061543636
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.055682737}
#    Validation: {'loss': 0.0806419663131237}
# Epoch 129/150
#    -- Batch 1/5 / Loss:  0.049922716
#    -- Batch 2/5 / Loss:  0.04685125
#    -- Batch 3/5 / Loss:  0.0511921
#    -- Batch 4/5 / Loss:  0.049755372
#    -- Batch 5/5 / Loss:  0.048671745
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.04927864}
#    Validation: {'loss': 0.07948648594319821}
# Epoch 130/150
#    -- Batch 1/5 / Loss:  0.06085795
#    -- Batch 2/5 / Loss:  0.05026131
#    -- Batch 3/5 / Loss:  0.04966358
#    -- Batch 4/5 / Loss:  0.04626262
#    -- Batch 5/5 / Loss:  0.04574173
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.050557442}
#    Validation: {'loss': 0.07881646733731032}
# Epoch 131/150
#    -- Batch 1/5 / Loss:  0.046454478
#    -- Batch 2/5 / Loss:  0.04431957
#    -- Batch 3/5 / Loss:  0.059464846
#    -- Batch 4/5 / Loss:  0.044141166
#    -- Batch 5/5 / Loss:  0.05055124
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.048986256}
#    Validation: {'loss': 0.07867547459900379}
# Epoch 132/150
#    -- Batch 1/5 / Loss:  0.04838707
#    -- Batch 2/5 / Loss:  0.05648669
#    -- Batch 3/5 / Loss:  0.05588222
#    -- Batch 4/5 / Loss:  0.052910116
#    -- Batch 5/5 / Loss:  0.052148607
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.05316294}
#    Validation: {'loss': 0.07938305754214525}
# Epoch 133/150
#    -- Batch 1/5 / Loss:  0.04952833
#    -- Batch 2/5 / Loss:  0.04768119
#    -- Batch 3/5 / Loss:  0.044409975
#    -- Batch 4/5 / Loss:  0.048933245
#    -- Batch 5/5 / Loss:  0.04561554
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.047233656}
#    Validation: {'loss': 0.08042727205902338}
# Epoch 134/150
#    -- Batch 1/5 / Loss:  0.049699977
#    -- Batch 2/5 / Loss:  0.047203325
#    -- Batch 3/5 / Loss:  0.048548386
#    -- Batch 4/5 / Loss:  0.051788557
#    -- Batch 5/5 / Loss:  0.04639872
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.04872779}
#    Validation: {'loss': 0.0803396724164486}
# Epoch 135/150
#    -- Batch 1/5 / Loss:  0.05538957
#    -- Batch 2/5 / Loss:  0.046944752
#    -- Batch 3/5 / Loss:  0.05703821
#    -- Batch 4/5 / Loss:  0.045244925
#    -- Batch 5/5 / Loss:  0.05065017
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.04627}
#    Validation: {'loss': 0.07974558100104331}
# Epoch 146/150
#    -- Batch 1/5 / Loss:  0.043131236
#    -- Batch 2/5 / Loss:  0.044099763
#    -- Batch 3/5 / Loss:  0.05227994
#    -- Batch 4/5 / Loss:  0.0493166
#    -- Batch 5/5 / Loss:  0.05305797
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0483771}
#    Validation: {'loss': 0.08030037712305785}
# Epoch 147/150
#    -- Batch 1/5 / Loss:  0.048438713
#    -- Batch 2/5 / Loss:  0.046487015
#    -- Batch 3/5 / Loss:  0.04336735
#    -- Batch 4/5 / Loss:  0.055921257
#    -- Batch 5/5 / Loss:  0.0495594
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.048754748}
#    Validation: {'loss': 0.08028325010091067}
# Epoch 148/150
#    -- Batch 1/5 / Loss:  0.042195752
#    -- Batch 2/5 / Loss:  0.047908347
#    -- Batch 3/5 / Loss:  0.047874857
#    -- Batch 4/5 / Loss:  0.04687607
#    -- Batch 5/5 / Loss:  0.044763237
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.045923654}
#    Validation: {'loss': 0.08022891003638506}
# Epoch 149/150
#    -- Batch 1/5 / Loss:  0.05503435
#    -- Batch 2/5 / Loss:  0.047937453
#    -- Batch 3/5 / Loss:  0.046648014
#    -- Batch 4/5 / Loss:  0.042627856
#    -- Batch 5/5 / Loss:  0.04589269
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.04762807}
#    Validation: {'loss': 0.08074364382773638}
# Epoch 150/150
#    -- Batch 1/5 / Loss:  0.04722353
#    -- Batch 2/5 / Loss:  0.041932628
#    -- Batch 3/5 / Loss:  0.052537873
#    -- Batch 4/5 / Loss:  0.046547174
#    -- Batch 5/5 / Loss:  0.054584254
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.048565093}
#    Validation: {'loss': 0.07988615464419127}

# %%
plot_histories(train_history['loss'], val_history['loss'], label="Loss")
# plot_histories(train_history=None, val_history=val_history['f1'], label="F1 Score")
plt.show()

# %%
# Select a test image
x,y = test_set_tda[0]
pred = evaluate_model_on_single_image(model, x)

# Plot the result
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 15))
ax1.set_title("True mask")
ax2.set_title("Predicted mask")
plot_image_with_segmentation(x, y, ax=ax1, model='rgb', sdf=False)
plot_image_with_segmentation(x, pred, ax=ax2, model='rgb', sdf=False)
plt.show()

# %%
mask_pred = pred[0][0].cpu()
plt.figure(figsize=(25,5))
plt.subplot(1,5,1)
plt.imshow(mask_pred > 0.5, cmap='gray')
plt.axis("off")
plt.subplot(1,5,2)
plt.imshow(mask_pred > 0.4, cmap='gray')
plt.axis("off")
plt.subplot(1,5,3)
plt.imshow(mask_pred > 0.3, cmap='gray')
plt.axis("off")
plt.subplot(1,5,4)
plt.imshow(mask_pred > 0.2, cmap='gray')
plt.axis("off")
plt.subplot(1,5,5)
plt.imshow(mask_pred > 0.1, cmap='gray')
plt.axis("off")
plt.show()

# %%
model.segmentation_head = nn.Sequential(
    nn.Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)),
    nn.Identity(),
    DynamicThresholdLayer(1)
)

model.segmentation_head.to(device)
# Out:
# Sequential(
#   (0): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): Identity()
#   (2): DynamicThresholdLayer(
#     (threshold_net): ThresholdNet(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=4096, out_features=128, bias=True)
#       (relu): ReLU()
#       (fc2): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )

# %%
# 冻结所有层的参数，除了ThresholdNet
for name, param in model.named_parameters():
    if 'segmentation_head' in name:
        param.requires_grad = True
    else:
        param.requires_grad = False

# 检查冻结情况
for name, param in model.named_parameters():
    print(name, param.requires_grad)

# 确保模型正确添加并其他层已冻结
print(model)
# Out:
# encoder._conv_stem.weight False
# encoder._bn0.weight False
# encoder._bn0.bias False
# encoder._blocks.0._depthwise_conv.weight False
# encoder._blocks.0._bn1.weight False
# encoder._blocks.0._bn1.bias False
# encoder._blocks.0._se_reduce.weight False
# encoder._blocks.0._se_reduce.bias False
# encoder._blocks.0._se_expand.weight False
# encoder._blocks.0._se_expand.bias False
# encoder._blocks.0._project_conv.weight False
# encoder._blocks.0._bn2.weight False
# encoder._blocks.0._bn2.bias False
# encoder._blocks.1._expand_conv.weight False
# encoder._blocks.1._bn0.weight False
# encoder._blocks.1._bn0.bias False
# encoder._blocks.1._depthwise_conv.weight False
# encoder._blocks.1._bn1.weight False
# encoder._blocks.1._bn1.bias False
# encoder._blocks.1._se_reduce.weight False
# encoder._blocks.1._se_reduce.bias False
# encoder._blocks.1._se_expand.weight False
# encoder._blocks.1._se_expand.bias False
# encoder._blocks.1._project_conv.weight False
# encoder._blocks.1._bn2.weight False
# encoder._blocks.1._bn2.bias False
# encoder._blocks.2._expand_conv.weight False
# encoder._blocks.2._bn0.weight False
# encoder._blocks.2._bn0.bias False
# encoder._blocks.2._depthwise_conv.weight False
# encoder._blocks.2._bn1.weight False
# encoder._blocks.2._bn1.bias False
# encoder._blocks.2._se_reduce.weight False
# encoder._blocks.2._se_reduce.bias False
# encoder._blocks.2._se_expand.weight False
# encoder._blocks.2._se_expand.bias False
# encoder._blocks.2._project_conv.weight False
# encoder._blocks.2._bn2.weight False
# encoder._blocks.2._bn2.bias False
# encoder._blocks.3._expand_conv.weight False
# encoder._blocks.3._bn0.weight False
# encoder._blocks.3._bn0.bias False
# encoder._blocks.3._depthwise_conv.weight False
# encoder._blocks.3._bn1.weight False
# encoder._blocks.3._bn1.bias False
# encoder._blocks.3._se_reduce.weight False
# encoder._blocks.3._se_reduce.bias False
# encoder._blocks.3._se_expand.weight False
# encoder._blocks.3._se_expand.bias False
# encoder._blocks.3._project_conv.weight False
# encoder._blocks.3._bn2.weight False
# encoder._blocks.3._bn2.bias False
# encoder._blocks.4._expand_conv.weight False
# encoder._blocks.4._bn0.weight False
# encoder._blocks.4._bn0.bias False
# encoder._blocks.4._depthwise_conv.weight False
# encoder._blocks.4._bn1.weight False
# encoder._blocks.4._bn1.bias False
# encoder._blocks.4._se_reduce.weight False
# encoder._blocks.4._se_reduce.bias False
# encoder._blocks.4._se_expand.weight False
# encoder._blocks.4._se_expand.bias False
# encoder._blocks.4._project_conv.weight False
# encoder._blocks.4._bn2.weight False
# encoder._blocks.4._bn2.bias False
# encoder._blocks.5._expand_conv.weight False
# encoder._blocks.5._bn0.weight False
# encoder._blocks.5._bn0.bias False
# encoder._blocks.5._depthwise_conv.weight False
# encoder._blocks.5._bn1.weight False
# encoder._blocks.5._bn1.bias False
# encoder._blocks.5._se_reduce.weight False
# encoder._blocks.5._se_reduce.bias False
# encoder._blocks.5._se_expand.weight False
# encoder._blocks.5._se_expand.bias False
# encoder._blocks.5._project_conv.weight False
# encoder._blocks.5._bn2.weight False
# encoder._blocks.5._bn2.bias False
# encoder._blocks.6._expand_conv.weight False
# encoder._blocks.6._bn0.weight False
# encoder._blocks.6._bn0.bias False
# encoder._blocks.6._depthwise_conv.weight False
# encoder._blocks.6._bn1.weight False
# encoder._blocks.6._bn1.bias False
# encoder._blocks.6._se_reduce.weight False
# encoder._blocks.6._se_reduce.bias False
# encoder._blocks.6._se_expand.weight False
# encoder._blocks.6._se_expand.bias False
# encoder._blocks.6._project_conv.weight False
# encoder._blocks.6._bn2.weight False
# encoder._blocks.6._bn2.bias False
# encoder._blocks.7._expand_conv.weight False
# encoder._blocks.7._bn0.weight False
# encoder._blocks.7._bn0.bias False
# encoder._blocks.7._depthwise_conv.weight False
# encoder._blocks.7._bn1.weight False
# encoder._blocks.7._bn1.bias False
# encoder._blocks.7._se_reduce.weight False
# encoder._blocks.7._se_reduce.bias False
# encoder._blocks.7._se_expand.weight False
# encoder._blocks.7._se_expand.bias False
# encoder._blocks.7._project_conv.weight False
# encoder._blocks.7._bn2.weight False
# encoder._blocks.7._bn2.bias False
# encoder._blocks.8._expand_conv.weight False
# encoder._blocks.8._bn0.weight False
# encoder._blocks.8._bn0.bias False
# encoder._blocks.8._depthwise_conv.weight False
# encoder._blocks.8._bn1.weight False
# encoder._blocks.8._bn1.bias False
# encoder._blocks.8._se_reduce.weight False
# encoder._blocks.8._se_reduce.bias False
# encoder._blocks.8._se_expand.weight False
# encoder._blocks.8._se_expand.bias False
# encoder._blocks.8._project_conv.weight False
# encoder._blocks.8._bn2.weight False
# encoder._blocks.8._bn2.bias False
# encoder._blocks.9._expand_conv.weight False
# encoder._blocks.9._bn0.weight False
# encoder._blocks.9._bn0.bias False
# encoder._blocks.9._depthwise_conv.weight False
# encoder._blocks.9._bn1.weight False
# encoder._blocks.9._bn1.bias False
# encoder._blocks.9._se_reduce.weight False
# encoder._blocks.9._se_reduce.bias False
# encoder._blocks.9._se_expand.weight False
# encoder._blocks.9._se_expand.bias False
# encoder._blocks.9._project_conv.weight False
# encoder._blocks.9._bn2.weight False
# encoder._blocks.9._bn2.bias False
# encoder._blocks.10._expand_conv.weight False
# encoder._blocks.10._bn0.weight False
# encoder._blocks.10._bn0.bias False
# encoder._blocks.10._depthwise_conv.weight False
# encoder._blocks.10._bn1.weight False
# encoder._blocks.10._bn1.bias False
# encoder._blocks.10._se_reduce.weight False
# encoder._blocks.10._se_reduce.bias False
# encoder._blocks.10._se_expand.weight False
# encoder._blocks.10._se_expand.bias False
# encoder._blocks.10._project_conv.weight False
# encoder._blocks.10._bn2.weight False
# encoder._blocks.10._bn2.bias False
# encoder._blocks.11._expand_conv.weight False
# encoder._blocks.11._bn0.weight False
# encoder._blocks.11._bn0.bias False
# encoder._blocks.11._depthwise_conv.weight False
# encoder._blocks.11._bn1.weight False
# encoder._blocks.11._bn1.bias False
# encoder._blocks.11._se_reduce.weight False
# encoder._blocks.11._se_reduce.bias False
# encoder._blocks.11._se_expand.weight False
# encoder._blocks.11._se_expand.bias False
# encoder._blocks.11._project_conv.weight False
# encoder._blocks.11._bn2.weight False
# encoder._blocks.11._bn2.bias False
# encoder._blocks.12._expand_conv.weight False
# encoder._blocks.12._bn0.weight False
# encoder._blocks.12._bn0.bias False
# encoder._blocks.12._depthwise_conv.weight False
# encoder._blocks.12._bn1.weight False
# encoder._blocks.12._bn1.bias False
# encoder._blocks.12._se_reduce.weight False
# encoder._blocks.12._se_reduce.bias False
# encoder._blocks.12._se_expand.weight False
# encoder._blocks.12._se_expand.bias False
# encoder._blocks.12._project_conv.weight False
# encoder._blocks.12._bn2.weight False
# encoder._blocks.12._bn2.bias False
# encoder._blocks.13._expand_conv.weight False
# encoder._blocks.13._bn0.weight False
# encoder._blocks.13._bn0.bias False
# encoder._blocks.13._depthwise_conv.weight False
# encoder._blocks.13._bn1.weight False
# encoder._blocks.13._bn1.bias False
# encoder._blocks.13._se_reduce.weight False
# encoder._blocks.13._se_reduce.bias False
# encoder._blocks.13._se_expand.weight False
# encoder._blocks.13._se_expand.bias False
# encoder._blocks.13._project_conv.weight False
# encoder._blocks.13._bn2.weight False
# encoder._blocks.13._bn2.bias False
# encoder._blocks.14._expand_conv.weight False
# encoder._blocks.14._bn0.weight False
# encoder._blocks.14._bn0.bias False
# encoder._blocks.14._depthwise_conv.weight False
# encoder._blocks.14._bn1.weight False
# encoder._blocks.14._bn1.bias False
# encoder._blocks.14._se_reduce.weight False
# encoder._blocks.14._se_reduce.bias False
# encoder._blocks.14._se_expand.weight False
# encoder._blocks.14._se_expand.bias False
# encoder._blocks.14._project_conv.weight False
# encoder._blocks.14._bn2.weight False
# encoder._blocks.14._bn2.bias False
# encoder._blocks.15._expand_conv.weight False
# encoder._blocks.15._bn0.weight False
# encoder._blocks.15._bn0.bias False
# encoder._blocks.15._depthwise_conv.weight False
# encoder._blocks.15._bn1.weight False
# encoder._blocks.15._bn1.bias False
# encoder._blocks.15._se_reduce.weight False
# encoder._blocks.15._se_reduce.bias False
# encoder._blocks.15._se_expand.weight False
# encoder._blocks.15._se_expand.bias False
# encoder._blocks.15._project_conv.weight False
# encoder._blocks.15._bn2.weight False
# encoder._blocks.15._bn2.bias False
# encoder._conv_head.weight False
# encoder._bn1.weight False
# encoder._bn1.bias False
# decoder.blocks.0.conv1.0.weight False
# decoder.blocks.0.conv1.1.weight False
# decoder.blocks.0.conv1.1.bias False
# decoder.blocks.0.conv2.0.weight False
# decoder.blocks.0.conv2.1.weight False
# decoder.blocks.0.conv2.1.bias False
# decoder.blocks.1.conv1.0.weight False
# decoder.blocks.1.conv1.1.weight False
# decoder.blocks.1.conv1.1.bias False
# decoder.blocks.1.conv2.0.weight False
# decoder.blocks.1.conv2.1.weight False
# decoder.blocks.1.conv2.1.bias False
# decoder.blocks.2.conv1.0.weight False
# decoder.blocks.2.conv1.1.weight False
# decoder.blocks.2.conv1.1.bias False
# decoder.blocks.2.conv2.0.weight False
# decoder.blocks.2.conv2.1.weight False
# decoder.blocks.2.conv2.1.bias False
# decoder.blocks.3.conv1.0.weight False
# decoder.blocks.3.conv1.1.weight False
# decoder.blocks.3.conv1.1.bias False
# decoder.blocks.3.conv2.0.weight False
# decoder.blocks.3.conv2.1.weight False
# decoder.blocks.3.conv2.1.bias False
# decoder.blocks.4.conv1.0.weight False
# decoder.blocks.4.conv1.1.weight False
# decoder.blocks.4.conv1.1.bias False
# decoder.blocks.4.conv2.0.weight False
# decoder.blocks.4.conv2.1.weight False
# decoder.blocks.4.conv2.1.bias False
# segmentation_head.0.weight True
# segmentation_head.0.bias True
# segmentation_head.2.threshold_net.fc1.weight True
# segmentation_head.2.threshold_net.fc1.bias True
# segmentation_head.2.threshold_net.fc2.weight True
# segmentation_head.2.threshold_net.fc2.bias True
# Unet(
#   (encoder): EfficientNetEncoder(
#     (_conv_stem): Conv2dStaticSamePadding(
#       3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#       (static_padding): ZeroPad2d((0, 1, 0, 1))
#     )
#     (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (_blocks): ModuleList(
#       (0): MBConvBlock(
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           32, 8, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           8, 32, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (1): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#           (static_padding): ZeroPad2d((0, 1, 0, 1))
#         )
#         (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           96, 4, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           4, 96, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (2): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           144, 6, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           6, 144, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (3): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#           (static_padding): ZeroPad2d((1, 2, 1, 2))
#         )
#         (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           144, 6, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           6, 144, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (4): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           240, 10, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           10, 240, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (5): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           240, 240, kernel_size=(3, 3), stride=[2, 2], groups=240, bias=False
#           (static_padding): ZeroPad2d((0, 1, 0, 1))
#         )
#         (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           240, 10, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           10, 240, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (6-7): 2 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           480, 20, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           20, 480, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (8): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           480, 480, kernel_size=(5, 5), stride=[1, 1], groups=480, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           480, 20, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           20, 480, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (9-10): 2 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           672, 28, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           28, 672, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (11): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           672, 672, kernel_size=(5, 5), stride=[2, 2], groups=672, bias=False
#           (static_padding): ZeroPad2d((1, 2, 1, 2))
#         )
#         (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           672, 28, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           28, 672, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (12-14): 3 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1152, 48, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           48, 1152, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (15): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1152, 1152, kernel_size=(3, 3), stride=[1, 1], groups=1152, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1152, 48, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           48, 1152, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#     )
#     (_conv_head): Conv2dStaticSamePadding(
#       320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn1): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#     (_dropout): Dropout(p=0.2, inplace=False)
#     (_swish): MemoryEfficientSwish()
#   )
#   (decoder): UnetDecoder(
#     (center): Identity()
#     (blocks): ModuleList(
#       (0): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(432, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (1): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(296, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (2): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(152, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (3): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (4): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#     )
#   )
#   (segmentation_head): Sequential(
#     (0): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Identity()
#     (2): DynamicThresholdLayer(
#       (threshold_net): ThresholdNet(
#         (flatten): Flatten(start_dim=1, end_dim=-1)
#         (fc1): Linear(in_features=4096, out_features=128, bias=True)
#         (relu): ReLU()
#         (fc2): Linear(in_features=128, out_features=1, bias=True)
#       )
#     )
#   )
# )

# %%
# Define loss and metrics
loss_1 = torch.nn.MSELoss(reduction="mean")
loss_2 = persistence_loss()

# Define optimizer
optimizer = torch.optim.Adam(model.segmentation_head.parameters(), lr=0.0001)

# metrics = {"f1": torchmetrics.classification.F1Score(task='binary', num_classes=1, average="macro", mdmc_average="samplewise")}
metrics = {}

# %%
# Run training
train_history, val_history = training_loop(
    model=model,
    loss=[loss_1, loss_2],
    optimizer=optimizer,
    train_loader=train_loader_tda,
    val_loader=test_loader_tda,
    init_epoch=init_epoch,
    n_epochs=150,
    metrics_dict=metrics,
    save_path="unet_with_threshold.ckpt",
    alpha=0.9
)
# Out:
# Epoch 1/150
#    -- Batch 1/5 / tensor(1.5080, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.50267917
#    -- Batch 2/5 / tensor(1.4674, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.24069783
#    -- Batch 3/5 / tensor(1.4411, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.27839708
#    -- Batch 4/5 / tensor(1.3171, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.3387854
#    -- Batch 5/5 / tensor(1.1682, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.33976638
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.34006518}
#    Validation: {'loss': 0.3214706674963236}
# Epoch 2/150
#    -- Batch 1/5 / tensor(1.2755, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.30157384
#    -- Batch 2/5 / tensor(1.2859, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.27000058
#    -- Batch 3/5 / tensor(1.5123, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.26686358
#    -- Batch 4/5 / tensor(1.4826, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2572434
#    -- Batch 5/5 / tensor(1.4836, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2543434
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.27000496}
#    Validation: {'loss': 0.29658212423324576}
# Epoch 3/150
#    -- Batch 1/5 / tensor(1.4657, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.26520643
#    -- Batch 2/5 / tensor(1.5390, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.
device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1252313
#    -- Batch 4/5 / tensor(0.9403, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.14216658
#    -- Batch 5/5 / tensor(0.8222, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1281567
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12345022}
#    Validation: {'loss': 0.15804582960903643}
# Epoch 145/150
#    -- Batch 1/5 / tensor(0.7344, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.114301965
#    -- Batch 2/5 / tensor(0.7309, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.12191404
#    -- Batch 3/5 / tensor(0.9534, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1400478
#    -- Batch 4/5 / tensor(0.7655, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.12279506
#    -- Batch 5/5 / tensor(0.6788, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.11046012
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12190379}
#    Validation: {'loss': 0.1619546802714467}
# Epoch 146/150
#    -- Batch 1/5 / tensor(0.7883, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.11363158
#    -- Batch 2/5 / tensor(0.8022, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.13711004
#    -- Batch 3/5 / tensor(0.8544, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.12512815
#    -- Batch 4/5 / tensor(0.9191, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.13170566
#    -- Batch 5/5 / tensor(0.8043, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.11992572
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12550023}
#    Validation: {'loss': 0.1604182193800807}
# Epoch 147/150
#    -- Batch 1/5 / tensor(0.7569, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.12140152
#    -- Batch 2/5 / tensor(0.8031, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.14146996
#    -- Batch 3/5 / tensor(0.8993, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.13489953
#    -- Batch 4/5 / tensor(0.9010, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.13335991
#    -- Batch 5/5 / tensor(0.6447, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.111753866
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12857696}
#    Validation: {'loss': 0.15661436831578612}
# Epoch 148/150
#    -- Batch 1/5 / tensor(0.8062, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.14930747
#    -- Batch 2/5 / tensor(0.5427, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.10234684
#    -- Batch 3/5 / tensor(0.7397, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.11877765
#    -- Batch 4/5 / tensor(0.8116, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.12664224
#    -- Batch 5/5 / tensor(0.9263, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.13539577
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12649399}
#    Validation: {'loss': 0.16421018090099093}
# Epoch 149/150
#    -- Batch 1/5 / tensor(0.7922, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1153249
#    -- Batch 2/5 / tensor(0.8013, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.12174867
#    -- Batch 3/5 / tensor(0.8548, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1265763
#    -- Batch 4/5 / tensor(0.8369, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.12598021
#    -- Batch 5/5 / tensor(0.6848, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1151184
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1209497}
#    Validation: {'loss': 0.16590200783684847}
# Epoch 150/150
#    -- Batch 1/5 / tensor(0.7690, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.11748092
#    -- Batch 2/5 / tensor(0.7433, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.12893385
#    -- Batch 3/5 / tensor(0.8836, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.13036743
#    -- Batch 4/5 / tensor(0.8747, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.12519817
#    -- Batch 5/5 / tensor(0.7014, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.11335917
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1230679}
#    Validation: {'loss': 0.1605156912654638}

# %%
plot_histories(train_history['loss'], val_history['loss'], label="Loss")
# plot_histories(train_history=None, val_history=val_history['f1'], label="F1 Score")
plt.show()

# %%
# Select a test image
x,y = test_set_tda[0]
pred = evaluate_model_on_single_image(model, x)

# Plot the result
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 15))
ax1.set_title("True mask")
ax2.set_title("Predicted mask")
plot_image_with_segmentation(x, y, ax=ax1, model='rgb', sdf=False)
plot_image_with_segmentation(x, pred, ax=ax2, model='rgb', sdf=False)
plt.show()

# %%
mask_pred = pred[0][0].cpu()
plt.figure(figsize=(25,5))
plt.subplot(1,5,1)
plt.imshow(mask_pred > 0.5, cmap='gray')
plt.axis("off")
plt.subplot(1,5,2)
plt.imshow(mask_pred > 0.4, cmap='gray')
plt.axis("off")
plt.subplot(1,5,3)
plt.imshow(mask_pred > 0.3, cmap='gray')
plt.axis("off")
plt.subplot(1,5,4)
plt.imshow(mask_pred > 0.2, cmap='gray')
plt.axis("off")
plt.subplot(1,5,5)
plt.imshow(mask_pred > 0.1, cmap='gray')
plt.axis("off")
plt.show()

# %%
class SegmentationMetric(object):
    def __init__(self, numClass):
        self.numClass = numClass
        self.confusionMatrix = np.zeros((self.numClass,) * 2)  # 混淆矩阵（空）

    def pixelAccuracy(self):
        # return all class overall pixel accuracy 正确的像素占总像素的比例
        #  PA = acc = (TP + TN) / (TP + TN + FP + TN)
        acc = np.diag(self.confusionMatrix).sum() / self.confusionMatrix.sum()
        return acc

    def classPixelAccuracy(self):
        # return each category pixel accuracy(A more accurate way to call it precision)
        # acc = (TP) / TP + FP
        classAcc = np.diag(self.confusionMatrix) / self.confusionMatrix.sum(axis=1)
        return classAcc  # 返回的是一个列表值，如：[0.90, 0.80, 0.96]，表示类别1 2 3各类别的预测准确率

    def meanPixelAccuracy(self):
        """
        Mean Pixel Accuracy(MPA，均像素精度)：是PA的一种简单提升，计算每个类内被正确分类像素数的比例，之后求所有类的平均。
        :return:
        """
        classAcc = self.classPixelAccuracy()
        meanAcc = np.nanmean(classAcc)  # np.nanmean 求平均值，nan表示遇到Nan类型，其值取为0
        return meanAcc  # 返回单个值，如：np.nanmean([0.90, 0.80, 0.96, nan, nan]) = (0.90 + 0.80 + 0.96） / 3 =  0.89

    def IntersectionOverUnion(self):
        # Intersection = TP Union = TP + FP + FN
        # IoU = TP / (TP + FP + FN)
        intersection = np.diag(self.confusionMatrix)  # 取对角元素的值，返回列表
        union = np.sum(self.confusionMatrix, axis=1) + np.sum(self.confusionMatrix, axis=0) - np.diag(
            self.confusionMatrix)  # axis = 1表示混淆矩阵行的值，返回列表； axis = 0表示取混淆矩阵列的值，返回列表
        IoU = intersection / union  # 返回列表，其值为各个类别的IoU
        return IoU

    def meanIntersectionOverUnion(self):
        mIoU = np.nanmean(self.IntersectionOverUnion())  # 求各类别IoU的平均
        return mIoU

    def genConfusionMatrix(self, imgPredict, imgLabel):  #
        """
        同FCN中score.py的fast_hist()函数,计算混淆矩阵
        :param imgPredict:
        :param imgLabel:
        :return: 混淆矩阵
        """
        # remove classes from unlabeled pixels in gt image and predict
        mask = (imgLabel >= 0) & (imgLabel < self.numClass)
        label = self.numClass * imgLabel[mask] + imgPredict[mask]
        count = np.bincount(label, minlength=self.numClass ** 2)
        confusionMatrix = count.reshape(self.numClass, self.numClass)
        # print(confusionMatrix)
        return confusionMatrix

    def Frequency_Weighted_Intersection_over_Union(self):
        """
        FWIoU，频权交并比:为MIoU的一种提升，这种方法根据每个类出现的频率为其设置权重。
        FWIOU =     [(TP+FN)/(TP+FP+TN+FN)] *[TP / (TP + FP + FN)]
        """
        freq = np.sum(self.confusion_matrix, axis=1) / np.sum(self.confusion_matrix)
        iu = np.diag(self.confusion_matrix) / (
                np.sum(self.confusion_matrix, axis=1) + np.sum(self.confusion_matrix, axis=0) -
                np.diag(self.confusion_matrix))
        FWIoU = (freq[freq > 0] * iu[freq > 0]).sum()
        return FWIoU

    def addBatch(self, imgPredict, imgLabel):
        assert imgPredict.shape == imgLabel.shape
        self.confusionMatrix += self.genConfusionMatrix(imgPredict, imgLabel)  # 得到混淆矩阵
        return self.confusionMatrix

    def reset(self):
        self.confusionMatrix = np.zeros((self.numClass, self.numClass))

# %%
def meanSkeletonAccuracy(x, y):
    skel_x = soft_skel(x)
    skel_y = soft_skel(y)
    metric = SegmentationMetric(2)
    hist = metric.addBatch(skel_x, skel_y)

    return metric.pixelAccuracy()

# %%
threshold = 0.5

imLst_train = train_set.show()
imLst_test = test_set.show()

eval_loss_func = cldice()

# %%
mean_metric_train = {'IoU':[], 'PA':[], 'clDice':[]}

for i, (x, y) in enumerate(train_set_tda):
    pred = evaluate_model_on_single_image(model, x)

    print(imLst_train[i]+':')

    # Plot the result
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 10))
    ax1.set_title("True mask")
    ax2.set_title("Predicted mask")
    plot_image_with_segmentation(x, y, ax=ax1, model='rgb', sdf=False, threshold=threshold)
    plot_image_with_segmentation(x, pred, ax=ax2, model='rgb', sdf=False, threshold=threshold)
    ax1.axis('off')
    ax2.axis('off')
    plt.show()

    # save result
    segm = pred.cpu().detach().numpy()
    segm[segm < threshold] = 0
    segm[segm >= threshold] = 255
    mask = segm.squeeze()

    cldice = eval_loss_func(pred.to(device), y.unsqueeze(0).to(device)).cpu().detach().numpy().item()

    pred_mask = torch.where(pred > threshold, torch.ones_like(pred), torch.zeros_like(pred))
    pred_mask, real_mask = pred_mask.cpu().numpy().squeeze(), y.cpu().numpy().squeeze()
    pred_mask, real_mask = pred_mask.astype(np.int32), real_mask.astype(np.int32)

    metric = SegmentationMetric(2)
    hist = metric.addBatch(pred_mask, real_mask)
    pa = metric.pixelAccuracy()
    cpa = metric.classPixelAccuracy()
    mpa = metric.meanPixelAccuracy()
    IoU = metric.IntersectionOverUnion()
    mIoU = metric.meanIntersectionOverUnion()
    print('hist:\n{},\niou:{},\nmiou:{},\nPA:{},\ncPA:{},\nmPA:{}'.format(hist, IoU, mIoU, pa, cpa, mpa))
    print('clDice:', cldice)
    print('--'*20)

    mean_metric_train['IoU'].append(mIoU)
    mean_metric_train['PA'].append(pa)
    mean_metric_train['clDice'].append(cldice)

    # result = Image.fromarray(mask)
    # result = result.convert('L')
    # result.save("/content/drive/MyDrive/code/Post-Processing/unet/AngioData/train/result/"+"threshold_"+str(threshold)+"/"+imLst_train[i])



# IoU_list = mean_metric_train['IoU']
# PA_list = mean_metric_train['PA']
# clDice_list = mean_metric_train['clDice']
# print('IoU: segm')
# print('  Min IoU: {:.4f}, \n  0.25 IoU: {:.4f}, \n  0.5 IoU: {:.4f}, \n  0.75 IoU: {:.4f}, \n  Max IoU: {:.4f}, \n  mIoU: {:.4f}'
#     .format(np.min(IoU_list), statistics.quantiles(IoU_list, n=4)[0], statistics.quantiles(IoU_list, n=4)[1], statistics.quantiles(IoU_list, n=4)[2], np.max(IoU_list), np.mean(IoU_list)))
# print('PA: segm')
# print('  Min PA: {:.4f}, \n  0.25 PA: {:.4f}, \n  0.5 PA: {:.4f}, \n  0.75 PA: {:.4f}, \n  Max PA: {:.4f}, \n  mPA: {:.4f}'
#     .format(np.min(PA_list), statistics.quantiles(PA_list, n=4)[0], statistics.quantiles(PA_list, n=4)[1], statistics.quantiles(PA_list, n=4)[2], np.max(PA_list), np.mean(PA_list)))
# Out:
# 22_training.tif:
# hist:
# [[3417.  171.]
#  [  87.  421.]],
# iou:[0.92979592 0.62002946],
# miou:0.7749126867241742,
# PA:0.93701171875,
# cPA:[0.95234114 0.82874016],
# mPA:0.8905406473020303
# clDice: 0.33748823404312134
# ----------------------------------------
# 29_training.tif:
# hist:
# [[3142.  104.]
#  [  86.  764.]],
# iou:[0.94297719 0.80083857],
# miou:0.8719078826499154,
# PA:0.95361328125,
# cPA:[0.96796057 0.89882353],
# mPA:0.9333920481316371
# clDice: 0.17422282695770264
# ----------------------------------------
# 25_training.tif:
# hist:
# [[3239.  198.]
#  [  76.  583.]],
# iou:[0.92200399 0.68028005],
# miou:0.8011420159361412,
# PA:0.93310546875,
# cPA:[0.94239162 0.88467375],
# mPA:0.9135326843512732
# clDice: 0.3139568567276001
# ----------------------------------------
# 26_training.tif:
# hist:
# [[3273.  147.]
#  [  69.  607.]],
# iou:[0.93809114 0.73754557],
# miou:0.8378183543001142,
# PA:0.947265625,
# cPA:[0.95701754 0.89792899],
# mPA:0.9274732689712446
# clDice: 0.24230623245239258
# ----------------------------------------
# 24_training.tif:
# hist:
# [[3338.   73.]
#  [ 135.  550.]],
# iou:[0.94134236 0.72559367],
# miou:0.8334680125660933,
# PA:0.94921875,
# cPA:[0.97859865 0.80291971],
# mPA:0.8907591797255338
# clDice: 0.2711106538772583
# ----------------------------------------
# 30_training.tif:
# hist:
# [[3054.  192.]
#  [ 124.  726.]],
# iou:[0.90623145 0.69673704],
# miou:0.801484249075904,
# PA:0.9228515625,
# cPA:[0.94085028 0.85411765],
# mPA:0.8974839621615744
# clDice: 0.28583455085754395
# ----------------------------------------
# 23_training.tif:
# hist:
# [[3393.  522.]
#  [  11.  170.]],
# iou:[0.86423841 0.24182077],
# miou:0.553029589366292,
# PA:0.869873046875,
# cPA:[0.86666667 0.93922652],
# mPA:0.9029465930018417
# clDice: 0.3986142873764038
# ----------------------------------------
# 31_training.tif:
# hist:
# [[3.499e+03 3.800e+02]
#  [1.000e+00 2.160e+02]],
# iou:[0.90180412 0.36180905],
# miou:0.6318065844687355,
# PA:0.906982421875,
# cPA:[0.90203661 0.99539171],
# mPA:0.9487141562210794
# clDice: 0.36378639936447144
# ----------------------------------------
# 21_training.tif:
# hist:
# [[3225.  134.]
#  [  39.  698.]],
# iou:[0.9490877  0.80137773],
# miou:0.8752327126985617,
# PA:0.957763671875,
# cPA:[0.96010717 0.94708277],
# mPA:0.9535949713663407
# clDice: 0.16644275188446045
# ----------------------------------------
# 27_training.tif:
# hist:
# [[3042.  180.]
#  [  31.  843.]],
# iou:[0.9351368  0.79981025],
# miou:0.867473521741134,
# PA:0.948486328125,
# cPA:[0.94413408 0.96453089],
# mPA:0.9543324853304015
# clDice: 0.11323577165603638
# ----------------------------------------
# 28_training.tif:
# hist:
# [[3129.   51.]
#  [ 227.  689.]],
# iou:[0.91840329 0.71251293],
# miou:0.8154581069633084,
# PA:0.93212890625,
# cPA:[0.98396226 0.75218341],
# mPA:0.8680728351322402
# clDice: 0.25699007511138916
# ----------------------------------------
# 36_training.tif:
# hist:
# [[3263.   66.]
#  [ 214.  553.]],
# iou:[0.92097093 0.66386555],
# miou:0.7924182374050381,
# PA:0.931640625,
# cPA:[0.98017423 0.72099087],
# mPA:0.8505825500138446
# clDice: 0.3007909059524536
# ----------------------------------------
# 40_training.tif:
# hist:
# [[3422.  197.]
#  [   5.  472.]],
# iou:[0.94426049 0.70029674],
# miou:0.8222786107781292,
# PA:0.95068359375,
# cPA:[0.94556507 0.98951782],
# mPA:0.9675414464655734
# clDice: 0.125652015209198
# ----------------------------------------
# 33_training.tif:
# hist:
# [[3248.   33.]
#  [ 195.  620.]],
# iou:[0.93440736 0.73113208],
# miou:0.8327697201294049,
# PA:0.9443359375,
# cPA:[0.98994209 0.7607362 ],
# mPA:0.8753391435724931
# clDice: 0.2797084450721741
# ----------------------------------------
# 37_training.tif:
# hist:
# [[2984.   84.]
#  [ 131.  897.]],
# iou:[0.9327915  0.80665468],
# miou:0.8697230868009562,
# PA:0.947509765625,
# cPA:[0.9726206  0.87256809],
# mPA:0.9225943465622288
# clDice: 0.13464581966400146
# ----------------------------------------
# 38_training.tif:
# hist:
# [[3361.  180.]
#  [  11.  544.]],
# iou:[0.94622748 0.74013605],
# miou:0.843181765949623,
# PA:0.953369140625,
# cPA:[0.9491669  0.98018018],
# mPA:0.9646735410926317
# clDice: 0.052958011627197266
# ----------------------------------------
# 34_training.tif:
# hist:
# [[3287.  439.]
#  [  49.  321.]],
# iou:[0.87072848 0.39678616],
# miou:0.6337573162845145,
# PA:0.880859375,
# cPA:[0.88217928 0.86756757],
# mPA:0.8748734241487865
# clDice: 0.3021402955055237
# ----------------------------------------
# 35_training.tif:
# hist:
# [[3129.  357.]
#  [  41.  569.]],
# iou:[0.88715622 0.58841779],
# miou:0.7377870051946734,
# PA:0.90283203125,
# cPA:[0.89759036 0.93278689],
# mPA:0.9151886233458424
# clDice: 0.2527610659599304
# ----------------------------------------
# 39_training.tif:
# hist:
# [[3274.  135.]
#  [ 152.  535.]],
# iou:[0.91940466 0.65085158],
# miou:0.7851281215602113,
# PA:0.929931640625,
# cPA:[0.96039894 0.77874818],
# mPA:0.8695735622333722
# clDice: 0.32436639070510864
# ----------------------------------------
# 32_training.tif:
# hist:
# [[3165.  208.]
#  [  13.  710.]],
# iou:[0.93473125 0.76262084],
# miou:0.8486760420585681,
# PA:0.946044921875,
# cPA:[0.93833383 0.98201936],
# mPA:0.960176595607704
# clDice: 0.06016319990158081
# ----------------------------------------

# %%
toPIL = transforms.ToPILImage()
mean_metric_test = {'IoU':[], 'PA':[], 'clDice':[]}
for i, (x, y) in enumerate(test_set_tda):
    pred = evaluate_model_on_single_image(model, x)

    # print(imLst_test[i]+':')

    # Plot the result
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 10))
    ax1.set_title("True mask")
    ax2.set_title("Predicted mask")
    plot_image_with_segmentation(x, y, ax=ax1, model='rgb', sdf=False, threshold=threshold)
    plot_image_with_segmentation(x, pred, ax=ax2, model='rgb', sdf=False, threshold=threshold)
    ax1.axis('off')
    ax2.axis('off')
    plt.show()

    # save result
    segm = pred.cpu().detach().numpy()
    segm[segm < threshold] = 0
    segm[segm >= threshold] = 255
    mask = segm.squeeze()

    pred_mask = torch.where(pred > threshold, torch.ones_like(pred), torch.zeros_like(pred))
    pred_mask, real_mask = pred_mask.cpu().numpy().squeeze(), y.cpu().numpy().squeeze()
    pred_mask, real_mask = pred_mask.astype(np.int32), real_mask.astype(np.int32)

    cldice = eval_loss_func(pred.to(device), y.unsqueeze(0).to(device)).cpu().detach().numpy().item()

    metric = SegmentationMetric(2)
    hist = metric.addBatch(pred_mask, real_mask)
    pa = metric.pixelAccuracy()
    cpa = metric.classPixelAccuracy()
    mpa = metric.meanPixelAccuracy()
    IoU = metric.IntersectionOverUnion()
    mIoU = metric.meanIntersectionOverUnion()
    print('hist:\n{},\niou:{},\nmiou:{},\nPA:{},\ncPA:{},\nmPA:{}'.format(hist, IoU, mIoU, pa, cpa, mpa))
    print('clDice:', cldice)
    print('--'*20)

    mean_metric_test['IoU'].append(mIoU)
    mean_metric_test['PA'].append(pa)
    mean_metric_test['clDice'].append(cldice)

    # result = Image.fromarray(mask)
    # result = result.convert('L')
    # result.save("/content/drive/MyDrive/code/Post-Processing/unet/AngioData/test/result/"+"threshold_"+str(threshold)+"/"+imLst_test[i])

# IoU_list = mean_metric_test['IoU']
# PA_list = mean_metric_test['PA']
# clDice_list = mean_metric_test['clDice']
# print('IoU: segm')
# print('  Min IoU: {:.4f}, \n  0.25 IoU: {:.4f}, \n  0.5 IoU: {:.4f}, \n  0.75 IoU: {:.4f}, \n  Max IoU: {:.4f}, \n  mIoU: {:.4f}'
#     .format(np.min(IoU_list), statistics.quantiles(IoU_list, n=4)[0], statistics.quantiles(IoU_list, n=4)[1], statistics.quantiles(IoU_list, n=4)[2], np.max(IoU_list), np.mean(IoU_list)))
# print('PA: segm')
# print('  Min PA: {:.4f}, \n  0.25 PA: {:.4f}, \n  0.5 PA: {:.4f}, \n  0.75 PA: {:.4f}, \n  Max PA: {:.4f}, \n  mPA: {:.4f}'
#     .format(np.min(PA_list), statistics.quantiles(PA_list, n=4)[0], statistics.quantiles(PA_list, n=4)[1], statistics.quantiles(PA_list, n=4)[2], np.max(PA_list), np.mean(PA_list)))
# Out:
# hist:
# [[3144.   83.]
#  [ 289.  580.]],
# iou:[0.89419795 0.6092437 ],
# miou:0.7517208248487108,
# PA:0.9091796875,
# cPA:[0.97427952 0.66743383],
# mPA:0.8208566742848299
# clDice: 0.2831011414527893
# ----------------------------------------
# hist:
# [[3036.   49.]
#  [ 371.  640.]],
# iou:[0.87847222 0.60377358],
# miou:0.7411229035639413,
# PA:0.8974609375,
# cPA:[0.98411669 0.6330366 ],
# mPA:0.8085766455536906
# clDice: 0.281272292137146
# ----------------------------------------
# hist:
# [[3100.   74.]
#  [ 281.  641.]],
# iou:[0.89725036 0.6435743 ],
# miou:0.7704123294916279,
# PA:0.913330078125,
# cPA:[0.97668557 0.69522777],
# mPA:0.8359566679925151
# clDice: 0.41917526721954346
# ----------------------------------------
# hist:
# [[3410.  425.]
#  [ 116.  145.]],
# iou:[0.86307264 0.21137026],
# miou:0.5372214511143432,
# PA:0.867919921875,
# cPA:[0.88917862 0.55555556],
# mPA:0.7223670867738665
# clDice: 0.6401424407958984
# ----------------------------------------
# hist:
# [[3335.  121.]
#  [  99.  541.]],
# iou:[0.93811533 0.7109067 ],
# miou:0.8245110161143363,
# PA:0.9462890625,
# cPA:[0.96498843 0.8453125 ],
# mPA:0.905150462962963
# clDice: 0.21387887001037598
# ----------------------------------------
# hist:
# [[3178.  123.]
#  [ 163.  632.]],
# iou:[0.91743649 0.68845316],
# miou:0.8029448243243924,
# PA:0.93017578125,
# cPA:[0.96273856 0.79496855],
# mPA:0.8788535587653066
# clDice: 0.21029287576675415
# ----------------------------------------
# hist:
# [[3393.   72.]
#  [ 220.  411.]],
# iou:[0.92075984 0.58463727],
# miou:0.7526985530127714,
# PA:0.9287109375,
# cPA:[0.97922078 0.65134707],
# mPA:0.8152839236832898
# clDice: 0.4805450439453125
# ----------------------------------------
# hist:
# [[2989.    8.]
#  [ 453.  646.]],
# iou:[0.86637681 0.58355917],
# miou:0.7249679902596127,
# PA:0.887451171875,
# cPA:[0.99733066 0.5878071 ],
# mPA:0.7925688806792841
# clDice: 0.25065821409225464
# ----------------------------------------
# hist:
# [[3089.  119.]
#  [ 287.  601.]],
# iou:[0.88383405 0.59682224],
# miou:0.740328146465443,
# PA:0.90087890625,
# cPA:[0.96290524 0.6768018 ],
# mPA:0.8198535193547662
# clDice: 0.2285137176513672
# ----------------------------------------
# hist:
# [[3496.  280.]
#  [  76.  244.]],
# iou:[0.90758048 0.40666667],
# miou:0.6571235721703012,
# PA:0.9130859375,
# cPA:[0.92584746 0.7625    ],
# mPA:0.8441737288135593
# clDice: 0.4349716305732727
# ----------------------------------------
# hist:
# [[3285.   77.]
#  [ 322.  412.]],
# iou:[0.89169381 0.5080148 ],
# miou:0.6998543038111954,
# PA:0.902587890625,
# cPA:[0.97709697 0.5613079 ],
# mPA:0.7692024339994845
# clDice: 0.3757464289665222
# ----------------------------------------
# hist:
# [[3382.  153.]
#  [ 181.  380.]],
# iou:[0.91011841 0.53221289],
# miou:0.7211656460215948,
# PA:0.91845703125,
# cPA:[0.95671853 0.67736185],
# mPA:0.8170401914140994
# clDice: 0.5250741839408875
# ----------------------------------------
# hist:
# [[3451.  163.]
#  [  77.  405.]],
# iou:[0.93497697 0.62790698],
# miou:0.7814419738773761,
# PA:0.94140625,
# cPA:[0.95489762 0.84024896],
# mPA:0.897573291510424
# clDice: 0.29339808225631714
# ----------------------------------------
# hist:
# [[3328.  626.]
#  [  19.  123.]],
# iou:[0.83765417 0.16015625],
# miou:0.49890520780896047,
# PA:0.842529296875,
# cPA:[0.84167931 0.86619718],
# mPA:0.8539382475938077
# clDice: 0.6525938510894775
# ----------------------------------------
# hist:
# [[3315.  103.]
#  [ 140.  538.]],
# iou:[0.9317032  0.68886044],
# miou:0.8102818196932631,
# PA:0.940673828125,
# cPA:[0.96986542 0.79351032],
# mPA:0.8816878714285468
# clDice: 0.24502336978912354
# ----------------------------------------
# hist:
# [[3447.   91.]
#  [  94.  464.]],
# iou:[0.94906388 0.71494607],
# miou:0.8320049737651283,
# PA:0.954833984375,
# cPA:[0.97427925 0.83154122],
# mPA:0.902910236226854
# clDice: 0.22045224905014038
# ----------------------------------------
# hist:
# [[3454.  168.]
#  [ 124.  350.]],
# iou:[0.92205019 0.54517134],
# miou:0.7336107632149267,
# PA:0.9287109375,
# cPA:[0.95361679 0.73839662],
# mPA:0.846006705389241
# clDice: 0.3549192547798157
# ----------------------------------------
# hist:
# [[3216.  133.]
#  [ 188.  559.]],
# iou:[0.90924512 0.63522727],
# miou:0.7722361978564269,
# PA:0.921630859375,
# cPA:[0.96028665 0.74832664],
# mPA:0.854306646312532
# clDice: 0.2727092504501343
# ----------------------------------------
# hist:
# [[3358.  230.]
#  [ 116.  392.]],
# iou:[0.90658747 0.53116531],
# miou:0.7188763923276382,
# PA:0.91552734375,
# cPA:[0.93589744 0.77165354],
# mPA:0.8537754896022612
# clDice: 0.2812842130661011
# ----------------------------------------
# hist:
# [[3459.  419.]
#  [  33.  185.]],
# iou:[0.88442853 0.29042386],
# miou:0.5874261983769965,
# PA:0.8896484375,
# cPA:[0.89195462 0.84862385],
# mPA:0.8702892344961699
# clDice: 0.5311664342880249
# ----------------------------------------

# %%
# print('threshold:', threshold)
print(mean_metric_train)
print(mean_metric_test)
# print('--'*20)
# Out:
# {'IoU': [0.7749126867241742, 0.8719078826499154, 0.8011420159361412, 0.8378183543001142, 0.8334680125660933, 0.801484249075904, 0.553029589366292, 0.6318065844687355, 0.8752327126985617, 0.867473521741134, 0.8154581069633084, 0.7924182374050381, 0.8222786107781292, 0.8327697201294049, 0.8697230868009562, 0.843181765949623, 0.6337573162845145, 0.7377870051946734, 0.7851281215602113, 0.8486760420585681], 'PA': [0.93701171875, 0.95361328125, 0.93310546875, 0.947265625, 0.94921875, 0.9228515625, 0.869873046875, 0.906982421875, 0.957763671875, 0.948486328125, 0.93212890625, 0.931640625, 0.95068359375, 0.9443359375, 0.947509765625, 0.953369140625, 0.880859375, 0.90283203125, 0.929931640625, 0.946044921875], 'clDice': [0.33748823404312134, 0.17422282695770264, 0.3139568567276001, 0.24230623245239258, 0.2711106538772583, 0.28583455085754395, 0.3986142873764038, 0.36378639936447144, 0.16644275188446045, 0.11323577165603638, 0.25699007511138916, 0.3007909059524536, 0.125652015209198, 0.2797084450721741, 0.13464581966400146, 0.052958011627197266, 0.3021402955055237, 0.2527610659599304, 0.32436639070510864, 0.06016319990158081]}
# {'IoU': [0.7517208248487108, 0.7411229035639413, 0.7704123294916279, 0.5372214511143432, 0.8245110161143363, 0.8029448243243924, 0.7526985530127714, 0.7249679902596127, 0.740328146465443, 0.6571235721703012, 0.6998543038111954, 0.7211656460215948, 0.7814419738773761, 0.49890520780896047, 0.8102818196932631, 0.8320049737651283, 0.7336107632149267, 0.7722361978564269, 0.7188763923276382, 0.5874261983769965], 'PA': [0.9091796875, 0.8974609375, 0.913330078125, 0.867919921875, 0.9462890625, 0.93017578125, 0.9287109375, 0.887451171875, 0.90087890625, 0.9130859375, 0.902587890625, 0.91845703125, 0.94140625, 0.842529296875, 0.940673828125, 0.954833984375, 0.9287109375, 0.921630859375, 0.91552734375, 0.8896484375], 'clDice': [0.2831011414527893, 0.281272292137146, 0.41917526721954346, 0.6401424407958984, 0.21387887001037598, 0.21029287576675415, 0.4805450439453125, 0.25065821409225464, 0.2285137176513672, 0.4349716305732727, 0.3757464289665222, 0.5250741839408875, 0.29339808225631714, 0.6525938510894775, 0.24502336978912354, 0.22045224905014038, 0.3549192547798157, 0.2727092504501343, 0.2812842130661011, 0.5311664342880249]}

# %%
box_1, box_2, box_3 = mean_metric_test['IoU'], mean_metric_test['PA'], mean_metric_test['clDice']

plt.figure(figsize=(10,5))
# plt.title('Examples of boxplot',fontsize=15)
labels = ['IoU','PA','clDice']
plt.boxplot([box_1, box_2, box_3], labels = labels, showmeans=True)
# plt.legend()
plt.show()

# %%
print(np.mean(mean_metric_train['IoU']))
print(np.mean(mean_metric_train['PA']))
print(np.mean(mean_metric_train['clDice']))
# Out:
# 0.7914726811325746
# 0.932275390625
# 0.23785873949527742

# %%
def remove_outliers(data, min, max):
    # 确保数据是 NumPy 数组
    data = np.array(data)

    # 计算第5和第95百分位数
    q_low = np.percentile(data, min)
    q_high = np.percentile(data, max)

    # 过滤掉低于第5百分位和高于第95百分位的数据点
    filtered_data = data[(data >= q_low) & (data <= q_high)]
    return filtered_data

# %%
iou_clean = mean_metric_train['IoU']
pa_clean = mean_metric_train['PA']
cldice_clean = remove_outliers(mean_metric_train['clDice'], 10, 90)

# %%
print(np.mean(iou_clean))
print(np.mean(pa_clean))
print(np.mean(cldice_clean))
# Out:
# 0.7914726811325746
# 0.932275390625
# 0.24260330572724342

# %%
print(np.median(iou_clean))
print(np.median(pa_clean))
print(np.median(cldice_clean))
# Out:
# 0.8188683588707188
# 0.940673828125
# 0.26405036449432373

# %%
box_1, box_2 = iou_clean, pa_clean

plt.figure(figsize=(10,5))
# plt.title('Examples of boxplot',fontsize=15)
labels = ['IoU','PA']
plt.boxplot([box_1, box_2], labels = labels, showmeans=True)
# plt.legend()
plt.show()

# %%
box_1 = cldice_clean

plt.figure(figsize=(10,5))
# plt.title('Examples of boxplot',fontsize=15)
labels = ['clDice']
plt.boxplot([box_1], labels = labels, showmeans=True)
# plt.legend()
plt.show()

# %%
print(np.std(iou_clean))
print(np.std(pa_clean))
print(np.std(cldice_clean))
# Out:
# 0.08633826495631292
# 0.023866965734572212
# 0.0727252883538627
