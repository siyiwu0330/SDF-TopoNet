# %%
import sys
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False
if IN_COLAB:
    # !pip3 install torch matplotlib torchmetrics scikit-image segmentation-models-pytorch &> /dev/null

# %%
# !pip install -U giotto-tda &> /dev/null
# !pip install torch_topological &> /dev/null

# %%
import torch
from torch import nn as nn
from torchvision import transforms as T
from torchvision.transforms import functional as TF
from torchvision.datasets.utils import download_url

from torch import Tensor

import torchmetrics
import segmentation_models_pytorch as smp

import random
import numpy as np
import matplotlib.pyplot as plt
import os

from pprint import pformat
from skimage.transform import resize
from pathlib import Path
from glob import glob
from matplotlib.pyplot import imread
from collections import defaultdict

from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import DataLoader, random_split
from torchvision import transforms
import statistics
import cv2

import torch.nn.functional as F

# from gtda.homology import VietorisRipsPersistence, CubicalPersistence, WeakAlphaPersistence
# from gtda.diagrams import PersistenceEntropy, PairwiseDistance, Amplitude

from torch_topological.nn import AlphaComplex, VietorisRipsComplex, CubicalComplex, WassersteinDistance, SignatureLoss

# %%
gpu = torch.cuda.is_available()
device = torch.device("cuda:0" if gpu else "cpu")
print("device:", device)
# Out:
# device: cuda:0

# %%
data_path = '/content/drive/MyDrive/code/datasets'

batch_size = 4

epochs = 200

lr = 0.0001

# loss = loss_1 * alpha + loss_2 * (1-alpha)
alpha = 0.99

crop_size = (64,64)
padding = 2

# %%
# class DriveDataset(Dataset):
#     def __init__(self, root: str, data_type: str):
#         super(DriveDataset, self).__init__()
#         self.flag = data_type
#         data_root = os.path.join(root, "DRIVE", self.flag)
#         assert os.path.exists(data_root), f"path '{data_root}' does not exists."
#         img_names = [i for i in os.listdir(os.path.join(data_root, "images")) if i.endswith(".tif")]
#         self.img_list = [os.path.join(data_root, "images", i) for i in img_names]
#         self.manual_list = [os.path.join(data_root, "1st_manual", i.split("_")[0] + "_manual1.gif") for i in img_names]
#         self.roi_mask = [os.path.join(data_root, "mask", i.split("_")[0] + f"_{self.flag}_mask.gif") for i in img_names]

#         self.imLst = [i for i in img_names]

#     def __getitem__(self, idx):
#         img = Image.open(self.img_list[idx]).convert('RGB')
#         img = T.functional.resize(img, [512, 512])
#         img = np.array(img) / 255
#         img = np.transpose(img, (2, 0, 1))
#         img = torch.tensor(img, dtype=torch.float32)

#         manual = Image.open(self.manual_list[idx]).convert('L')
#         manual = T.functional.resize(manual, [512, 512])
#         manual = np.array(manual) / 255
#         # roi_mask = Image.open(self.roi_mask[idx]).convert('L')
#         # roi_mask = 255 - np.array(roi_mask)
#         # mask = np.clip(manual + roi_mask, a_min=0, a_max=255)
#         mask = manual[np.newaxis, ...]
#         mask = torch.tensor(mask, dtype=torch.float32)

#         # print(img)
#         # print(mask.size())

#         # img = Image.fromarray(img)
#         # mask = Image.fromarray(mask)

#         return img, mask

#     def __len__(self):
#         return len(self.img_list)

#     def show(self):
#         return self.imLst

# %%
# class DriveDataset(Dataset):
#     def __init__(self, root: str, data_type: str, crop_size=(256, 256)):
#         super(DriveDataset, self).__init__()
#         self.flag = data_type
#         self.crop_size = crop_size
#         data_root = os.path.join(root, "DRIVE", self.flag)
#         assert os.path.exists(data_root), f"path '{data_root}' does not exists."
#         img_names = [i for i in os.listdir(os.path.join(data_root, "images")) if i.endswith(".tif")]
#         self.img_list = [os.path.join(data_root, "images", i) for i in img_names]
#         self.manual_list = [os.path.join(data_root, "1st_manual", i.split("_")[0] + "_manual1.gif") for i in img_names]
#         self.roi_mask = [os.path.join(data_root, "mask", i.split("_")[0] + f"_{self.flag}_mask.gif") for i in img_names]

#         self.imLst = [i for i in img_names]

#     def __getitem__(self, idx):
#         img = Image.open(self.img_list[idx]).convert('RGB')
#         manual = Image.open(self.manual_list[idx]).convert('L')

#         # 应用裁剪
#         i, j, h, w = T.RandomCrop.get_params(img, output_size=self.crop_size)
#         img = T.functional.crop(img, i, j, h, w)
#         manual = T.functional.crop(manual, i, j, h, w)

#         img = T.functional.to_tensor(img)
#         manual = T.functional.to_tensor(manual)
#         mask = manual

#         return img, mask

#     def __len__(self):
#         return len(self.img_list)

#     def show(self):
#         return self.imLst

# %%
# class DriveDataset(Dataset):
#     def __init__(self, root: str, data_type: str, crop_size=(256, 256)):
#         super(DriveDataset, self).__init__()
#         self.flag = data_type
#         self.crop_size = crop_size
#         data_root = os.path.join(root, "DRIVE", self.flag)
#         assert os.path.exists(data_root), f"path '{data_root}' does not exist."
#         img_names = [i for i in os.listdir(os.path.join(data_root, "images")) if i.endswith(".tif")]
#         self.img_list = [os.path.join(data_root, "images", i) for i in img_names]
#         self.manual_list = [os.path.join(data_root, "1st_manual", i.split("_")[0] + "_manual1.gif") for i in img_names]
#         self.roi_mask = [os.path.join(data_root, "mask", i.split("_")[0] + f"_{self.flag}_mask.gif") for i in img_names]

#         self.imLst = [i for i in img_names]

#     def __getitem__(self, idx):
#         img = Image.open(self.img_list[idx]).convert('RGB')
#         manual = Image.open(self.manual_list[idx]).convert('L')
#         mask = Image.open(self.roi_mask[idx]).convert('L')

#         i, j, h, w = T.RandomCrop.get_params(img, output_size=self.crop_size)
#         img = T.functional.crop(img, i, j, h, w)
#         manual = T.functional.crop(manual, i, j, h, w)
#         mask = T.functional.crop(mask, i, j, h, w)

#         img = T.functional.to_tensor(img)
#         manual = T.functional.to_tensor(manual)
#         mask = T.functional.to_tensor(mask)

#         img = img * mask
#         manual = manual * mask

#         return img, manual

#     def __len__(self):
#         return len(self.img_list)

#     def show(self):
#         return self.imLst

# %%
class DriveDataset(Dataset):
    def __init__(self, root: str, data_type: str, crop_size=(60, 60), padding=2):
        super(DriveDataset, self).__init__()
        self.flag = data_type
        self.crop_size = crop_size
        self.padding = padding
        data_root = os.path.join(root, "DRIVE", self.flag)
        assert os.path.exists(data_root), f"path '{data_root}' does not exist."
        img_names = [i for i in os.listdir(os.path.join(data_root, "images")) if i.endswith(".tif")]
        self.img_list = [os.path.join(data_root, "images", i) for i in img_names]
        self.manual_list = [os.path.join(data_root, "1st_manual", i.split("_")[0] + "_manual1.gif") for i in img_names]
        self.roi_mask = [os.path.join(data_root, "mask", i.split("_")[0] + f"_{self.flag}_mask.gif") for i in img_names]

        self.imLst = [i for i in img_names]

    def __getitem__(self, idx):
        img = Image.open(self.img_list[idx]).convert('RGB')
        manual = Image.open(self.manual_list[idx]).convert('L')
        mask = Image.open(self.roi_mask[idx]).convert('L')

        img_width, img_height = img.size
        start_i = (img_height - self.crop_size[1]) // 6
        start_j = (img_width - self.crop_size[0]) // 2

        img = TF.crop(img, start_i, start_j, self.crop_size[1], self.crop_size[0])
        manual = TF.crop(manual, start_i, start_j, self.crop_size[1], self.crop_size[0])
        mask = TF.crop(mask, start_i, start_j, self.crop_size[1], self.crop_size[0])

        img = T.functional.to_tensor(img)
        manual = T.functional.to_tensor(manual)
        mask = T.functional.to_tensor(mask)

        img = img * mask
        manual = manual * mask

        # padding = self.padding
        # img = TF.pad(img, padding=[padding, padding, padding, padding], fill=1)
        # manual = TF.pad(manual, padding=[padding, padding, padding, padding], fill=1)
        # mask = TF.pad(mask, padding=[padding, padding, padding, padding], fill=0)

        return img, manual

    def __len__(self):
        return len(self.img_list)

    def show(self):
        return self.imLst

# %%
train_set = DriveDataset(data_path, data_type="training", crop_size=crop_size, padding = padding)
test_set = DriveDataset(data_path, data_type="test", crop_size=crop_size, padding = padding)

print(len(train_set))
print(len(test_set))

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, batch_size=1, shuffle=False)
# Out:
# 20
# 20

# %%
for batch_x, batch_y in train_loader:
    print(batch_x.size())
    print(batch_y.size())
    plt.subplot(1, 2, 1)
    plt.imshow(np.transpose(batch_x[0], (1, 2, 0)))
    plt.subplot(1, 2, 2)
    plt.imshow(batch_y[0][0], cmap=plt.get_cmap('gray'))
    plt.show()
# Out:
# torch.Size([4, 3, 64, 64])
# torch.Size([4, 1, 64, 64])
# torch.Size([4, 3, 64, 64])
# torch.Size([4, 1, 64, 64])
# torch.Size([4, 3, 64, 64])
# torch.Size([4, 1, 64, 64])
# torch.Size([4, 3, 64, 64])
# torch.Size([4, 1, 64, 64])
# torch.Size([4, 3, 64, 64])
# torch.Size([4, 1, 64, 64])

# %%
def plot_image_with_segmentation(image, segmentation, ax=None, model='gray'):
    """
    Plots an image with overlayed segmentation mask. Segmentation is thresholded at 0.5

    Returns: plt.fig and ax objects
    """
    if ax is None:
        fig = plt.figure(figsize=(8, 8))
        ax = fig.add_subplot(111)
        ax.axis("off")

    im = image.cpu().detach().numpy()
    segm = segmentation.cpu().detach().numpy()
    if model == 'gray':
        ax.imshow(im.squeeze(), cmap="gray")
    elif model == 'rgb':
        ax.imshow(np.transpose(im.squeeze(), (1, 2, 0)))
    mask = segm < 0.5
    ax.imshow(mask.squeeze(), cmap="Set1", alpha=0.5)
    return plt.gcf(), ax

# %%
def evaluate_model_on_single_image(model, x, device=device):
    """
    Evaluate a model on a single data point on the device.

    Returns: model(x)
    """
    with torch.no_grad():
        x = x.to(device)
        return model(x.view(1, *x.shape))

# %%
def evaluate_model(model, data_loader, metrics_dict, reduction=True, device=device, alpha=0.5):
    """
    Evaluate a model 'model' on all batches of a torch DataLoader 'data_loader'.
    On each batch, compute all metric functions stored in dictionary 'metrics_dict'.

    Returns: dict of metric_name: (list of batch-wise metrics if reduction == False, else single scalar)
    """

    # defaultdict(list) returns a dictionary-like object with default_factory list.
    # When a new key is encountered, an entry is automatically created of type default_factory.
    metrics = defaultdict(list)
    with torch.no_grad():
        for i, (batch_x, batch_y) in enumerate(data_loader):
            # Predict on batch
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)
            logits = model(batch_x)

            if alpha == 0.0:
                for metric_name, metric_func in metrics_dict.items():
                    value_1 = 0
                    value_2 = metric_func[1](logits.cpu(), batch_y.cpu()).item()

                    value = alpha*value_1 + (1-alpha)*value_2

                    metrics[metric_name].append(value)

            elif alpha == 1.0:
                for metric_name, metric_func in metrics_dict.items():
                    value_1 = metric_func[0](logits.cpu(), batch_y.cpu()).item() #.cpu().numpy()
                    value_2 = 0

                    value = alpha*value_1 + (1-alpha)*value_2

                    metrics[metric_name].append(value)

            else:
                for metric_name, metric_func in metrics_dict.items():
                    value_1 = metric_func[0](logits.cpu(), batch_y.cpu()).item() #.cpu().numpy()
                    value_2 = metric_func[1](logits.cpu(), batch_y.cpu()).item()

                    value = alpha*value_1 + (1-alpha)*value_2

                    metrics[metric_name].append(value)

    if reduction == True:
        # Return mean values
        return {key: np.mean(value) for key, value in metrics.items()}
    else:
        return metrics

# %%
def save_model(model, path, optimizer=None):
    """
    Saves the state_dict of a torch model and optional optimizer to 'path'
    Returns: None
    """
    state = {"model": model.state_dict()}
    if optimizer is not None:
        state["optimizer"] = optimizer.state_dict()
    torch.save(state, path)


def load_model(model, path, optimizer=None):
    """
    Loads the state_dict of a torch model and optional optimizer from 'path'
    Returns: None
    """
    state = torch.load(path)
    model.load_state_dict(state["model"])
    if optimizer is not None:
        optimizer.load_state_dict(state["optimizer"])

# %%
def plot_histories(train_history=None, val_history=None, label="Loss"):
    """
    Takes a list of training and/or validation metrics and plots them
    Returns: plt.figure and ax objects
    """
    if not train_history and not val_history:
        raise ValueError("Must specify at least one of 'train_histories' and 'val_histories'")
    fig = plt.figure(figsize=(5, 3))
    ax = fig.add_subplot(111)

    epochs = np.arange(len(train_history or val_history))
    if train_history:
        ax.plot(epochs, train_history, label="Training", color="black")
    if val_history:
        ax.plot(epochs, val_history, label="Validation", color="darkred")

    ax.set_xlabel("Epoch")
    ax.set_ylabel(label)
    ax.legend(loc=0)

    return fig, ax

# %%
def run_one_epoch(model, loss, optimizer, train_loader, val_loader, n_epochs, metrics_dict, device=device, alpha=0.5):
    """
    Run 1 epoch of training
    Changes to model parameters and optimizer occour internally (state updates)
    Returns:
        two dictionaries, training and a validation metrics
    """
    train_losses = []
    for i, (batch_x, batch_y) in enumerate(train_loader):
        # Zero out stored gradients for all parameters
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)
        optimizer.zero_grad()

        print(f"   -- Batch {i+1}/{len(train_loader)}", end=" / ")
        # Predict on batch
        logits = model(batch_x)

        if alpha == 0.0:
            loss_tensor_1 = 0
            loss_tensor_2 = loss[1](logits, batch_y)
        elif alpha == 1.0:
            loss_tensor_1 = loss[0](logits, batch_y)
            loss_tensor_2 = 0
        else:
            # Compute loss function
            loss_tensor_1 = loss[0](logits, batch_y)
            loss_tensor_2 = loss[1](logits, batch_y)

            print(loss_tensor_2)

        loss_tensor = alpha*loss_tensor_1 + (1-alpha)*loss_tensor_2
        loss_scalar = loss_tensor.detach().cpu().numpy()

        train_losses.append(loss_scalar)
        print("Loss: ", loss_scalar)

        # Backprop and step
        loss_tensor.backward()
        optimizer.step()

    # Run validation
    print("   Validation running...")
    val_metrics = evaluate_model(
        model=model,
        data_loader=val_loader,
        metrics_dict=metrics_dict,
        alpha=alpha
    )
    # Return loss and metrics as dicts
    return {"loss": np.mean(train_losses)}, val_metrics


def merge_list_of_dicts(list_of_dicts):
    """
    Takes a list of dictionaries and merges them into a single dictionary pointing to lists

    E.g. [{"loss": 5}, {"loss": 3}, {"loss": -2, "F1": 0.5}] --> {"loss": [5, 3, -2], "F1": [0.5]}

    Returns: dict
    """
    merged = defaultdict(list)
    for dict_ in list_of_dicts:
        for value, key in dict_.items():
            merged[value].append(key)
    return merged


def training_loop(model, loss, optimizer, train_loader, val_loader, n_epochs, init_epoch=None, metrics_dict=None, save_path=None, alpha=0.5):
    """
    Run training of a model given a loss function, optimizer and a set of training and validation data.
    Supports computing additional metrics on the validation set (only) via the metrics_dict param.
    Specify save_path to store the model at each epoch.

    Returns:
        Two lists of metric dictionaries for each epoch for training and validation, specifically
    """
    train_history, val_history = [], []

    metrics_with_loss = {"loss": loss}
    if metrics_dict is not None:
        metrics_with_loss.update(metrics_dict)

    if init_epoch == None:
        init_epoch = 0
    try:
        for i in range(init_epoch, n_epochs):
            print(f"Epoch {i+1}/{n_epochs}")
            train_metrics, val_metrics = run_one_epoch(
                model=model,
                loss=loss,
                optimizer=optimizer,
                train_loader=train_loader,
                val_loader=val_loader,
                n_epochs=n_epochs,
                metrics_dict=metrics_with_loss,
                alpha=alpha
            )
            print("   Mean epoch metrics:")
            print(f"   Training:   {pformat(train_metrics)}")
            print(f"   Validation: {pformat(val_metrics)}")
            train_history.append(train_metrics), val_history.append(val_metrics)

            # wandb.log({'epoch': n_epochs+1, 'loss': train_metrics['loss'], 'val_loss': val_metrics['loss']})
            # wandb.watch(model, loss, log="all")

            # if save_path:
            #     save_path_epoch = f"epoch_{i+1}_{save_path}"
            #     print(f"   Saving to: {save_path_epoch}")
            #     save_model(model, save_path_epoch, optimizer)
            #     old_path_epoch = f"epoch_{i}_{save_path}"
            #     if os.path.exists(old_path_epoch):
            #         os.remove(old_path_epoch)

    except KeyboardInterrupt:
        print("Training stopped.")
        pass

    # Merge list of training and validation dicts into single dicts
    return merge_list_of_dicts(train_history), merge_list_of_dicts(val_history)

# %%
# Init U-Net model
model = smp.Unet(encoder_name='efficientnet-b0',in_channels=3,classes=1)

model.to(device)

# Define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

print(model)
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
# 100%|██████████| 20.4M/20.4M [00:00<00:00, 35.2MB/s]
# Unet(
#   (encoder): EfficientNetEncoder(
#     (_conv_stem): Conv2dStaticSamePadding(
#       3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#       (static_padding): ZeroPad2d((0, 1, 0, 1))
#     )
#     (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (_blocks): ModuleList(
#       (0): MBConvBlock(
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           32, 8, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           8, 32, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (1): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#           (static_padding): ZeroPad2d((0, 1, 0, 1))
#         )
#         (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           96, 4, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           4, 96, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (2): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           144, 6, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           6, 144, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (3): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#           (static_padding): ZeroPad2d((1, 2, 1, 2))
#         )
#         (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           144, 6, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           6, 144, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (4): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           240, 10, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           10, 240, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (5): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           240, 240, kernel_size=(3, 3), stride=[2, 2], groups=240, bias=False
#           (static_padding): ZeroPad2d((0, 1, 0, 1))
#         )
#         (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           240, 10, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           10, 240, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (6-7): 2 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           480, 20, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           20, 480, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (8): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           480, 480, kernel_size=(5, 5), stride=[1, 1], groups=480, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           480, 20, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           20, 480, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (9-10): 2 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           672, 28, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           28, 672, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (11): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           672, 672, kernel_size=(5, 5), stride=[2, 2], groups=672, bias=False
#           (static_padding): ZeroPad2d((1, 2, 1, 2))
#         )
#         (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           672, 28, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           28, 672, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (12-14): 3 x MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#           (static_padding): ZeroPad2d((2, 2, 2, 2))
#         )
#         (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1152, 48, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           48, 1152, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (15): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1152, 1152, kernel_size=(3, 3), stride=[1, 1], groups=1152, bias=False
#           (static_padding): ZeroPad2d((1, 1, 1, 1))
#         )
#         (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1152, 48, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           48, 1152, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#     )
#     (_conv_head): Conv2dStaticSamePadding(
#       320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn1): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#     (_dropout): Dropout(p=0.2, inplace=False)
#     (_swish): MemoryEfficientSwish()
#   )
#   (decoder): UnetDecoder(
#     (center): Identity()
#     (blocks): ModuleList(
#       (0): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(432, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (1): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(296, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (2): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(152, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (3): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (4): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#     )
#   )
#   (segmentation_head): SegmentationHead(
#     (0): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Identity()
#     (2): Activation(
#       (activation): Identity()
#     )
#   )
# )

# %%
# Specify integer, starting at 1
init_epoch = None
if init_epoch != None:
    load_model(model, f"epoch_{init_epoch}_model.ckpt", optimizer)

# %%
def soft_dice(y_true, y_pred):
    smooth = 1
    intersection = torch.sum((y_true * y_pred))
    coeff = (2. * intersection + smooth) / (torch.sum(y_true) + torch.sum(y_pred) + smooth)
    return 1. - coeff


class soft_dice_cldice(nn.Module):
    def __init__(self, iter_=3, alpha=0.5, smooth=1.):
        super(soft_dice_cldice, self).__init__()
        self.iter = iter_
        self.smooth = smooth
        self.alpha = alpha

    def forward(self, y_pred, y_true):
        dice = soft_dice(y_true, y_pred)
        skel_pred = soft_skel(y_pred, self.iter)
        skel_true = soft_skel(y_true, self.iter)
        tprec = (torch.sum(torch.multiply(skel_pred, y_true)) + self.smooth) / (
                    torch.sum(skel_pred) + self.smooth)
        tsens = (torch.sum(torch.multiply(skel_true, y_pred)) + self.smooth) / (
                    torch.sum(skel_true) + self.smooth)
        cl_dice = 1. - 2.0 * (tprec * tsens) / (tprec + tsens)
        return (1.0 - self.alpha) * dice + self.alpha * cl_dice

class soft_cldice(nn.Module):
    def __init__(self, iter_=3, alpha=0.5, smooth=1.):
        super(soft_cldice, self).__init__()
        self.iter = iter_
        self.smooth = smooth
        self.alpha = alpha

    def forward(self, y_pred, y_true):
        skel_pred = soft_skel(y_pred, self.iter)
        skel_true = soft_skel(y_true, self.iter)
        tprec = (torch.sum(torch.multiply(skel_pred, y_true)) + self.smooth) / (
                    torch.sum(skel_pred) + self.smooth)
        tsens = (torch.sum(torch.multiply(skel_true, y_pred)) + self.smooth) / (
                    torch.sum(skel_true) + self.smooth)
        cl_dice = 1. - 2.0 * (tprec * tsens) / (tprec + tsens)
        return cl_dice

def soft_erode(img):
    if len(img.shape) == 4:
        p1 = -F.max_pool2d(-img, (3, 1), (1, 1), (1, 0))
        p2 = -F.max_pool2d(-img, (1, 3), (1, 1), (0, 1))
        return torch.min(p1, p2)
    elif len(img.shape) == 5:
        p1 = -F.max_pool3d(-img, (3, 1, 1), (1, 1, 1), (1, 0, 0))
        p2 = -F.max_pool3d(-img, (1, 3, 1), (1, 1, 1), (0, 1, 0))
        p3 = -F.max_pool3d(-img, (1, 1, 3), (1, 1, 1), (0, 0, 1))
        return torch.min(torch.min(p1, p2), p3)


def soft_dilate(img):
    if len(img.shape) == 4:
        return F.max_pool2d(img, (3, 3), (1, 1), (1, 1))
    elif len(img.shape) == 5:
        return F.max_pool3d(img, (3, 3, 3), (1, 1, 1), (1, 1, 1))


def soft_open(img):
    return soft_dilate(soft_erode(img))


def soft_skel(img, iter_):
    img1 = soft_open(img)
    skel = F.gelu(img - img1)
    for j in range(iter_):
        img = soft_erode(img)
        img1 = soft_open(img)
        delta = F.gelu(img - img1)
        skel = skel + F.gelu(delta - skel * delta)
    return skel

from skimage.morphology import skeletonize

def skel(img, iter_):
    img_tensor = img.detach().cpu().numpy()
    threshold = 0.5
    binary_image = (img_tensor > threshold).astype(np.uint8)
    skeletonized_tensor = torch.from_numpy(np.stack([skeletonize(im) for im in binary_image])).float().to('cuda:0')
    return skeletonized_tensor


class cldice(nn.Module):
    def __init__(self, iter_=3, alpha=0.5, smooth=1.):
        super(cldice, self).__init__()
        self.iter = iter_
        self.smooth = smooth
        self.alpha = alpha

    def forward(self, y_pred, y_true):
        skel_pred = skel(y_pred, self.iter)
        skel_true = skel(y_true, self.iter)
        tprec = (torch.sum(torch.multiply(skel_pred, y_true)) + self.smooth) / (
                    torch.sum(skel_pred) + self.smooth)
        tsens = (torch.sum(torch.multiply(skel_true, y_pred)) + self.smooth) / (
                    torch.sum(skel_true) + self.smooth)
        cl_dice = 1. - 2.0 * (tprec * tsens) / (tprec + tsens)
        return cl_dice

# %%
class persistence_loss(nn.Module):
    def __init__(self, dim=1):
        super(persistence_loss, self).__init__()
        self.persistence_algo = CubicalComplex()
        self.loss_fn = WassersteinDistance(q=1)

    def forward(self, y_pred, y_true):
        loss = 0.0
        batch_size = y_pred.size(0)
        for i in range(batch_size):
            pd_y_pred = self.persistence_algo(y_pred[i])
            pd_y_pred = pd_y_pred[0]
            pd_y_true = self.persistence_algo(y_true[i])[0]
            pd_y_true = pd_y_true[0]

            loss += self.loss_fn(pd_y_pred, pd_y_true)

        loss /= batch_size
        return loss

# %%
# Define loss and metrics
loss_1 = torch.nn.MSELoss(reduction="mean")
loss_2 = persistence_loss(dim=1)

# metrics = {"f1": torchmetrics.classification.F1Score(task='binary', num_classes=1, average="macro", mdmc_average="samplewise")}
metrics = {}

# %%
# Run training
train_history, val_history = training_loop(
    model=model,
    loss=[loss_1, loss_2],
    optimizer=optimizer,
    train_loader=train_loader,
    val_loader=test_loader,
    init_epoch=init_epoch,
    n_epochs=epochs,
    metrics_dict=metrics,
    save_path="model.ckpt",
    alpha=alpha
)
# Out:
# Epoch 1/200
#    -- Batch 1/5 / tensor(82.7399, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.6118724
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#    -- Batch 2/5 / tensor(76.5166, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.5255165
#    -- Batch 3/5 / tensor(85.3135, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.637281
#    -- Batch 4/5 / tensor(78.8501, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.5106263
#    -- Batch 5/5 / tensor(79.5738, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.5439396
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.5658472}
#    Validation: {'loss': 1.5626034621894367}
# Epoch 2/200
#    -- Batch 1/5 / tensor(73.8561, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.4656005
#    -- Batch 2/5 / tensor(79.1219, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.522775
#    -- Batch 3/5 / tensor(69.1031, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.4245796
#    -- Batch 4/5 / tensor(70.3322, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.3452431
#    -- Batch 5/5 / tensor(75.4533, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.4010935
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.4318583}
#    Validation: {'loss': 1.4546265715062625}
# Epoch 3/200
#    -- Batch 1/5 / tensor(69.5741, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.3672338
#    -- Batch 2/5 / tensor(73.1146, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.369894
#    -- Batch 3/5 / tensor(69.4852, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.2914705
#    -- Batch 4/5 / tensor(66.5472, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.237946
#    -- Batch 5/5 / tensor(66.6866, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.2451966
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.3023481}
#    Validation: {'loss': 1.3566466860771185}
# Epoch 4/200
#    -- Batch 1/5 / tensor(67.2033, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.2095933
#    -- Batch 2/5 / tensor(71.5768, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.2617527
#    -- Batch 3/5 / tensor(60.0978, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.1507461
#    -- Batch 4/5 / tensor(64.7517, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.2100611
#    -- Batch 5/5 / tensor(73.8078, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.31464
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.2293587}
#    Validation: {'loss': 1.2641725474298007}
# Epoch 5/200
#    -- Batch 1/5 / tensor(68.0408, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.2123393
#    -- Batch 2/5 / tensor(65.0715, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.1682115
#    -- Batch 3/5 / tensor(60.6420, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.0925143
#    -- Batch 4/5 / tensor(56.2639, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.0549846
#    -- Batch 5/5 / tensor(58.8092, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.0422845
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.1140668}
#    Validation: {'loss': 1.1823759369254119}
# Epoch 6/200
#    -- Batch 1/5 / tensor(62.3981, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.0978463
#    -- Batch 2/5 / tensor(57.2637, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.0346378
#    -- Batch 3/5 / tensor(57.4608, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.0421609
#    -- Batch 4/5 / tensor(54.1239, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.96788657
#    -- Batch 5/5 / tensor(54.5563, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.9696052
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 1.0224273}
#    Validation: {'loss': 1.1085043231695895}
# Epoch 7/200
#    -- Batch 1/5 / tensor(55.2253, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.9830852
#    -- Batch 2/5 / tensor(53.0566, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.91481715
#    -- Batch 3/5 / tensor(55.1397, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.9508274
#    -- Batch 4/5 / tensor(59.4324, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  1.0320803
#    -- Batch 5/5 / tensor(56.6626, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.97413695
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.9709894}
#    Validation: {'loss': 1.0425797849893574}
# Epoch 8/200
#    -- Batch 1/5 / tensor(49.6575, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.88374674
#    -- Batch 2/5 / tensor(52.1842, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.89252627
#    -- Batch 3/5 / tensor(45.2960, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.8071761
#    -- Batch 4/5 / tensor(47.3410, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.8251725
#    -- Batch 5/5 / tensor(52.7982, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.9208927
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.8659029}
#    Validation: {'loss': 0.9798344207704073}
# Epoch 9/200
#    -- Batch 1/5 / tensor(49.1654, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.83818865
#    -- Batch 2/5 / tensor(43.4061, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.76379794
#    -- Batch 3/5 / tensor(54.1882, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.9269824
#    -- Batch 4/5 / tensor(42.7248, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.73908406
#    -- Batch 5/5 / tensor(44.4641, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.7975602
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.81312263}
#    Validation: {'loss': 0.9245633716732268}
# Epoch 10/200
#    -- Batch 1/5 / tensor(41.9993, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.7330198
#    -- Batch 2/5 / tensor(46.6350, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.78354883
#    -- Batch 3/5 / tensor(41.9283, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.7373713
#    -- Batch 4/5 / tensor(45.0858, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.76545674
#    -- Batch 5/5 / tensor(40.8473, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.68355566
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.74059045}
#    Validation: {'loss': 0.8751865859180693}
# Epoch 11/200
#    -- Batch 1/5 / tensor(44.2507, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.75393295
#    -- Batch 2/5 / tensor(42.1539, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.7241534
#    -- Batch 3/5 / tensor(44.2785, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.7414781
#    -- Batch 4/5 / tensor(37.9294, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.64876825
#    -- Batch 5/5 / tensor(38.9657, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.6655657
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.70677966}
#    Validation: {'loss': 0.8305964703410869}
# Epoch 12/200
#    -- Batch 1/5 / tensor(39.5489, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.657099
#    -- Batch 2/5 / tensor(38.1078, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.6390971
#    -- Batch 3/5 / tensor(36.0458, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.61969596
#    -- Batch 4/5 / tensor(44.6343, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.72100306
#    -- Batch 5/5 / tensor(36.9556, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.6600447
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.65938795}
#    Validation: {'loss': 0.7905911892354492}
# Epoch 13/200
#    -- Batch 1/5 / tensor(34.2009, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.5779422
#    -- Batch 2/5 / tensor(45.4233, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.7463531
#    -- Batch 3/5 / tensor(36.2238, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.597226
#    -- Batch 4/5 / tensor(35.8656, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.5860452
#    -- Batch 5/5 / tensor(35.1228, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.5784621
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.61720574}
#    Validation: {'loss': 0.7537003635317091}
# Epoch 14/200
#    -- Batch 1/5 / tensor(35.1163, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.57342
#    -- Batch 2/5 / tensor(34.6564, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.5669399
#    -- Batch 3/5 / tensor(37.0658, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.6187134
#    -- Batch 4/5 / tensor(32.7563, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.54118097
#    -- Batch 5/5 / tensor(35.6623, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.5911407
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.578279}
#    Validation: {'loss': 0.7198460495769982}
# Epoch 15/200
#    -- Batch 1/5 / tensor(32.9297, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.5602797
#    -- Batch 2/5 / tensor(29.3414, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.52638847
#    -- Batch 3/5 / tensor(36.3223, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.6086173
#    -- Batch 4/5 / tensor(31.4824, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.527173
#    -- Batch 5/5 / tensor(31.5982, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.5343723
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.5513662}
#    Validation: {'loss': 0.688078679658473}
# Epoch 16/200
#    -- Batch 1/5 / tensor(30.9426, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.49391496
#    -- Batch 2/5 / tensor(30.1595, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.51596963
#    -- Batch 3/5 / tensor(35.9547, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.5915964
#    -- Batch 4/5 / tensor(33.6235, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.56520194
#    -- Batch 5/5 / tensor(29.0107, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.49655882
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.5326484}
#    Validation: {'loss': 0.6612740979567173}
# Epoch 17/200
#    -- Batch 1/5 / tensor(30.9175, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.495219
#    -- Batch 2/5 / tensor(28.2600, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.5045674
#    -- Batch 3/5 / tensor(28.0763, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.4603565
#    -- Batch 4/5 / tensor(27.7572, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.47600445
#    -- Batch 5/5 / tensor(32.1051, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.51229066
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.4896876}
#    Validation: {'loss': 0.6346928415596489}
# Epoch 18/200
#    -- Batch 1/5 / tensor(30.0642, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.49655563
#    -- Batch 2/5 / tensor(29.9281, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.48767972
#    -- Batch 3/5 / tensor(28.5874, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.45757633
#    -- Batch 4/5 / tensor(28.4805, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.47342575
#    -- Batch 5/5 / tensor(27.3292, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.46816015
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.4766795}
#    Validation: {'loss': 0.6110999927967791}
# Epoch 19/200
#    -- Batch 1/5 / tensor(24.4548, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.42306256
#    -- Batch 2/5 / tensor(26.1826, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.43728018
#    -- Batch 3/5 / tensor(30.5939, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.5173098
#    -- Batch 4/5 / tensor(26.5560, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.4340895
#    -- Batch 5/5 / tensor(26.6266, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.44328538
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.45100552}
#    Validation: {'loss': 0.5905651828348639}
# Epoch 20/200
#    -- Batch 1/5 / tensor(26.7678, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.4502774
#    -- Batch 2/5 / tensor(27.4854, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.4382891
#    -- Batch 3/5 / tensor(23.0009, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.3912812
#    -- Batch 4/5 / tensor(25.3528, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.4164133
#    -- Batch 5/5 / tensor(27.7690, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.4571183
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.43067583}
#    Validation: {'loss': 0.5682639134898785}
# Epoch 21/200
#    -- Batch 1/5 / tensor(25.8511, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.43665355
#    -- Batch 2/5 / tensor(24.9975, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.40878314
#    -- Batch 3/5 / tensor(25.1905, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.4087016
#    -- Batch 4/5 / tensor(26.9037, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.44853225
#    -- Batch 5/5 / tensor(25.5480, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.40709335
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.42195278}
#    Validation: {'loss': 0.5512991313412788}
# Epoch 22/200
#    -- Batch 1/5 / tensor(23.5410, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.40563723
#    -- Batch 2/5 / tensor(24.3348, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.39562234
#    -- Batch 3/5 / tensor(24.7380, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.42665386
#    -- Batch 4/5 / tensor(20.5925, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.3458122
#    -- Batch 5/5 / tensor(23.6497, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.3926731
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.39327973}
#    Validation: {'loss': 0.5336140541657808}
# Epoch 23/200
#    -- Batch 1/5 / tensor(26.5334, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.42538565
#    -- Batch 2/5 / tensor(22.4177, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.38067085
#    -- Batch 3/5 / tensor(24.8183, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.4085624
#    -- Batch 4/5 / tensor(22.8725, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.37826967
#    -- Batch 5/5 / tensor(23.4172, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.39931497
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.39844072}
#    Validation: {'loss': 0.5189628277048471}
# Epoch 24/200
#    -- Batch 1/5 / tensor(22.2849, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.36070254
#    -- Batch 2/5 / tensor(23.3110, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.41120058
#    -- Batch 3/5 / tensor(23.0241, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.38018358
#    -- Batch 4/5 / tensor(20.3669, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.3518905
#    -- Batch 5/5 / tensor(21.1834, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.35109594
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.37101465}
#    Validation: {'loss': 0.5048852864578369}
# Epoch 25/200
#    -- Batch 1/5 / tensor(23.6935, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.392623
#    -- Batch 2/5 / tensor(21.9229, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.36614716
#    -- Batch 3/5 / tensor(20.3083, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.35199746
#    -- Batch 4/5 / tensor(20.9622, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.35105407
#    -- Batch 5/5 / tensor(20.6604, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.347238
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.36181194}
#    Validation: {'loss': 0.49035011923313165}
# Epoch 26/200
#    -- Batch 1/5 / tensor(20.7494, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.34205103
#    -- Batch 2/5 / tensor(22.2043, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.36876297
#    -- Batch 3/5 / tensor(20.3980, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.33956635
#    -- Batch 4/5 / tensor(21.2754, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.35409147
#    -- Batch 5/5 / tensor(19.2294, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.34065363
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.3490251}
#    Validation: {'loss': 0.4772576158046725}
# Epoch 27/200
#    -- Batch 1/5 / tensor(19.8974, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.3293388
#    -- Batch 2/5 / tensor(21.8024, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.37287349
#    -- Batch 3/5 / tensor(19.6044, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.32247472
#    -- Batch 4/5 / tensor(21.8390, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.38019097
#    -- Batch 5/5 / tensor(20.9744, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.34141904
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.34925944}
#    Validation: {'loss': 0.46544457415491375}
# Epoch 28/200
#    -- Batch 1/5 / tensor(18.5931, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.33725595
#    -- Batch 2/5 / tensor(18.0660, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.31008214
#    -- Batch 3/5 / tensor(20.3892, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.3370164
#    -- Batch 4/5 / tensor(22.2354, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.34867707
#    -- Batch 5/5 / tensor(20.1419, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.3395249
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.33451128}
#    Validation: {'loss': 0.45337753170728706}
# Epoch 29/200
#    -- Batch 1/5 / tensor(17.8608, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.31187415
#    -- Batch 2/5 / tensor(19.0033, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.32014477
#    -- Batch 3/5 / tensor(20.1853, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.32516268
#    -- Batch 4/5 / tensor(17.9162, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2973517
#    -- Batch 5/5 / tensor(17.0069, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.30387527
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.3116817}
#    Validation: {'loss': 0.4427941929996016}
# Epoch 30/200
#    -- Batch 1/5 / tensor(18.6690, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.31178266
#    -- Batch 2/5 / tensor(18.8330, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.30639172
#    -- Batch 3/5 / tensor(19.2401, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.32069522
#    -- Batch 4/5 / tensor(17.2058, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.29010266
#    -- Batch 5/5 / tensor(17.8458, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.30698317
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.30719107}
#    Validation: {'loss': 0.43254259789735106}
# Epoch 31/200
#    -- Batch 1/5 / tensor(18.7730, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.32728493
#    -- Batch 2/5 / tensor(19.6496, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.3162653
#    -- Batch 3/5 / tensor(18.2486, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.3120762
#    -- Batch 4/5 / tensor(18.3176, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.30837125
#    -- Batch 5/5 / tensor(15.4433, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.26752132
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.30630383}
#    Validation: {'loss': 0.4235549564659598}
# Epoch 32/200
#    -- Batch 1/5 / tensor(16.7681, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.279616
#    -- Batch 2/5 / tensor(17.5905, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.3037382
#    -- Batch 3/5 / tensor(16.4843, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.28497624
#    -- Batch 4/5 / tensor(17.8577, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.3069377
#    -- Batch 5/5 / tensor(17.6242, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2946919
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.293992}
#    Validation: {'loss': 0.41455768349766753}
# Epoch 33/200
#    -- Batch 1/5 / tensor(16.4894, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.29320723
#    -- Batch 2/5 / tensor(18.0523, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.30645946
#    -- Batch 3/5 / tensor(17.4071, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.30645916
#    -- Batch 4/5 / tensor(16.8227, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2732187
#    -- Batch 5/5 / tensor(18.2124, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.3018451
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.29623795}
#    Validation: {'loss': 0.4045847430042925}
# Epoch 34/200
#    -- Batch 1/5 / tensor(16.0913, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.287875
#    -- Batch 2/5 / tensor(16.3338, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.26813018
#    -- Batch 3/5 / tensor(16.6744, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.27391633
#    -- Batch 4/5 / tensor(15.7094, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.27327922
#    -- Batch 5/5 / tensor(18.3672, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.31471986
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.28358412}
#    Validation: {'loss': 0.3965499301701786}
# Epoch 35/200
#    -- Batch 1/5 / tensor(15.1975, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.26960856
#    -- Batch 2/5 / tensor(14.7500, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2611739
#    -- Batch 3/5 / tensor(16.6081, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.28166065
#    -- Batch 4/5 / tensor(16.7188, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2727796
#    -- Batch 5/5 / tensor(17.0317, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2859363
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.27423182}
#    Validation: {'loss': 0.3887437019757929}
# Epoch 36/200
#    -- Batch 1/5 / tensor(15.4809, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2560453
#    -- Batch 2/5 / tensor(15.9508, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.28603
#    -- Batch 3/5 / tensor(17.5401, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.30775854
#    -- Batch 4/5 / tensor(15.2656, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2765822
#    -- Batch 5/5 / tensor(15.1681, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2629754
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.27787828}
#    Validation: {'loss': 0.3815517044365408}
# Epoch 37/200
#    -- Batch 1/5 / tensor(14.3563, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.24017188
#    -- Batch 2/5 / tensor(15.7473, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.26832014
#    -- Batch 3/5 / tensor(16.2525, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.28694904
#    -- Batch 4/5 / tensor(16.8268, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.28717536
#    -- Batch 5/5 / tensor(16.2585, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2841095
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.27334517}
#    Validation: {'loss': 0.3739330684877934}
# Epoch 38/200
#    -- Batch 1/5 / tensor(15.7143, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2759379
#    -- Batch 2/5 / tensor(15.1504, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.272159
#    -- Batch 3/5 / tensor(15.8149, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.26468825
#    -- Batch 4/5 / tensor(14.6845, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2519941
#    -- Batch 5/5 / tensor(13.3971, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.22545707
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.25804728}
#    Validation: {'loss': 0.36683346294239183}
# Epoch 39/200
#    -- Batch 1/5 / tensor(16.0623, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.28793088
#    -- Batch 2/5 / tensor(16.1763, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.26234204
#    -- Batch 3/5 / tensor(15.4550, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2767424
#    -- Batch 4/5 / tensor(15.9652, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.27209437
#    -- Batch 5/5 / tensor(13.1828, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.23283666
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.26638928}
#    Validation: {'loss': 0.3608524390198292}
# Epoch 40/200
#    -- Batch 1/5 / tensor(15.6643, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2651447
#    -- Batch 2/5 / tensor(15.2662, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.26370692
#    -- Batch 3/5 / tensor(15.4140, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.28032374
#    -- Batch 4/5 / tensor(16.0680, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.26541385
#    -- Batch 5/5 / tensor(14.1917, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.26496977
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.26791182}
#    Validation: {'loss': 0.352935888502747}
# Epoch 41/200
#    -- Batch 1/5 / tensor(14.9500, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.24747609
#    -- Batch 2/5 / tensor(14.7516, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.26542774
#    -- Batch 3/5 / tensor(14.9757, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.26864603
#    -- Batch 4/5 / tensor(13.3447, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.24726126
#    -- Batch 5/5 / tensor(13.6069, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.23939657
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.25364155}
#    Validation: {'loss': 0.3452648655064406}
# Epoch 42/200
#    -- Batch 1/5 / tensor(14.4772, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2664998
#    -- Batch 2/5 / tensor(13.7167, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.23786542
#    -- Batch 3/5 / tensor(11.9102, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21528316
#    -- Batch 4/5 / tensor(12.7047, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21787009
#    -- Batch 5/5 / tensor(13.8207, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2350227
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.23450823}
#    Validation: {'loss': 0.3387795854024591}
# Epoch 43/200
#    -- Batch 1/5 / tensor(12.7148, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.24288666
#    -- Batch 2/5 / tensor(14.2201, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.25728136
#    -- Batch 3/5 / tensor(13.5320, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2338709
#    -- Batch 4/5 / tensor(12.3448, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.22794247
#    -- Batch 5/5 / tensor(14.7393, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.23896778
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.24018984}
#    Validation: {'loss': 0.33300893366709367}
# Epoch 44/200
#    -- Batch 1/5 / tensor(13.3979, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.23786707
#    -- Batch 2/5 / tensor(12.3250, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.22031637
#    -- Batch 3/5 / tensor(12.6707, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.22003776
#    -- Batch 4/5 / tensor(13.6124, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.24467058
#    -- Batch 5/5 / tensor(12.5538, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.22864635
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.23030762}
#    Validation: {'loss': 0.3281268255077304}
# Epoch 45/200
#    -- Batch 1/5 / tensor(13.6463, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.24327835
#    -- Batch 2/5 / tensor(11.7223, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21207295
#    -- Batch 3/5 / tensor(12.0032, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.22802767
#    -- Batch 4/5 / tensor(13.7879, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.23114766
#    -- Batch 5/5 / tensor(12.2646, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21846284
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.22659788}
#    Validation: {'loss': 0.32303532754257336}
# Epoch 46/200
#    -- Batch 1/5 / tensor(11.4007, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.203704
#    -- Batch 2/5 / tensor(12.7976, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2170197
#    -- Batch 3/5 / tensor(12.0028, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21858418
#    -- Batch 4/5 / tensor(12.1754, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21741116
#    -- Batch 5/5 / tensor(12.6859, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.23086828
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.21751747}
#    Validation: {'loss': 0.31946376153454203}
# Epoch 47/200
#    -- Batch 1/5 / tensor(12.6077, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2181727
#    -- Batch 2/5 / tensor(12.6400, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2192747
#    -- Batch 3/5 / tensor(11.2610, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.20643055
#    -- Batch 4/5 / tensor(13.0312, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.24195284
#    -- Batch 5/5 / tensor(11.2485, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.20527692
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.21822155}
#    Validation: {'loss': 0.3148283927999439}
# Epoch 48/200
#    -- Batch 1/5 / tensor(12.0856, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.22134921
#    -- Batch 2/5 / tensor(10.4864, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19477078
#    -- Batch 3/5 / tensor(14.3024, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.25299817
#    -- Batch 4/5 / tensor(10.7437, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19562599
#    -- Batch 5/5 / tensor(13.7790, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.23164618
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.21927807}
#    Validation: {'loss': 0.3104611433707179}
# Epoch 49/200
#    -- Batch 1/5 / tensor(12.1683, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.22813737
#    -- Batch 2/5 / tensor(11.7368, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21271148
#    -- Batch 3/5 / tensor(12.8152, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.22877027
#    -- Batch 4/5 / tensor(12.4826, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.22095737
#    -- Batch 5/5 / tensor(12.6073, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21541913
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.22119913}
#    Validation: {'loss': 0.3062142315991224}
# Epoch 50/200
#    -- Batch 1/5 / tensor(11.5859, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21153133
#    -- Batch 2/5 / tensor(10.7637, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19684982
#    -- Batch 3/5 / tensor(10.5788, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19122109
#    -- Batch 4/5 / tensor(10.8732, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.20143974
#    -- Batch 5/5 / tensor(12.1190, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.22253919
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20471624}
#    Validation: {'loss': 0.3024508041255177}
# Epoch 51/200
#    -- Batch 1/5 / tensor(11.0357, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21512309
#    -- Batch 2/5 / tensor(9.3881, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19049773
#    -- Batch 3/5 / tensor(11.2214, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19299896
#    -- Batch 4/5 / tensor(11.7628, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2036573
#    -- Batch 5/5 / tensor(12.0016, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21279606
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20301464}
#    Validation: {'loss': 0.29896405909210455}
# Epoch 52/200
#    -- Batch 1/5 / tensor(11.2926, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.18841282
#    -- Batch 2/5 / tensor(10.9449, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21002969
#    -- Batch 3/5 / tensor(11.2054, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.22194463
#    -- Batch 4/5 / tensor(11.8334, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21564837
#    -- Batch 5/5 / tensor(10.6057, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19816503
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20684011}
#    Validation: {'loss': 0.2948591019250454}
# Epoch 53/200
#    -- Batch 1/5 / tensor(11.5620, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21222217
#    -- Batch 2/5 / tensor(11.5321, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21116352
#    -- Batch 3/5 / tensor(10.9647, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21034588
#    -- Batch 4/5 / tensor(12.0743, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2258229
#    -- Batch 5/5 / tensor(11.4924, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21183655
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.21427819}
#    Validation: {'loss': 0.29113386599719543}
# Epoch 54/200
#    -- Batch 1/5 / tensor(10.5244, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.18698245
#    -- Batch 2/5 / tensor(11.2469, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21437287
#    -- Batch 3/5 / tensor(10.4947, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19784726
#    -- Batch 4/5 / tensor(11.1906, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19971287
#    -- Batch 5/5 / tensor(9.6269, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17588407
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.19495991}
#    Validation: {'loss': 0.2869634979851546}
# Epoch 55/200
#    -- Batch 1/5 / tensor(10.2792, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.18950027
#    -- Batch 2/5 / tensor(11.3458, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.20598958
#    -- Batch 3/5 / tensor(10.4850, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1879698
#    -- Batch 4/5 / tensor(9.9582, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.20279333
#    -- Batch 5/5 / tensor(10.4967, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.20125973
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.19750254}
#    Validation: {'loss': 0.2834515034742655}
# Epoch 56/200
#    -- Batch 1/5 / tensor(10.4932, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.20374075
#    -- Batch 2/5 / tensor(10.6151, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21064171
#    -- Batch 3/5 / tensor(10.1741, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.18281455
#    -- Batch 4/5 / tensor(10.1817, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19682035
#    -- Batch 5/5 / tensor(9.9404, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.18473631
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.19575073}
#    Validation: {'loss': 0.2793840269856156}
# Epoch 57/200
#    -- Batch 1/5 / tensor(9.6490, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19446383
#    -- Batch 2/5 / tensor(10.4798, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.18753472
#    -- Batch 3/5 / tensor(10.3800, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.20003432
#    -- Batch 4/5 / tensor(11.9605, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19772851
#    -- Batch 5/5 / tensor(11.1948, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1974155
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.19543537}
#    Validation: {'loss': 0.2759102315604688}
# Epoch 58/200
#    -- Batch 1/5 / tensor(10.2333, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.20417511
#    -- Batch 2/5 / tensor(10.2208, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19449365
#    -- Batch 3/5 / tensor(12.2040, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.23177144
#    -- Batch 4/5 / tensor(10.7921, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19125223
#    -- Batch 5/5 / tensor(10.6239, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19194771
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20272803}
#    Validation: {'loss': 0.27152249627187863}
# Epoch 59/200
#    -- Batch 1/5 / tensor(9.6563, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17002957
#    -- Batch 2/5 / tensor(10.8560, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.2124953
#    -- Batch 3/5 / tensor(10.5028, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19012502
#    -- Batch 4/5 / tensor(8.8822, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16315162
#    -- Batch 5/5 / tensor(9.2220, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.18903066
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.18496642}
#    Validation: {'loss': 0.2681441833600403}
# Epoch 60/200
#    -- Batch 1/5 / tensor(11.7727, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.21783888
#    -- Batch 2/5 / tensor(9.5909, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.18493491
#    -- Batch 3/5 / tensor(9.8590, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19421412
#    -- Batch 4/5 / tensor(9.0915, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17065996
#    -- Batch 5/5 / tensor(10.5340, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.18777373
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.19108431}
#    Validation: {'loss': 0.2648676113076509}
# Epoch 61/200
#    -- Batch 1/5 / tensor(8.8903, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16595772
#    -- Batch 2/5 / tensor(11.6791, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19740967
#    -- Batch 3/5 / tensor(9.2573, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19639707
#    -- Batch 4/5 / tensor(10.8076, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19291762
#    -- Batch 5/5 / tensor(9.6464, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17678714
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.18589385}
#    Validation: {'loss': 0.2615217962488533}
# Epoch 62/200
#    -- Batch 1/5 / tensor(10.0063, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19369903
#    -- Batch 2/5 / tensor(9.1663, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17572153
#    -- Batch 3/5 / tensor(7.9001, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16174975
#    -- Batch 4/5 / tensor(8.5078, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1778498
#    -- Batch 5/5 / tensor(9.2616, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1758369
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1769714}
#    Validation: {'loss': 0.2586693286299707}
# Epoch 63/200
#    -- Batch 1/5 / tensor(8.5283, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16039833
#    -- Batch 2/5 / tensor(9.8570, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.18006396
#    -- Batch 3/5 / tensor(8.0401, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17264625
#    -- Batch 4/5 / tensor(11.1611, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19723123
#    -- Batch 5/5 / tensor(8.5311, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16869405
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17580676}
#    Validation: {'loss': 0.25620783000066893}
# Epoch 64/200
#    -- Batch 1/5 / tensor(8.8594, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16032512
#    -- Batch 2/5 / tensor(9.5808, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.18363655
#    -- Batch 3/5 / tensor(9.3509, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16409539
#    -- Batch 4/5 / tensor(8.8412, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17751332
#    -- Batch 5/5 / tensor(9.2722, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1859799
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17431006}
#    Validation: {'loss': 0.2537579274736346}
# Epoch 65/200
#    -- Batch 1/5 / tensor(9.0129, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16244143
#    -- Batch 2/5 / tensor(10.5868, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.20629668
#    -- Batch 3/5 / tensor(9.3240, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16957445
#    -- Batch 4/5 / tensor(9.1027, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1742943
#    -- Batch 5/5 / tensor(8.6490, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17757148
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17803566}
#    Validation: {'loss': 0.2508044409267606}
# Epoch 66/200
#    -- Batch 1/5 / tensor(9.9517, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17422923
#    -- Batch 2/5 / tensor(9.0459, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1701425
#    -- Batch 3/5 / tensor(9.2630, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17793906
#    -- Batch 4/5 / tensor(8.4617, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1708563
#    -- Batch 5/5 / tensor(8.8654, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16637531
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17190847}
#    Validation: {'loss': 0.2486095158159735}
# Epoch 67/200
#    -- Batch 1/5 / tensor(10.2121, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.20619556
#    -- Batch 2/5 / tensor(8.1891, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16572124
#    -- Batch 3/5 / tensor(8.9360, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16435948
#    -- Batch 4/5 / tensor(7.8120, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.15251598
#    -- Batch 5/5 / tensor(8.6962, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17149234
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17205691}
#    Validation: {'loss': 0.24610048326849948}
# Epoch 68/200
#    -- Batch 1/5 / tensor(7.7216, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.15107115
#    -- Batch 2/5 / tensor(9.0479, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.19244543
#    -- Batch 3/5 / tensor(8.7494, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16918994
#    -- Batch 4/5 / tensor(10.9355, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.20233428
#    -- Batch 5/5 / tensor(7.5109, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.14551008
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17211017}
#    Validation: {'loss': 0.24295747813954965}
# Epoch 69/200
#    -- Batch 1/5 / tensor(8.5968, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1611117
#    -- Batch 2/5 / tensor(8.7211, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16935557
#    -- Batch 3/5 / tensor(8.8744, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16680145
#    -- Batch 4/5 / tensor(8.2299, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16503522
#    -- Batch 5/5 / tensor(8.5434, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16900836
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16626246}
#    Validation: {'loss': 0.24020902177691475}
# Epoch 70/200
#    -- Batch 1/5 / tensor(9.0679, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.18369019
#    -- Batch 2/5 / tensor(9.0860, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1748198
#    -- Batch 3/5 / tensor(8.3368, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.15500766
#    -- Batch 4/5 / tensor(9.7615, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.18269363
#    -- Batch 5/5 / tensor(8.9145, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17114237
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1734707}
#    Validation: {'loss': 0.2373547661006452}
# Epoch 71/200
#    -- Batch 1/5 / tensor(9.1620, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.18186516
#    -- Batch 2/5 / tensor(9.5399, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17700738
#    -- Batch 3/5 / tensor(8.6270, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17656791
#    -- Batch 4/5 / tensor(8.3582, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16471496
#    -- Batch 5/5 / tensor(7.0784, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.15231258
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17049359}
#    Validation: {'loss': 0.23517210451513543}
# Epoch 72/200
#    -- Batch 1/5 / tensor(8.5685, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16760272
#    -- Batch 2/5 / tensor(8.9312, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17700356
#    -- Batch 3/5 / tensor(7.7932, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16059002
#    -- Batch 4/5 / tensor(8.3072, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16464402
#    -- Batch 5/5 / tensor(7.7586, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1493544
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16383895}
#    Validation: {'loss': 0.2333493321649731}
# Epoch 73/200
#    -- Batch 1/5 / tensor(8.9768, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16709112
#    -- Batch 2/5 / tensor(9.5670, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17948622
#    -- Batch 3/5 / tensor(9.0333, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16341457
#    -- Batch 4/5 / tensor(7.9158, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.15977514
#    -- Batch 5/5 / tensor(7.2262, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.15034345
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16402209}
#    Validation: {'loss': 0.23093189983069906}
# Epoch 74/200
#    -- Batch 1/5 / tensor(8.3430, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17592993
#    -- Batch 2/5 / tensor(7.2447, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.14309436
#    -- Batch 3/5 / tensor(8.7499, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1687121
#    -- Batch 4/5 / tensor(7.0555, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.14648923
#    -- Batch 5/5 / tensor(7.2391, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.14305994
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15545711}
#    Validation: {'loss': 0.2289523431695999}
# Epoch 75/200
#    -- Batch 1/5 / tensor(7.3690, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1659851
#    -- Batch 2/5 / tensor(9.0327, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16321787
#    -- Batch 3/5 / tensor(7.4514, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.15066728
#    -- Batch 4/5 / tensor(8.7221, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16918997
#    -- Batch 5/5 / tensor(6.8755, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1358285
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15697774}
#    Validation: {'loss': 0.2268992942199112}
# Epoch 76/200
#    -- Batch 1/5 / tensor(9.1833, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17441574
#    -- Batch 2/5 / tensor(7.6501, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16065043
#    -- Batch 3/5 / tensor(7.7705, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.15341529
#    -- Batch 4/5 / tensor(7.3608, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.14803961
#    -- Batch 5/5 / tensor(6.8555, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1343959
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1541834}
#    Validation: {'loss': 0.22520788145437845}
# Epoch 77/200
#    -- Batch 1/5 / tensor(8.1074, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.15891504
#    -- Batch 2/5 / tensor(7.8208, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16455421
#    -- Batch 3/5 / tensor(8.8283, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16784382
#    -- Batch 4/5 / tensor(8.5423, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.1666893
#    -- Batch 5/5 / tensor(6.7714, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.13680413
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1589613}
#    Validation: {'loss': 0.22333824746310724}
# Epoch 78/200
#    -- Batch 1/5 / tensor(7.9148, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.15574673
#    -- Batch 2/5 / tensor(7.6342, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.14022154
#    -- Batch 3/5 / tensor(7.7859, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16048747
#    -- Batch 4/5 / tensor(7.4477, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.15283197
#    -- Batch 5/5 / tensor(8.3103, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16710584
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15527871}
#    Validation: {'loss': 0.22144163548201332}
# Epoch 79/200
#    -- Batch 1/5 / tensor(8.2175, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.16429627
#    -- Batch 2/5 / tensor(9.0495, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.17933357
#    -- Batch 3/5 / tensor(7.0080, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.15150702
#    -- Batch 4/5 / tensor(7.4597, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.14378408
#    -- Batch 5/5 / tensor(7.9722, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.15034431
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15785304}
# ...
#    -- Batch 4/5 / tensor(4.0121, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09088321
#    -- Batch 5/5 / tensor(3.9413, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.092499286
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0937423}
#    Validation: {'loss': 0.14038450974598535}
# Epoch 175/200
#    -- Batch 1/5 / tensor(3.8662, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08427326
#    -- Batch 2/5 / tensor(3.7125, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09311407
#    -- Batch 3/5 / tensor(4.3930, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.10785445
#    -- Batch 4/5 / tensor(3.1658, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08612257
#    -- Batch 5/5 / tensor(4.2368, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.096517876
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.093576446}
#    Validation: {'loss': 0.1394154196288437}
# Epoch 176/200
#    -- Batch 1/5 / tensor(4.6039, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.10035831
#    -- Batch 2/5 / tensor(4.1661, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.10115859
#    -- Batch 3/5 / tensor(3.3165, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08535117
#    -- Batch 4/5 / tensor(3.1949, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08485815
#    -- Batch 5/5 / tensor(3.6089, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.087622
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09186964}
#    Validation: {'loss': 0.13890489715896553}
# Epoch 177/200
#    -- Batch 1/5 / tensor(3.4730, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09325794
#    -- Batch 2/5 / tensor(3.3989, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08111109
#    -- Batch 3/5 / tensor(4.6180, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.101941794
#    -- Batch 4/5 / tensor(3.8906, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.092818454
#    -- Batch 5/5 / tensor(3.9521, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09253992
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09233384}
#    Validation: {'loss': 0.13846691207028933}
# Epoch 178/200
#    -- Batch 1/5 / tensor(4.1112, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.10572246
#    -- Batch 2/5 / tensor(3.5134, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08853054
#    -- Batch 3/5 / tensor(3.0757, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.07945646
#    -- Batch 4/5 / tensor(3.8093, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09005666
#    -- Batch 5/5 / tensor(4.6283, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.10083497
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09292022}
#    Validation: {'loss': 0.13809688367880885}
# Epoch 179/200
#    -- Batch 1/5 / tensor(4.8522, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.10565628
#    -- Batch 2/5 / tensor(4.5699, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.101784945
#    -- Batch 3/5 / tensor(3.3089, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09115437
#    -- Batch 4/5 / tensor(3.5588, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08684221
#    -- Batch 5/5 / tensor(3.3640, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08372126
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.093831815}
#    Validation: {'loss': 0.13766846999712293}
# Epoch 180/200
#    -- Batch 1/5 / tensor(3.4046, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08109963
#    -- Batch 2/5 / tensor(4.0386, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09961714
#    -- Batch 3/5 / tensor(3.5906, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09046608
#    -- Batch 4/5 / tensor(3.7500, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09422053
#    -- Batch 5/5 / tensor(3.8713, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08695788
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.090472244}
#    Validation: {'loss': 0.13745491273514931}
# Epoch 181/200
#    -- Batch 1/5 / tensor(3.4386, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08233957
#    -- Batch 2/5 / tensor(2.8980, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.07698911
#    -- Batch 3/5 / tensor(4.1698, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.10256954
#    -- Batch 4/5 / tensor(4.4590, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.10450261
#    -- Batch 5/5 / tensor(4.1183, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09554403
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09238897}
#    Validation: {'loss': 0.13739761625416583}
# Epoch 182/200
#    -- Batch 1/5 / tensor(4.1452, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09358844
#    -- Batch 2/5 / tensor(3.5265, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09307745
#    -- Batch 3/5 / tensor(4.2050, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.10207231
#    -- Batch 4/5 / tensor(3.5723, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08381218
#    -- Batch 5/5 / tensor(3.1848, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.078451656
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09020041}
#    Validation: {'loss': 0.13753514921851462}
# Epoch 183/200
#    -- Batch 1/5 / tensor(3.9115, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09124376
#    -- Batch 2/5 / tensor(4.0401, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09046167
#    -- Batch 3/5 / tensor(4.1222, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.0901136
#    -- Batch 4/5 / tensor(3.7745, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.090427
#    -- Batch 5/5 / tensor(3.1449, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09021236
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.090491675}
#    Validation: {'loss': 0.137149878775701}
# Epoch 184/200
#    -- Batch 1/5 / tensor(3.5251, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.0876285
#    -- Batch 2/5 / tensor(4.1172, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.098200634
#    -- Batch 3/5 / tensor(3.6626, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09289854
#    -- Batch 4/5 / tensor(2.8780, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08121199
#    -- Batch 5/5 / tensor(4.0599, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08652482
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0892929}
#    Validation: {'loss': 0.13674439689330758}
# Epoch 185/200
#    -- Batch 1/5 / tensor(4.7017, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.10387988
#    -- Batch 2/5 / tensor(3.3884, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.078798786
#    -- Batch 3/5 / tensor(3.2994, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08303817
#    -- Batch 4/5 / tensor(4.0209, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.093109086
#    -- Batch 5/5 / tensor(3.2044, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.089972034
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08975959}
#    Validation: {'loss': 0.13612307638674978}
# Epoch 186/200
#    -- Batch 1/5 / tensor(3.9347, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08218735
#    -- Batch 2/5 / tensor(4.8676, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.10981238
#    -- Batch 3/5 / tensor(3.7948, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09589255
#    -- Batch 4/5 / tensor(3.8284, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09449073
#    -- Batch 5/5 / tensor(3.2121, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08825112
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09412683}
#    Validation: {'loss': 0.1355773061010987}
# Epoch 187/200
#    -- Batch 1/5 / tensor(4.6589, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09799439
#    -- Batch 2/5 / tensor(3.2870, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.077186316
#    -- Batch 3/5 / tensor(3.1450, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08247319
#    -- Batch 4/5 / tensor(4.6771, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.111750975
#    -- Batch 5/5 / tensor(2.8651, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.085566044
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09099418}
#    Validation: {'loss': 0.13546721898764374}
# Epoch 188/200
#    -- Batch 1/5 / tensor(3.2313, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08282218
#    -- Batch 2/5 / tensor(3.6676, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09563307
#    -- Batch 3/5 / tensor(3.0210, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08054301
#    -- Batch 4/5 / tensor(4.2654, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.099227905
#    -- Batch 5/5 / tensor(3.5803, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08427422
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08850008}
#    Validation: {'loss': 0.13477738060988492}
# Epoch 189/200
#    -- Batch 1/5 / tensor(3.7177, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08606377
#    -- Batch 2/5 / tensor(3.6827, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08522418
#    -- Batch 3/5 / tensor(3.1123, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08509411
#    -- Batch 4/5 / tensor(3.5747, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09031182
#    -- Batch 5/5 / tensor(4.5773, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.10124461
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0895877}
#    Validation: {'loss': 0.13511758644320074}
# Epoch 190/200
#    -- Batch 1/5 / tensor(3.0712, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.080580436
#    -- Batch 2/5 / tensor(3.7722, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08802959
#    -- Batch 3/5 / tensor(3.8626, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.102064624
#    -- Batch 4/5 / tensor(4.2983, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09263736
#    -- Batch 5/5 / tensor(3.1906, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.0781184
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08828608}
#    Validation: {'loss': 0.13476632714644082}
# Epoch 191/200
#    -- Batch 1/5 / tensor(4.1446, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09931822
#    -- Batch 2/5 / tensor(3.5529, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08603577
#    -- Batch 3/5 / tensor(3.4849, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08624935
#    -- Batch 4/5 / tensor(3.9937, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09922678
#    -- Batch 5/5 / tensor(3.3388, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.080811
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.090328224}
#    Validation: {'loss': 0.1349297490678728}
# Epoch 192/200
#    -- Batch 1/5 / tensor(3.7091, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08903855
#    -- Batch 2/5 / tensor(3.1358, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.07914719
#    -- Batch 3/5 / tensor(3.2539, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.0840776
#    -- Batch 4/5 / tensor(4.1430, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.10208568
#    -- Batch 5/5 / tensor(3.4686, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08103505
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08707681}
#    Validation: {'loss': 0.13434190083853906}
# Epoch 193/200
#    -- Batch 1/5 / tensor(3.4249, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.089438766
#    -- Batch 2/5 / tensor(4.0416, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.093357146
#    -- Batch 3/5 / tensor(4.2648, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.10164637
#    -- Batch 4/5 / tensor(3.5561, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.088584244
#    -- Batch 5/5 / tensor(3.2991, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.07352474
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08931025}
#    Validation: {'loss': 0.1337303988412023}
# Epoch 194/200
#    -- Batch 1/5 / tensor(3.5015, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09046067
#    -- Batch 2/5 / tensor(3.3320, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.081523195
#    -- Batch 3/5 / tensor(3.7353, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08988474
#    -- Batch 4/5 / tensor(3.1529, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08517041
#    -- Batch 5/5 / tensor(3.3481, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08606799
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0866214}
#    Validation: {'loss': 0.13324895791150634}
# Epoch 195/200
#    -- Batch 1/5 / tensor(3.3949, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08578977
#    -- Batch 2/5 / tensor(3.7494, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09119061
#    -- Batch 3/5 / tensor(3.6058, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08225432
#    -- Batch 4/5 / tensor(3.1702, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08176867
#    -- Batch 5/5 / tensor(3.3233, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09030221
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08626111}
#    Validation: {'loss': 0.13315860885754233}
# Epoch 196/200
#    -- Batch 1/5 / tensor(3.2160, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08060585
#    -- Batch 2/5 / tensor(3.6484, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09217261
#    -- Batch 3/5 / tensor(3.8382, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09673243
#    -- Batch 4/5 / tensor(3.5989, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08300315
#    -- Batch 5/5 / tensor(3.2066, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08444847
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.087392494}
#    Validation: {'loss': 0.13297572313994172}
# Epoch 197/200
#    -- Batch 1/5 / tensor(3.7396, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.096999004
#    -- Batch 2/5 / tensor(3.8699, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08448081
#    -- Batch 3/5 / tensor(4.0539, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.0922147
#    -- Batch 4/5 / tensor(3.1917, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.0842721
#    -- Batch 5/5 / tensor(2.2678, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.07164042
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08592141}
#    Validation: {'loss': 0.1323628740664572}
# Epoch 198/200
#    -- Batch 1/5 / tensor(3.8985, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.0857552
#    -- Batch 2/5 / tensor(3.3554, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09283592
#    -- Batch 3/5 / tensor(3.4027, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08953668
#    -- Batch 4/5 / tensor(3.5241, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09624174
#    -- Batch 5/5 / tensor(3.2277, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.07512348
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.087898605}
#    Validation: {'loss': 0.1321476506721229}
# Epoch 199/200
#    -- Batch 1/5 / tensor(3.4180, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.087024204
#    -- Batch 2/5 / tensor(2.9428, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.07948591
#    -- Batch 3/5 / tensor(3.7337, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09603148
#    -- Batch 4/5 / tensor(3.2875, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.08521839
#    -- Batch 5/5 / tensor(3.5142, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.0790181
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08535562}
#    Validation: {'loss': 0.13150329804234212}
# Epoch 200/200
#    -- Batch 1/5 / tensor(3.8333, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09182276
#    -- Batch 2/5 / tensor(3.9737, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09471104
#    -- Batch 3/5 / tensor(2.8623, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.07468748
#    -- Batch 4/5 / tensor(3.9578, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.09179509
#    -- Batch 5/5 / tensor(2.8076, device='cuda:0', grad_fn=<DivBackward0>)
# Loss:  0.077283114
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0860599}
#    Validation: {'loss': 0.13138774132356054}

# %%
plot_histories(train_history['loss'], val_history['loss'], label="Loss")
# plot_histories(train_history=None, val_history=val_history['f1'], label="F1 Score")
plt.show()

# %%
# Select a test image
x,y = test_set[0]
pred = evaluate_model_on_single_image(model, x)

# Plot the result
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 15))
ax1.set_title("True mask")
ax2.set_title("Predicted mask")
plot_image_with_segmentation(x, y, ax=ax1, model='rgb')
plot_image_with_segmentation(x, pred, ax=ax2, model='rgb')
plt.show()

# %%
class SegmentationMetric(object):
    def __init__(self, numClass):
        self.numClass = numClass
        self.confusionMatrix = np.zeros((self.numClass,) * 2)  # 混淆矩阵（空）

    def pixelAccuracy(self):
        # return all class overall pixel accuracy 正确的像素占总像素的比例
        #  PA = acc = (TP + TN) / (TP + TN + FP + TN)
        acc = np.diag(self.confusionMatrix).sum() / self.confusionMatrix.sum()
        return acc

    def classPixelAccuracy(self):
        # return each category pixel accuracy(A more accurate way to call it precision)
        # acc = (TP) / TP + FP
        classAcc = np.diag(self.confusionMatrix) / self.confusionMatrix.sum(axis=1)
        return classAcc  # 返回的是一个列表值，如：[0.90, 0.80, 0.96]，表示类别1 2 3各类别的预测准确率

    def meanPixelAccuracy(self):
        """
        Mean Pixel Accuracy(MPA，均像素精度)：是PA的一种简单提升，计算每个类内被正确分类像素数的比例，之后求所有类的平均。
        :return:
        """
        classAcc = self.classPixelAccuracy()
        meanAcc = np.nanmean(classAcc)  # np.nanmean 求平均值，nan表示遇到Nan类型，其值取为0
        return meanAcc  # 返回单个值，如：np.nanmean([0.90, 0.80, 0.96, nan, nan]) = (0.90 + 0.80 + 0.96） / 3 =  0.89

    def IntersectionOverUnion(self):
        # Intersection = TP Union = TP + FP + FN
        # IoU = TP / (TP + FP + FN)
        intersection = np.diag(self.confusionMatrix)  # 取对角元素的值，返回列表
        union = np.sum(self.confusionMatrix, axis=1) + np.sum(self.confusionMatrix, axis=0) - np.diag(
            self.confusionMatrix)  # axis = 1表示混淆矩阵行的值，返回列表； axis = 0表示取混淆矩阵列的值，返回列表
        IoU = intersection / union  # 返回列表，其值为各个类别的IoU
        return IoU

    def meanIntersectionOverUnion(self):
        mIoU = np.nanmean(self.IntersectionOverUnion())  # 求各类别IoU的平均
        return mIoU

    def genConfusionMatrix(self, imgPredict, imgLabel):  #
        """
        同FCN中score.py的fast_hist()函数,计算混淆矩阵
        :param imgPredict:
        :param imgLabel:
        :return: 混淆矩阵
        """
        # remove classes from unlabeled pixels in gt image and predict
        mask = (imgLabel >= 0) & (imgLabel < self.numClass)
        label = self.numClass * imgLabel[mask] + imgPredict[mask]
        count = np.bincount(label, minlength=self.numClass ** 2)
        confusionMatrix = count.reshape(self.numClass, self.numClass)
        # print(confusionMatrix)
        return confusionMatrix

    def Frequency_Weighted_Intersection_over_Union(self):
        """
        FWIoU，频权交并比:为MIoU的一种提升，这种方法根据每个类出现的频率为其设置权重。
        FWIOU =     [(TP+FN)/(TP+FP+TN+FN)] *[TP / (TP + FP + FN)]
        """
        freq = np.sum(self.confusion_matrix, axis=1) / np.sum(self.confusion_matrix)
        iu = np.diag(self.confusion_matrix) / (
                np.sum(self.confusion_matrix, axis=1) + np.sum(self.confusion_matrix, axis=0) -
                np.diag(self.confusion_matrix))
        FWIoU = (freq[freq > 0] * iu[freq > 0]).sum()
        return FWIoU

    def addBatch(self, imgPredict, imgLabel):
        assert imgPredict.shape == imgLabel.shape
        self.confusionMatrix += self.genConfusionMatrix(imgPredict, imgLabel)  # 得到混淆矩阵
        return self.confusionMatrix

    def reset(self):
        self.confusionMatrix = np.zeros((self.numClass, self.numClass))

# %%
def meanSkeletonAccuracy(x, y):
    skel_x = soft_skel(x)
    skel_y = soft_skel(y)
    metric = SegmentationMetric(2)
    hist = metric.addBatch(skel_x, skel_y)

    return metric.pixelAccuracy()

# %%
threshold = 0.5

imLst_train = train_set.show()
imLst_test = test_set.show()

eval_loss_func = cldice()

# %%
mean_metric_train = {'IoU':[], 'PA':[], 'clDice':[]}

for i, (x, y) in enumerate(train_set):
    pred = evaluate_model_on_single_image(model, x)

    print(imLst_train[i]+':')

    # Plot the result
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 10))
    ax1.set_title("True mask")
    ax2.set_title("Predicted mask")
    plot_image_with_segmentation(x, y, ax=ax1, model='rgb')
    plot_image_with_segmentation(x, pred, ax=ax2, model='rgb')
    ax1.axis('off')
    ax2.axis('off')
    plt.show()

    # save result
    segm = pred.cpu().detach().numpy()
    segm[segm < threshold] = 0
    segm[segm >= threshold] = 255
    mask = segm.squeeze()

    cldice = eval_loss_func(pred.to(device), y.unsqueeze(0).to(device)).cpu().detach().numpy().item()

    pred_mask = torch.where(pred > threshold, torch.ones_like(pred), torch.zeros_like(pred))
    pred_mask, real_mask = pred_mask.cpu().numpy().squeeze(), y.cpu().numpy().squeeze()
    pred_mask, real_mask = pred_mask.astype(np.int32), real_mask.astype(np.int32)

    metric = SegmentationMetric(2)
    hist = metric.addBatch(pred_mask, real_mask)
    pa = metric.pixelAccuracy()
    cpa = metric.classPixelAccuracy()
    mpa = metric.meanPixelAccuracy()
    IoU = metric.IntersectionOverUnion()
    mIoU = metric.meanIntersectionOverUnion()
    print('hist:\n{},\niou:{},\nmiou:{},\nPA:{},\ncPA:{},\nmPA:{}'.format(hist, IoU, mIoU, pa, cpa, mpa))
    print('clDice:', cldice)
    print('--'*20)

    mean_metric_train['IoU'].append(mIoU)
    mean_metric_train['PA'].append(pa)
    mean_metric_train['clDice'].append(cldice)

    # result = Image.fromarray(mask)
    # result = result.convert('L')
    # result.save("/content/drive/MyDrive/code/Post-Processing/unet/AngioData/train/result/"+"threshold_"+str(threshold)+"/"+imLst_train[i])



# IoU_list = mean_metric_train['IoU']
# PA_list = mean_metric_train['PA']
# clDice_list = mean_metric_train['clDice']
# print('IoU: segm')
# print('  Min IoU: {:.4f}, \n  0.25 IoU: {:.4f}, \n  0.5 IoU: {:.4f}, \n  0.75 IoU: {:.4f}, \n  Max IoU: {:.4f}, \n  mIoU: {:.4f}'
#     .format(np.min(IoU_list), statistics.quantiles(IoU_list, n=4)[0], statistics.quantiles(IoU_list, n=4)[1], statistics.quantiles(IoU_list, n=4)[2], np.max(IoU_list), np.mean(IoU_list)))
# print('PA: segm')
# print('  Min PA: {:.4f}, \n  0.25 PA: {:.4f}, \n  0.5 PA: {:.4f}, \n  0.75 PA: {:.4f}, \n  Max PA: {:.4f}, \n  mPA: {:.4f}'
#     .format(np.min(PA_list), statistics.quantiles(PA_list, n=4)[0], statistics.quantiles(PA_list, n=4)[1], statistics.quantiles(PA_list, n=4)[2], np.max(PA_list), np.mean(PA_list)))
# Out:
# 22_training.tif:
# hist:
# [[3418.  124.]
#  [ 217.  337.]],
# iou:[0.90928438 0.49705015],
# miou:0.7031672658186724,
# PA:0.916748046875,
# cPA:[0.96499153 0.60830325],
# mPA:0.7866473896531971
# clDice: 0.37116605043411255
# ----------------------------------------
# 29_training.tif:
# hist:
# [[3092.   83.]
#  [ 171.  750.]],
# iou:[0.92408846 0.74701195],
# miou:0.8355502080143264,
# PA:0.93798828125,
# cPA:[0.97385827 0.81433225],
# mPA:0.8940952576367693
# clDice: 0.08325773477554321
# ----------------------------------------
# 25_training.tif:
# hist:
# [[3306.  157.]
#  [ 222.  411.]],
# iou:[0.89715061 0.52025316],
# miou:0.7087018875702042,
# PA:0.907470703125,
# cPA:[0.95466359 0.6492891 ],
# mPA:0.8019763430058862
# clDice: 0.38714534044265747
# ----------------------------------------
# 26_training.tif:
# hist:
# [[3214.  107.]
#  [ 226.  549.]],
# iou:[0.90611785 0.62244898],
# miou:0.7642834128294679,
# PA:0.918701171875,
# cPA:[0.96778079 0.7083871 ],
# mPA:0.8380839428465969
# clDice: 0.25481653213500977
# ----------------------------------------
# 24_training.tif:
# hist:
# [[3371.  147.]
#  [ 141.  437.]],
# iou:[0.92128997 0.60275862],
# miou:0.7620242953133982,
# PA:0.9296875,
# cPA:[0.95821489 0.75605536],
# mPA:0.8571351290742026
# clDice: 0.31071406602859497
# ----------------------------------------
# 30_training.tif:
# hist:
# [[3239.  111.]
#  [ 186.  560.]],
# iou:[0.91600679 0.65344224],
# miou:0.7847245138518562,
# PA:0.927490234375,
# cPA:[0.96686567 0.75067024],
# mPA:0.8587679564643271
# clDice: 0.2732424736022949
# ----------------------------------------
# 23_training.tif:
# hist:
# [[3509.  423.]
#  [  78.   86.]],
# iou:[0.87506234 0.14650767],
# miou:0.5107850051192292,
# PA:0.877685546875,
# cPA:[0.89242116 0.52439024],
# mPA:0.7084057018087984
# clDice: 0.7498522996902466
# ----------------------------------------
# 31_training.tif:
# hist:
# [[3603.  218.]
#  [  75.  200.]],
# iou:[0.92479466 0.40567951],
# miou:0.6652370871877746,
# PA:0.928466796875,
# cPA:[0.94294687 0.72727273],
# mPA:0.8351097999095906
# clDice: 0.4505416750907898
# ----------------------------------------
# 21_training.tif:
# hist:
# [[3234.   58.]
#  [ 121.  683.]],
# iou:[0.94755347 0.79234339],
# miou:0.8699484297448747,
# PA:0.956298828125,
# cPA:[0.98238153 0.84950249],
# mPA:0.9159420092731966
# clDice: 0.21447443962097168
# ----------------------------------------
# 27_training.tif:
# hist:
# [[3176.   33.]
#  [ 257.  630.]],
# iou:[0.91633006 0.68478261],
# miou:0.8005563360846986,
# PA:0.92919921875,
# cPA:[0.98971642 0.7102593 ],
# mPA:0.8499878617881009
# clDice: 0.17130005359649658
# ----------------------------------------
# 28_training.tif:
# hist:
# [[3119.   35.]
#  [ 297.  645.]],
# iou:[0.903796   0.66018424],
# miou:0.7819901193103507,
# PA:0.9189453125,
# cPA:[0.98890298 0.68471338],
# mPA:0.8368081780693003
# clDice: 0.24060273170471191
# ----------------------------------------
# 36_training.tif:
# hist:
# [[3173.   29.]
#  [ 348.  546.]],
# iou:[0.89380282 0.5915493 ],
# miou:0.7426760563380281,
# PA:0.907958984375,
# cPA:[0.99094316 0.61073826],
# mPA:0.8008407077791146
# clDice: 0.3097243309020996
# ----------------------------------------
# 40_training.tif:
# hist:
# [[3440.  132.]
#  [  75.  449.]],
# iou:[0.94324102 0.68445122],
# miou:0.8138461197643234,
# PA:0.949462890625,
# cPA:[0.96304591 0.85687023],
# mPA:0.9099580708308044
# clDice: 0.16469621658325195
# ----------------------------------------
# 33_training.tif:
# hist:
# [[3298.   47.]
#  [ 179.  572.]],
# iou:[0.93586833 0.71679198],
# miou:0.8263301556957092,
# PA:0.94482421875,
# cPA:[0.98594918 0.76165113],
# mPA:0.8738001548508316
# clDice: 0.33069908618927
# ----------------------------------------
# 37_training.tif:
# hist:
# [[3042.   61.]
#  [ 194.  799.]],
# iou:[0.92265696 0.75806452],
# miou:0.8403607385012768,
# PA:0.937744140625,
# cPA:[0.9803416  0.80463243],
# mPA:0.8924870159437039
# clDice: 0.15226519107818604
# ----------------------------------------
# 38_training.tif:
# hist:
# [[3402.  134.]
#  [ 140.  420.]],
# iou:[0.92546246 0.60518732],
# miou:0.7653248895397515,
# PA:0.93310546875,
# cPA:[0.96210407 0.75      ],
# mPA:0.8560520361990951
# clDice: 0.28019481897354126
# ----------------------------------------
# 34_training.tif:
# hist:
# [[3251.  300.]
#  [ 242.  303.]],
# iou:[0.85710519 0.35857988],
# miou:0.6078425377174084,
# PA:0.86767578125,
# cPA:[0.91551676 0.5559633 ],
# mPA:0.735740029297859
# clDice: 0.46077245473861694
# ----------------------------------------
# 35_training.tif:
# hist:
# [[3368.  185.]
#  [ 126.  417.]],
# iou:[0.91546616 0.5728022 ],
# miou:0.7441341785423057,
# PA:0.924072265625,
# cPA:[0.94793133 0.7679558 ],
# mPA:0.8579435633726382
# clDice: 0.21558815240859985
# ----------------------------------------
# 39_training.tif:
# hist:
# [[3237.  153.]
#  [ 212.  494.]],
# iou:[0.89866741 0.57508731],
# miou:0.7368773589113279,
# PA:0.910888671875,
# cPA:[0.95486726 0.69971671],
# mPA:0.827291985259094
# clDice: 0.362404465675354
# ----------------------------------------
# 32_training.tif:
# hist:
# [[3215.   86.]
#  [ 150.  645.]],
# iou:[0.93161402 0.73212259],
# miou:0.8318683064442655,
# PA:0.9423828125,
# cPA:[0.97394729 0.81132075],
# mPA:0.8926340217086874
# clDice: 0.16226619482040405
# ----------------------------------------

# %%
toPIL = transforms.ToPILImage()
mean_metric_test = {'IoU':[], 'PA':[], 'clDice':[]}
for i, (x, y) in enumerate(test_set):
    pred = evaluate_model_on_single_image(model, x)

    print(imLst_test[i]+':')

    # Plot the result
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 10))
    ax1.set_title("True mask")
    ax2.set_title("Predicted mask")
    plot_image_with_segmentation(x, y, ax=ax1, model='rgb')
    plot_image_with_segmentation(x, pred, ax=ax2, model='rgb')
    ax1.axis('off')
    ax2.axis('off')
    plt.show()

    # save result
    segm = pred.cpu().detach().numpy()
    segm[segm < threshold] = 0
    segm[segm >= threshold] = 255
    mask = segm.squeeze()

    pred_mask = torch.where(pred > threshold, torch.ones_like(pred), torch.zeros_like(pred))
    pred_mask, real_mask = pred_mask.cpu().numpy().squeeze(), y.cpu().numpy().squeeze()
    pred_mask, real_mask = pred_mask.astype(np.int32), real_mask.astype(np.int32)

    cldice = eval_loss_func(pred.to(device), y.unsqueeze(0).to(device)).cpu().detach().numpy().item()

    metric = SegmentationMetric(2)
    hist = metric.addBatch(pred_mask, real_mask)
    pa = metric.pixelAccuracy()
    cpa = metric.classPixelAccuracy()
    mpa = metric.meanPixelAccuracy()
    IoU = metric.IntersectionOverUnion()
    mIoU = metric.meanIntersectionOverUnion()
    print('hist:\n{},\niou:{},\nmiou:{},\nPA:{},\ncPA:{},\nmPA:{}'.format(hist, IoU, mIoU, pa, cpa, mpa))
    print('clDice:', cldice)
    print('--'*20)

    mean_metric_test['IoU'].append(mIoU)
    mean_metric_test['PA'].append(pa)
    mean_metric_test['clDice'].append(cldice)

    # result = Image.fromarray(mask)
    # result = result.convert('L')
    # result.save("/content/drive/MyDrive/code/Post-Processing/unet/AngioData/test/result/"+"threshold_"+str(threshold)+"/"+imLst_test[i])

# IoU_list = mean_metric_test['IoU']
# PA_list = mean_metric_test['PA']
# clDice_list = mean_metric_test['clDice']
# print('IoU: segm')
# print('  Min IoU: {:.4f}, \n  0.25 IoU: {:.4f}, \n  0.5 IoU: {:.4f}, \n  0.75 IoU: {:.4f}, \n  Max IoU: {:.4f}, \n  mIoU: {:.4f}'
#     .format(np.min(IoU_list), statistics.quantiles(IoU_list, n=4)[0], statistics.quantiles(IoU_list, n=4)[1], statistics.quantiles(IoU_list, n=4)[2], np.max(IoU_list), np.mean(IoU_list)))
# print('PA: segm')
# print('  Min PA: {:.4f}, \n  0.25 PA: {:.4f}, \n  0.5 PA: {:.4f}, \n  0.75 PA: {:.4f}, \n  Max PA: {:.4f}, \n  mPA: {:.4f}'
#     .format(np.min(PA_list), statistics.quantiles(PA_list, n=4)[0], statistics.quantiles(PA_list, n=4)[1], statistics.quantiles(PA_list, n=4)[2], np.max(PA_list), np.mean(PA_list)))
# Out:
# 01_test.tif:
# hist:
# [[3075.   73.]
#  [ 415.  533.]],
# iou:[0.86303677 0.52203722],
# miou:0.6925369925914482,
# PA:0.880859375,
# cPA:[0.97681067 0.56223629],
# mPA:0.7695234801816437
# clDice: 0.3069852590560913
# ----------------------------------------
# 03_test.tif:
# hist:
# [[3204.   62.]
#  [ 262.  568.]],
# iou:[0.90816327 0.6367713 ],
# miou:0.7724672828772765,
# PA:0.9208984375,
# cPA:[0.98101653 0.68433735],
# mPA:0.8326769416920592
# clDice: 0.2646474838256836
# ----------------------------------------
# 02_test.tif:
# hist:
# [[3086.   85.]
#  [ 421.  504.]],
# iou:[0.8591314 0.4990099],
# miou:0.6790706520540695,
# PA:0.87646484375,
# cPA:[0.97319458 0.54486486],
# mPA:0.7590297203542237
# clDice: 0.46967387199401855
# ----------------------------------------
# 13_test.tif:
# hist:
# [[3385.  399.]
#  [ 205.  107.]],
# iou:[0.8485836  0.15049226],
# miou:0.4995379346649136,
# PA:0.8525390625,
# cPA:[0.89455603 0.34294872],
# mPA:0.6187523716593484
# clDice: 0.730471134185791
# ----------------------------------------
# 09_test.tif:
# hist:
# [[3367.  146.]
#  [ 111.  472.]],
# iou:[0.92908389 0.64746228],
# miou:0.7882730811508099,
# PA:0.937255859375,
# cPA:[0.95844008 0.80960549],
# mPA:0.8840227842773642
# clDice: 0.2592756152153015
# ----------------------------------------
# 08_test.tif:
# hist:
# [[3376.  124.]
#  [ 158.  438.]],
# iou:[0.92290869 0.60833333],
# miou:0.7656210133041734,
# PA:0.93115234375,
# cPA:[0.96457143 0.73489933],
# mPA:0.8497353787152444
# clDice: 0.16045725345611572
# ----------------------------------------
# 06_test.tif:
# hist:
# [[3344.  165.]
#  [ 248.  339.]],
# iou:[0.89007187 0.45079787],
# miou:0.670434869095419,
# PA:0.899169921875,
# cPA:[0.95297806 0.57751278],
# mPA:0.765245416628839
# clDice: 0.505062997341156
# ----------------------------------------
# 10_test.tif:
# hist:
# [[2990.   16.]
#  [ 386.  704.]],
# iou:[0.88148585 0.63652803],
# miou:0.759006938994848,
# PA:0.90185546875,
# cPA:[0.99467731 0.64587156],
# mPA:0.8202744358378045
# clDice: 0.23197436332702637
# ----------------------------------------
# 12_test.tif:
# hist:
# [[3229.  122.]
#  [ 233.  512.]],
# iou:[0.90094866 0.5905421 ],
# miou:0.7457453799534519,
# PA:0.913330078125,
# cPA:[0.96359296 0.68724832],
# mPA:0.8254206397369112
# clDice: 0.25818347930908203
# ----------------------------------------
# 04_test.tif:
# hist:
# [[3520.  325.]
#  [  80.  171.]],
# iou:[0.89681529 0.296875  ],
# miou:0.5968451433121019,
# PA:0.901123046875,
# cPA:[0.91547464 0.6812749 ],
# mPA:0.798374771395562
# clDice: 0.3872387409210205
# ----------------------------------------
# 07_test.tif:
# hist:
# [[3378.  131.]
#  [ 238.  349.]],
# iou:[0.90152122 0.48607242],
# miou:0.6937968201859538,
# PA:0.909912109375,
# cPA:[0.96266743 0.59454855],
# mPA:0.7786079892881921
# clDice: 0.36186593770980835
# ----------------------------------------
# 11_test.tif:
# hist:
# [[3441.  119.]
#  [ 213.  323.]],
# iou:[0.91200636 0.49312977],
# miou:0.7025680659891596,
# PA:0.9189453125,
# cPA:[0.96657303 0.60261194],
# mPA:0.7845924870031864
# clDice: 0.4694153666496277
# ----------------------------------------
# 14_test.tif:
# hist:
# [[3422.  230.]
#  [ 145.  299.]],
# iou:[0.90123782 0.44362018],
# miou:0.6724289986862969,
# PA:0.908447265625,
# cPA:[0.93702081 0.67342342],
# mPA:0.805222116969105
# clDice: 0.38823258876800537
# ----------------------------------------
# 15_test.tif:
# hist:
# [[3571.  374.]
#  [  47.  104.]],
# iou:[0.89453908 0.19809524],
# miou:0.5463171581257753,
# PA:0.897216796875,
# cPA:[0.90519645 0.68874172],
# mPA:0.7969690865291802
# clDice: 0.580391526222229
# ----------------------------------------
# 05_test.tif:
# hist:
# [[3309.  109.]
#  [ 137.  541.]],
# iou:[0.93080169 0.68742058],
# miou:0.8091111361309036,
# PA:0.93994140625,
# cPA:[0.96811001 0.7979351 ],
# mPA:0.8830225545481064
# clDice: 0.2613264322280884
# ----------------------------------------
# 19_test.tif:
# hist:
# [[3361.  110.]
#  [ 117.  508.]],
# iou:[0.93673356 0.69115646],
# miou:0.8139450094419038,
# PA:0.944580078125,
# cPA:[0.96830884 0.8128    ],
# mPA:0.8905544223566695
# clDice: 0.18058693408966064
# ----------------------------------------
# 17_test.tif:
# hist:
# [[3445.  208.]
#  [ 138.  305.]],
# iou:[0.90873121 0.46850998],
# miou:0.6886205950628479,
# PA:0.91552734375,
# cPA:[0.9430605  0.68848758],
# mPA:0.8157740414353767
# clDice: 0.36977237462997437
# ----------------------------------------
# 20_test.tif:
# hist:
# [[3289.  138.]
#  [ 157.  512.]],
# iou:[0.91768973 0.63444857],
# miou:0.7760691535559391,
# PA:0.927978515625,
# cPA:[0.95973154 0.76532138],
# mPA:0.8625264594055035
# clDice: 0.2317999005317688
# ----------------------------------------
# 16_test.tif:
# hist:
# [[3409.  251.]
#  [ 113.  323.]],
# iou:[0.90352505 0.47016012],
# miou:0.6868425814152577,
# PA:0.9111328125,
# cPA:[0.93142077 0.74082569],
# mPA:0.8361232265503584
# clDice: 0.30799227952957153
# ----------------------------------------
# 18_test.tif:
# hist:
# [[3538.  387.]
#  [  30.  141.]],
# iou:[0.89456384 0.25268817],
# miou:0.5736260076397102,
# PA:0.898193359375,
# cPA:[0.90140127 0.8245614 ],
# mPA:0.8629813386970611
# clDice: 0.4817986488342285
# ----------------------------------------

# %%
# print('threshold:', threshold)
print(mean_metric_train)
print(mean_metric_test)
# print('--'*20)
# Out:
# {'IoU': [0.7031672658186724, 0.8355502080143264, 0.7087018875702042, 0.7642834128294679, 0.7620242953133982, 0.7847245138518562, 0.5107850051192292, 0.6652370871877746, 0.8699484297448747, 0.8005563360846986, 0.7819901193103507, 0.7426760563380281, 0.8138461197643234, 0.8263301556957092, 0.8403607385012768, 0.7653248895397515, 0.6078425377174084, 0.7441341785423057, 0.7368773589113279, 0.8318683064442655], 'PA': [0.916748046875, 0.93798828125, 0.907470703125, 0.918701171875, 0.9296875, 0.927490234375, 0.877685546875, 0.928466796875, 0.956298828125, 0.92919921875, 0.9189453125, 0.907958984375, 0.949462890625, 0.94482421875, 0.937744140625, 0.93310546875, 0.86767578125, 0.924072265625, 0.910888671875, 0.9423828125], 'clDice': [0.37116605043411255, 0.08325773477554321, 0.38714534044265747, 0.25481653213500977, 0.31071406602859497, 0.2732424736022949, 0.7498522996902466, 0.4505416750907898, 0.21447443962097168, 0.17130005359649658, 0.24060273170471191, 0.3097243309020996, 0.16469621658325195, 0.33069908618927, 0.15226519107818604, 0.28019481897354126, 0.46077245473861694, 0.21558815240859985, 0.362404465675354, 0.16226619482040405]}
# {'IoU': [0.6925369925914482, 0.7724672828772765, 0.6790706520540695, 0.4995379346649136, 0.7882730811508099, 0.7656210133041734, 0.670434869095419, 0.759006938994848, 0.7457453799534519, 0.5968451433121019, 0.6937968201859538, 0.7025680659891596, 0.6724289986862969, 0.5463171581257753, 0.8091111361309036, 0.8139450094419038, 0.6886205950628479, 0.7760691535559391, 0.6868425814152577, 0.5736260076397102], 'PA': [0.880859375, 0.9208984375, 0.87646484375, 0.8525390625, 0.937255859375, 0.93115234375, 0.899169921875, 0.90185546875, 0.913330078125, 0.901123046875, 0.909912109375, 0.9189453125, 0.908447265625, 0.897216796875, 0.93994140625, 0.944580078125, 0.91552734375, 0.927978515625, 0.9111328125, 0.898193359375], 'clDice': [0.3069852590560913, 0.2646474838256836, 0.46967387199401855, 0.730471134185791, 0.2592756152153015, 0.16045725345611572, 0.505062997341156, 0.23197436332702637, 0.25818347930908203, 0.3872387409210205, 0.36186593770980835, 0.4694153666496277, 0.38823258876800537, 0.580391526222229, 0.2613264322280884, 0.18058693408966064, 0.36977237462997437, 0.2317999005317688, 0.30799227952957153, 0.4817986488342285]}

# %%
box_1, box_2, box_3 = mean_metric_test['IoU'], mean_metric_test['PA'], mean_metric_test['clDice']

plt.figure(figsize=(10,5))
# plt.title('Examples of boxplot',fontsize=15)
labels = ['IoU','PA','clDice']
plt.boxplot([box_1, box_2, box_3], labels = labels, showmeans=True)
# plt.legend()
plt.show()

# %%
def remove_outliers(data, min, max):
    # 确保数据是 NumPy 数组
    data = np.array(data)

    # 计算第5和第95百分位数
    q_low = np.percentile(data, min)
    q_high = np.percentile(data, max)

    # 过滤掉低于第5百分位和高于第95百分位的数据点
    filtered_data = data[(data >= q_low) & (data <= q_high)]
    return filtered_data

# %%
iou_clean = mean_metric_train['IoU']
pa_clean = mean_metric_train['PA']
cldice_clean = remove_outliers(mean_metric_train['clDice'], 10, 90)

# %%
print(np.mean(iou_clean))
print(np.mean(pa_clean))
print(np.mean(cldice_clean))
# Out:
# 0.7548114451149625
# 0.92333984375
# 0.28122353926301

# %%
print(np.median(iou_clean))
print(np.median(pa_clean))
print(np.median(cldice_clean))
# Out:
# 0.7648041511846098
# 0.927978515625
# 0.2767186462879181

# %%
box_1, box_2 = iou_clean, pa_clean

plt.figure(figsize=(10,5))
# plt.title('Examples of boxplot',fontsize=15)
labels = ['IoU','PA']
plt.boxplot([box_1, box_2], labels = labels, showmeans=True)
# plt.legend()
plt.show()

# %%
box_1 = cldice_clean

plt.figure(figsize=(10,5))
# plt.title('Examples of boxplot',fontsize=15)
labels = ['clDice']
plt.boxplot([box_1], labels = labels, showmeans=True)
# plt.legend()
plt.show()

# %%
print(np.std(iou_clean))
print(np.std(pa_clean))
print(np.std(cldice_clean))
# Out:
# 0.08371335637468257
# 0.021377017812687645
# 0.08279722772265764
